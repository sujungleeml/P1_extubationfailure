# %%
import pandas as pd

# %%
adults_icu = pd.read_csv('../outputs/adults_icu2.csv')
intubation_extubation = pd.read_csv('../outputs/intubation_extubation.csv')
intubation_extubation_stay = pd.read_csv('../outputs/intubation_extubation_stay.csv')

print(adults_icu.shape)
print(intubation_extubation.shape)
print(intubation_extubation_stay.shape)

# 시간변수 바꿔주기
intubation_extubation['int_ext_time'] = pd.to_timedelta(intubation_extubation['int_ext_time'])
intubation_extubation['intubationtime'] = pd.to_datetime(intubation_extubation['intubationtime'])
intubation_extubation['extubationtime'] = pd.to_datetime(intubation_extubation['extubationtime'])

intubation_extubation = intubation_extubation.drop(columns=['int_ext_time'])

intubation_extubation.info()
# Out:
# (73181, 13)
# (10928, 15)
# (10111, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10928 entries, 0 to 10927
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subject_id       10928 non-null  int64
#  1   hadm_id          10928 non-null  int64
#  2   int_stayid       10928 non-null  int64
#  3   admittime        10928 non-null  object
#  4   intubationtime   10928 non-null  datetime64[ns]
#  5   int_itemid       10928 non-null  int64
#  6   int_weight       10928 non-null  float64
#  7   ext_stayid       9387 non-null   float64
#  8   extubationtime   9387 non-null   datetime64[ns]
#  9   ext_itemid       9387 non-null   float64
#  10  ext_weight       9387 non-null   float64
#  11  extubationcause  9387 non-null   object
#  12  dischtime        10928 non-null  object
#  13  deathtime        2950 non-null   object
# dtypes: datetime64[ns](2), float64(4), int64(4), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Subject level
#
# - 개별 환자 데이터 기준으로 전처리 코드 작성 중에 있음.
# - 1) 하나의 hadm_id에 1개의 intubation-extubation pair가 존재하는 경우 (코드 완성):
#     - 발관 시간에 결측치가 존재하는가?
#         - deathtime, dischtime 등 대체 가능한 값이 존재하는가?
#     - 삽관-발관 시간 순서가 맞는가?
#
# - 2) 하나의 hadm_id 에 2개 이상의 intubation-extubation pair가 존재하는 경우(즉, 삽관/발관이 여러차례 이루어진 경우), 아래 pseudocode와 같은 정렬 알고리즘을 사용해서 작업해보고자 함 (작업 중).
#     - 1. hadm_id 별로 데이터를 groupby 해줌.
#     - 2. 각 hadm_id 그룹 별로 intubationtime, extubationtime의 고유값(unique value) 추출
#         - 전제: intubation, extubation time의 중복값은 오류로 취급
#     - 3. intubationtime과 extubationtime 에 대해 아래와 같은 정렬 알고리즘 적용 (아직 여러 subject 케이스로 테스트 필요)
#
#
# ```
# # 정렬 알고리즘
# function find_pairs(start_times, end_times):
#     # 빈 리스트 pairs 생성
#     pairs = []
#     # end_times의 인덱스를 추적하기 위한 변수 초기화
#     end_time_index = []
#
#     # start_times의 모든 요소에 대해 반복
#     for each start_time in start_times:
#         # end_times 리스트의 끝에 도달할 때까지 반복
#         while end_time_index < length of end_times:
#             # 현재 start_time보다 늦은 end_time 찾기
#             if end_times[end_time_index] > start_time:
#                 # 다음 pair의 start_time과 겹치지 않는지 확인
#                 if end_time_index + 1 < length of end_times and end_times[end_time_index] > start_times[end_time_index + 1]:
#                     break
#                 # 조건을 만족하는 pair를 pairs 리스트에 추가
#                 append (start_time, end_times[end_time_index]) to pairs
#                 # 다음 end_time으로 이동
#                 increment end_time_index
#                 break
#             else:
#                 # 다음 end_time으로 이동
#                 increment end_time_index
#
#         # 적절한 end_time을 찾지 못한 경우 start_time을 null과 짝지음
#         if end_time_index >= length of end_times:
#             append (start_time, null) to pairs
#
#     # 모든 pair를 포함한 리스트 반환
#     return pairs
#
#
# ```

# %% [markdown]
# ### BASE CODE

# %%
## ROW 단위로 적용되는 함수들

def impute_extubationtime(row):
    """
    누락된 extubationtime을 1) deathtime 2) dischtime 순으로 대체합니다.
    이 함수는 수정된 row를 반환하고 원본 DataFrame은 변경하지 않습니다.

    Args:
    row (pd.Series): DataFrame의 행입니다.

    Returns:
    pd.Series: 수정된 행입니다.
    String: 결측치를 대체한 값에 대한 설명입니다 (deathtime, dischtime) 메인함수에서 logging을 위해 사용됩니다.
    """
    modified_row = row.copy()
    impute_with = None   # 대체값 초기화
    
    if pd.isnull(row['extubationtime']):
        if pd.notnull(row['deathtime']):
            modified_row['extubationtime'] = row['deathtime']
            impute_with = 'deathtime'
        else:
            modified_row['extubationtime'] = row['dischtime']
            impute_with = 'dischtime'

    return modified_row, impute_with


def validate_time_difference(row, df, log_messages):
    """
    intubationtime과 extubationtime 사이의 시간 차이를 검증합니다.
    extubationtime이 intubationtime 보다 뒤에 있어야 합니다. 
    그렇지 않을 경우 log_message가 저장됩니다.  

    Args:
    row (pd.Series): DataFrame의 행입니다.
    df (pd.DataFrame): 처리 중인 DataFrame입니다.
    log_messages (list): 로그 메시지를 저장하는 리스트입니다.

    Returns:
    bool: 시간 차이가 유효한지 여부를 반환합니다 (True: 유효, False: 무효).

    """
    subject_id = row['subject_id']
    hadm_id = row['hadm_id']
    index = row.name

    # 시간 차이 계산
    time_diff = pd.to_datetime(df.at[index, 'extubationtime']) - pd.to_datetime(row['intubationtime'])
    if time_diff <= pd.Timedelta(0):
        log_messages.append(f"{index}, {subject_id}, {hadm_id}: 유효하지 않은 데이터 (extubationtime <= intubationtime)")

    return time_diff >= pd.Timedelta(0)

## GROUP 단위로 적용되는 함수들

def count_unique_events(group):
    """
    주어진 그룹에서 고유한 (시간이 중복되지 않는) intubation 및 extubation 이벤트의 수를 "개별적으로" 계산합니다 (null 값 포함).

    Args:
    group (DataFrame): 특정 그룹화된 DataFrame입니다.

    Returns:
    List: 고유한 intubation 시간과 고유한 extubation 시간의 리스트
    """
    # intubationtime 및 extubationtime의 고유한 값과 Null 값을 계산
    unique_intubations = group['intubationtime'].unique()
    unique_extubations = group['extubationtime'].unique()
    
    isna_extubations_count = group['extubationtime'].isna().sum()
    unique_int_count = len(unique_intubations)
    unique_ext_count = len(unique_extubations)

    # 결과 출력
    print(f"고유한 intubation 이벤트 수: {unique_int_count}")
    print(f"고유한 extubation 이벤트 수: {unique_ext_count}")
    print(f"extubation 결측치 수: {isna_extubations_count}")

    print(f'--고유한 Intubation 이벤트--')
    print(unique_intubations)
    print(f'--고유한 Extubation 이벤트--')
    print(unique_extubations)

    return unique_intubations, unique_extubations


def handle_single_event_cases(group, modified_df):
    """
    처리 그룹에서 단일 이벤트 케이스를 처리합니다.

    Args:
    group (pd.DataFrame): 처리할 그룹 DataFrame.
    modified_df (pd.DataFrame): 수정된 DataFrame.

    Returns:
    pd.DataFrame: 수정된 DataFrame.
    list: 생성된 로그 메시지 리스트.
    """
    log_messages = []
    index = group.index[0]  # 행의 인덱스 가져오기
    row = group.iloc[0]     # 처리할 행 가져오기

    # impute_extubationtime 함수를 호출하여 row 수정 및 impute_with 값 받기
    modified_row, impute_with = impute_extubationtime(row)
    modified_df.loc[index] = modified_row  # 수정된 row로 DataFrame 업데이트

    # 로그 메시지 추가
    if row['extubationtime'] != modified_row['extubationtime']:
        log_message = f"row:{index}, sub_id:{group['subject_id'].iloc[0]}, hadm_id:{group['hadm_id'].iloc[0]}: extubationtime {impute_with}로 수정됨"
        log_messages.append(log_message)

    return modified_df, log_messages


# 정렬 알고리즘
# def find_pairs(unique_intubations, unique_extubations):
#     """
#     고유한 삽관 시간과 발관 시간을 짝지어 주는 함수입니다.

#     Args:
#     unique_intubations (list): 고유한 삽관 시간의 리스트.
#     unique_extubations (list): 고유한 발관 시간의 리스트.

#     Returns:
#     list: 삽관 시간과 발관 시간이 짝지어진 리스트. 발관 시간이 적절하지 않은 경우 None으로 표시됩니다.
#     """

#     pairs = []  # 삽관/발관 페어를 저장할 빈 리스트
#     ext_index = 0  # 발관 시간의 인덱스

#     # 모든 삽관 시간에 대하여
#     for int_index, int_time in enumerate(unique_intubations):
#         # 발관 시간 리스트를 순회
#         while ext_index < len(unique_extubations):
#             # 현재 발관 시간이 삽관 시간보다 늦을 경우
#             if unique_extubations[ext_index] > int_time:
#                 # 다음 삽관 시간과 현재 발관 시간을 비교
#                 if (int_index + 1 < len(unique_intubations) and 
#                     unique_extubations[ext_index] > unique_intubations[int_index + 1]):
#                     break
#                 # 조건을 만족하는 경우, 짝을 pairs 리스트에 추가
#                 pairs.append((int_time, unique_extubations[ext_index]))
#                 ext_index += 1  # 다음 발관 시간으로 이동
#                 break
#             else:
#                 ext_index += 1  # 다음 발관 시간으로 이동
        
#         # 적절한 발관 시간을 찾지 못한 경우, None으로 짝을 지음
#         if ext_index >= len(unique_extubations):
#             pairs.append((int_time, None))
    
#     return pairs  # 짝지어진 리스트 반환

# 정렬 알고리즘 v2
def find_pairs(unique_intubations, unique_extubations):
    """
    고유한 삽관 시간과 발관 시간을 쌍으로 짝지어 주는 함수입니다.
        조건 1. 삽관 시간보다 발관 시간이 뒤에 발생해야 함.
        조건 2. 현재 행의 발관 시간이 다음 행의 삽관 시간과 같거나 빨라야 함.

    Args:
    unique_intubations (list): 고유한 삽관 시간의 리스트.
    unique_extubations (list): 고유한 발관 시간의 리스트.

    Returns:
    list: 삽관 시간과 발관 시간이 짝지어진 리스트.
          적절한 발관 시간을 찾지 못할 경우, 발관 시간은 None으로 표시됩니다.
    """
    pairs = []  # 삽관과 발관 시간의 쌍을 저장할 리스트
    ext_index = 0  # 발관 시간 리스트를 탐색하기 위한 인덱스

    # 모든 삽관 시간에 대하여 반복
    for int_index, int_time in enumerate(unique_intubations):
        matched = False  # 현재 삽관 시간에 대한 적절한 발관 시간을 찾았는지 여부

        # 발관 시간 리스트를 순회
        while ext_index < len(unique_extubations) and not matched:
            ext_time = unique_extubations[ext_index]

            # 현재 발관 시간이 삽관 시간보다 늦은지 확인
            if ext_time > int_time:
                # 마지막 삽관 시간인지, 또는 현재 발관 시간이 다음 삽관 시간보다 이른지 확인
                if int_index + 1 == len(unique_intubations) or ext_time < unique_intubations[int_index + 1]:
                    pairs.append((int_time, ext_time))  # 쌍으로 추가
                    matched = True  # 적절한 쌍을 찾음
                else:
                    # 현재 발관 시간이 다음 삽관 시간보다 늦음, 더 이상 진행하지 않음
                    break

            ext_index += 1  # 다음 발관 시간으로 이동

        # 적절한 발관 시간을 찾지 못한 경우
        if not matched:
            pairs.append((int_time, None))  # 삽관 시간과 None을 쌍으로 추가

    return pairs  # 짝지어진 삽관/발관 시간 리스트 반환

# def extract_row_data(group, intubation_time, extubation_time):
#     # Filter the group based on the intubation and extubation times
#     filtered_group = group[(group['intubationtime'] == intubation_time) & (group['extubationtime'] == extubation_time)]

#     # If no matching row is found, return an empty dict or handle accordingly
#     if filtered_group.empty:
#         return {}

#     row_data = filtered_group.iloc[0]

#     # Handle null extubation time
#     if pd.isnull(extubation_time):
#         for col in ['ext_stayid', 'extubationtime', 'ext_itemid', 'ext_weight', 'extubationcause']:
#             row_data[col] = None

#     # Handle null intubation time
#     if pd.isnull(intubation_time):
#         for col in ['int_stayid', 'admittime', 'intubationtime', 'int_itemid', 'int_weight']:
#             row_data[col] = None

#     return row_data.to_dict()

# 수정 필요
def extract_row_data(group, intubation_time, extubation_time):
    # Initialize a dictionary to store the row data
    row_data = {}

    # Filter for intubation and extubation
    intubation_filtered = group[group['intubationtime'] == intubation_time]
    extubation_filtered = group[group['extubationtime'] == extubation_time]

    # Check if exact match exists
    if not intubation_filtered.empty and not extubation_filtered.empty:
        row_data = intubation_filtered.merge(extubation_filtered, on=['subject_id', 'hadm_id'], how='outer').iloc[0].to_dict()
    else:
        # Handle intubation data
        if not intubation_filtered.empty:
            intubation_data = intubation_filtered.iloc[0]
            for col in ['subject_id', 'hadm_id', 'int_stayid', 'admittime', 'intubationtime', 'int_itemid', 'int_weight', 'dischtime', 'deathtime']:
                row_data[col] = intubation_data[col]
            for col in ['ext_stayid', 'extubationtime', 'ext_itemid', 'ext_weight', 'extubationcause']:
                row_data[col] = None

        # Handle extubation data
        if not extubation_filtered.empty:
            extubation_data = extubation_filtered.iloc[0]
            for col in ['subject_id', 'hadm_id', 'ext_stayid', 'extubationtime', 'ext_itemid', 'ext_weight', 'extubationcause']:
                row_data[col] = extubation_data[col]
            for col in ['int_stayid', 'admittime', 'intubationtime', 'int_itemid', 'int_weight']:
                row_data.setdefault(col, None)  # Set as None if not already set by intubation data

    return row_data


## DATAFRAME 단위로 적용되는 함수들
## 메인 코드 ##
def process_intubation_data_grouped(df):
    """
    subject_id와 hadm_id 별로 그룹화된 intubation/extubation 데이터를 처리합니다.

    Args:
    df (pd.DataFrame): 데이터가 포함된 DataFrame입니다.

    Returns:
    pd.DataFrame: 처리된 DataFrame입니다.
    """

    modified_df = df.copy()  # 원본 DataFrame의 복사본 생성
    all_log_messages = []

    # subject_id와 hadm_id로 그룹화

    for (subject_id, hadm_id), group in df.groupby(['subject_id', 'hadm_id']):
        # 해당 그룹(hadm_id)에 intubation 이벤트가 하나만 있는 경우
        if group['intubationtime'].count() == 1:
            modified_df, log_messages = handle_single_event_cases(group, modified_df)
            all_log_messages.extend(log_messages)

        # 해당 그룹(hadm_id) 안에 여러개의 intubation 이벤트가 있는 경우
        else:
            pair_logs = []
            # 1. intubation/extubation 페어링
            pair_results = {}  # 해당 그룹의 삽관/발관 페어링 결과 저장소

            unique_intubations = list(group['intubationtime'].dropna().unique())
            unique_extubations = list(group['extubationtime'].dropna().unique())

            pairs = find_pairs(unique_intubations, unique_extubations)
            pair_results[(subject_id, hadm_id)] = pairs  # 페어링 결과 저장

            for pair in pairs:
                pair_logs.append(f"sub_id:{subject_id}, hadm_id:{hadm_id}: intubation/extubation pair: {pair}")
            
            # 2. 페어링된 값을 DataFrame에 적용 (작업중)
            extracted_data = []  # Extracted data from each pair
            for int_time, ext_time in pairs:
                data = extract_row_data(group, int_time, ext_time)
                extracted_data.append(data)


    return modified_df, all_log_messages, pair_logs, pair_results, extracted_data  # log_messages

# %% [markdown]
# ### TEST CODE (아래)

# %%
test_subs = [10098215, 10004401, 10007818, 13033327, \
             1513422667, 13515178, 18344437, 19997367, \
                13696494, 12495515, 10233597]

intubation_extubation_test = intubation_extubation[intubation_extubation.subject_id.isin(test_subs)]
intubation_extubation_test.subject_id.unique()
# Out:
# array([10004401, 10007818, 10098215, 10233597, 12495515, 13033327,
#        13515178, 13696494, 18344437, 19997367])

# %%
intubation_extubation_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 2 to 10924
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subject_id       87 non-null     int64
#  1   hadm_id          87 non-null     int64
#  2   int_stayid       87 non-null     int64
#  3   admittime        87 non-null     object
#  4   intubationtime   87 non-null     datetime64[ns]
#  5   int_itemid       87 non-null     int64
#  6   int_weight       87 non-null     float64
#  7   ext_stayid       85 non-null     float64
#  8   extubationtime   85 non-null     datetime64[ns]
#  9   ext_itemid       85 non-null     float64
#  10  ext_weight       85 non-null     float64
#  11  extubationcause  85 non-null     object
#  12  dischtime        87 non-null     object
#  13  deathtime        11 non-null     object
# dtypes: datetime64[ns](2), float64(4), int64(4), object(4)
# memory usage: 10.2+ KB

# %%
intubation_extubation_test
# Out:
#        subject_id   hadm_id  int_stayid            admittime  \
# 2        10004401  27939719    31202136  2144-04-11 03:31:00
# 3        10004401  29988601    32773003  2144-01-23 07:58:00
# 4        10004401  29988601    32773003  2144-01-23 07:58:00
# 6        10007818  22987108    32359580  2146-06-10 16:37:00
# 69       10098215  20652197    37703075  2118-08-14 20:31:00
# ...           ...       ...         ...                  ...
# 10920    19997367  20617667    35616526  2126-04-20 07:15:00
# 10921    19997367  20617667    35616526  2126-04-20 07:15:00
# 10922    19997367  20617667    35616526  2126-04-20 07:15:00
# 10923    19997367  20617667    35616526  2126-04-20 07:15:00
# 10924    19997367  20617667    35616526  2126-04-20 07:15:00
#
#            intubationtime  int_itemid  int_weight  ext_stayid  \
# 2     2144-04-11 05:03:00      224385       120.0         NaN
# 3     2144-01-27 19:00:00      224385        76.0  32773003.0
# 4     2144-01-30 13:00:00      224385        76.0  32773003.0
# 6     2146-06-22 12:49:00      224385        86.2         NaN
# 69    2118-09-02 07:45:00      224385        66.0  37703075.0
# ...                   ...         ...         ...         ...
# 10920 2126-04-26 20:14:00      224385        59.0  35616526.0
# 10921 2126-04-26 20:14:00      224385        59.0  35616526.0
# 10922 2126-05-05 18:20:00      224385        59.0  35616526.0
# 10923 2126-05-05 18:20:00      224385        59.0  35616526.0
# 10924 2126-05-05 18:20:00      224385        59.0  35616526.0
#
#            extubationtime  ext_itemid  ext_weight     extubationcause  \
# 2                     NaT         NaN         NaN                 NaN
# 3     2144-01-30 12:30:00    227194.0        76.0  Planned Extubation
# 4     2144-01-30 12:30:00    227194.0        76.0  Planned Extubation
# 6                     NaT         NaN         NaN                 NaN
# 69    2118-09-05 11:20:00    227194.0        66.0  Planned Extubation
# ...                   ...         ...         ...                 ...
# 10920 2126-05-02 16:30:00    227194.0        59.0  Planned Extubation
# 10921 2126-05-08 17:29:00    227194.0        59.0  Planned Extubation
# 10922 2126-04-22 08:23:00    227194.0        59.0  Planned Extubation
# 10923 2126-05-02 16:30:00    227194.0        59.0  Planned Extubation
# 10924 2126-05-08 17:29:00    227194.0        59.0  Planned Extubation
#
#                  dischtime            deathtime
# 2      2144-04-13 17:31:00                  NaN
# 3      2144-02-06 11:45:00                  NaN
# 4      2144-02-06 11:45:00                  NaN
# 6      2146-07-12 00:00:00  2146-07-12 20:50:00
# 69     2118-09-18 15:15:00                  NaN
# ...                    ...                  ...
# 10920  2126-05-19 14:15:00                  NaN
# 10921  2126-05-19 14:15:00                  NaN
# 10922  2126-05-19 14:15:00                  NaN
# 10923  2126-05-19 14:15:00                  NaN
# 10924  2126-05-19 14:15:00                  NaN
#
# [87 rows x 14 columns]

# %%
processed_df_grouped, all_log_messages, pair_logs, pair_results, extracted_data = process_intubation_data_grouped(intubation_extubation_test)

# %%
extracted_data
# Out:
# [{'subject_id': 19997367,
#   'hadm_id': 20617667,
#   'int_stayid_x': 35616526,
#   'admittime_x': '2126-04-20 07:15:00',
#   'intubationtime_x': Timestamp('2126-04-26 20:14:00'),
#   'int_itemid_x': 224385,
#   'int_weight_x': 59.0,
#   'ext_stayid_x': 35616526.0,
#   'extubationtime_x': Timestamp('2126-04-22 08:23:00'),
#   'ext_itemid_x': 227194.0,
#   'ext_weight_x': 59.0,
#   'extubationcause_x': 'Planned Extubation',
#   'dischtime_x': '2126-05-19 14:15:00',
#   'deathtime_x': nan,
#   'int_stayid_y': 35616526,
#   'admittime_y': '2126-04-20 07:15:00',
#   'intubationtime_y': Timestamp('2126-04-26 20:14:00'),
#   'int_itemid_y': 224385,
#   'int_weight_y': 59.0,
#   'ext_stayid_y': 35616526.0,
#   'extubationtime_y': Timestamp('2126-05-02 16:30:00'),
#   'ext_itemid_y': 227194.0,
#   'ext_weight_y': 59.0,
#   'extubationcause_y': 'Planned Extubation',
#   'dischtime_y': '2126-05-19 14:15:00',
#   'deathtime_y': nan},
#  {'subject_id': 19997367,
#   'hadm_id': 20617667,
#   'int_stayid_x': 35616526,
#   'admittime_x': '2126-04-20 07:15:00',
#   'intubationtime_x': Timestamp('2126-05-05 18:20:00'),
#   'int_itemid_x': 224385,
#   'int_weight_x': 59.0,
#   'ext_stayid_x': 35616526.0,
#   'extubationtime_x': Timestamp('2126-04-22 08:23:00'),
#   'ext_itemid_x': 227194.0,
#   'ext_weight_x': 59.0,
#   'extubationcause_x': 'Planned Extubation',
#   'dischtime_x': '2126-05-19 14:15:00',
#   'deathtime_x': nan,
#   'int_stayid_y': 35616526,
#   'admittime_y': '2126-04-20 07:15:00',
#   'intubationtime_y': Timestamp('2126-04-26 20:14:00'),
#   'int_itemid_y': 224385,
#   'int_weight_y': 59.0,
#   'ext_stayid_y': 35616526.0,
#   'extubationtime_y': Timestamp('2126-05-08 17:29:00'),
#   'ext_itemid_y': 227194.0,
#   'ext_weight_y': 59.0,
#   'extubationcause_y': 'Planned Extubation',
#   'dischtime_y': '2126-05-19 14:15:00',
#   'deathtime_y': nan}]

# %%
len(pair_logs)
# Out:
# 27

# %%
pair_results.items()
# Out:
# dict_items([((19997367, 20617667), [(Timestamp('2126-04-26 20:14:00'), Timestamp('2126-05-02 16:30:00')), (Timestamp('2126-05-05 18:20:00'), Timestamp('2126-05-08 17:29:00'))])])

# %%
intubation_extubation_test[(intubation_extubation_test.subject_id == 10098215) & (intubation_extubation_test.hadm_id == 22394571)]
# Out:
#     subject_id   hadm_id  int_stayid            admittime      intubationtime  \
# 71    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 72    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 73    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 74    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 75    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 76    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 77    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 78    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 79    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 80    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 81    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 82    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 83    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 84    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 85    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 86    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 87    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 88    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 89    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 90    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
#
#     int_itemid  int_weight  ext_stayid      extubationtime  ext_itemid  \
# 71      224385        60.0  36018186.0 2118-06-06 16:33:00    227194.0
# 72      224385        60.0  36018186.0 2118-06-08 11:55:00    227194.0
# 73      224385        60.0  32301420.0 2118-06-21 03:30:00    225468.0
# 74      224385        60.0  32301420.0 2118-06-27 12:45:00    227194.0
# 75      224385        55.4  36018186.0 2118-06-06 16:33:00    227194.0
# 76      224385        55.4  36018186.0 2118-06-08 11:55:00    227194.0
# 77      224385        55.4  32301420.0 2118-06-21 03:30:00    225468.0
# 78      224385        55.4  32301420.0 2118-06-27 12:45:00    227194.0
# 79      224385        55.4  36018186.0 2118-06-06 16:33:00    227194.0
# 80      224385        55.4  36018186.0 2118-06-08 11:55:00    227194.0
# 81      224385        55.4  32301420.0 2118-06-21 03:30:00    225468.0
# 82      224385        55.4  32301420.0 2118-06-27 12:45:00    227194.0
# 83      224385        48.7  36018186.0 2118-06-06 16:33:00    227194.0
# 84      224385        48.7  36018186.0 2118-06-08 11:55:00    227194.0
# 85      224385        48.7  32301420.0 2118-06-21 03:30:00    225468.0
# 86      224385        48.7  32301420.0 2118-06-27 12:45:00    227194.0
# 87      224385        48.7  36018186.0 2118-06-06 16:33:00    227194.0
# 88      224385        48.7  36018186.0 2118-06-08 11:55:00    227194.0
# 89      224385        48.7  32301420.0 2118-06-21 03:30:00    225468.0
# 90      224385        48.7  32301420.0 2118-06-27 12:45:00    227194.0
#
#     ext_weight                           extubationcause       int_ext_time  \
# 71        55.4                        Planned Extubation   27 days 21:31:00
# 72        55.4                        Planned Extubation   29 days 16:53:00
# 73        48.7  Unplanned Extuabtion (patient-initiated)   42 days 08:28:00
# 74        48.7                        Planned Extubation   48 days 17:43:00
# 75        55.4                        Planned Extubation    2 days 19:43:00
# 76        55.4                        Planned Extubation    4 days 15:05:00
# 77        48.7  Unplanned Extuabtion (patient-initiated)   17 days 06:40:00
# 78        48.7                        Planned Extubation   23 days 15:55:00
# 79        55.4                        Planned Extubation  -1 days +14:53:00
# 80        55.4                        Planned Extubation    1 days 10:15:00
# 81        48.7  Unplanned Extuabtion (patient-initiated)   14 days 01:50:00
# 82        48.7                        Planned Extubation   20 days 11:05:00
# 83        55.4                        Planned Extubation -12 days +14:45:00
# 84        55.4                        Planned Extubation -10 days +10:07:00
# 85        48.7  Unplanned Extuabtion (patient-initiated)    3 days 01:42:00
# 86        48.7                        Planned Extubation    9 days 10:57:00
# 87        55.4                        Planned Extubation -15 days +08:05:00
# 88        55.4                        Planned Extubation -13 days +03:27:00
# 89        48.7  Unplanned Extuabtion (patient-initiated)  -1 days +19:02:00
# 90        48.7                        Planned Extubation    6 days 04:17:00
#
#               dischtime deathtime
# 71  2118-07-16 12:15:00       NaN
# 72  2118-07-16 12:15:00       NaN
# 73  2118-07-16 12:15:00       NaN
# 74  2118-07-16 12:15:00       NaN
# 75  2118-07-16 12:15:00       NaN
# 76  2118-07-16 12:15:00       NaN
# 77  2118-07-16 12:15:00       NaN
# 78  2118-07-16 12:15:00       NaN
# 79  2118-07-16 12:15:00       NaN
# 80  2118-07-16 12:15:00       NaN
# 81  2118-07-16 12:15:00       NaN
# 82  2118-07-16 12:15:00       NaN
# 83  2118-07-16 12:15:00       NaN
# 84  2118-07-16 12:15:00       NaN
# 85  2118-07-16 12:15:00       NaN
# 86  2118-07-16 12:15:00       NaN
# 87  2118-07-16 12:15:00       NaN
# 88  2118-07-16 12:15:00       NaN
# 89  2118-07-16 12:15:00       NaN
# 90  2118-07-16 12:15:00       NaN

# %%
pair_logs
# Out:
# ["sub_id:10004401, hadm_id:29988601: intubation/extubation pair: (Timestamp('2144-01-27 19:00:00'), Timestamp('2144-01-30 12:30:00'))",
#  "sub_id:10004401, hadm_id:29988601: intubation/extubation pair: (Timestamp('2144-01-30 13:00:00'), None)",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-05-09 19:02:00'), None)",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-03 20:50:00'), Timestamp('2118-06-06 16:33:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-07 01:40:00'), Timestamp('2118-06-08 11:55:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-18 01:48:00'), Timestamp('2118-06-21 03:30:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-21 08:28:00'), Timestamp('2118-06-27 12:45:00'))",
#  "sub_id:10233597, hadm_id:27468267: intubation/extubation pair: (Timestamp('2187-12-14 20:56:00'), Timestamp('2187-12-18 16:25:00'))",
#  "sub_id:10233597, hadm_id:27468267: intubation/extubation pair: (Timestamp('2187-12-19 03:52:00'), Timestamp('2187-12-23 13:55:00'))",
#  "sub_id:10233597, hadm_id:27468267: intubation/extubation pair: (Timestamp('2187-12-29 06:22:00'), None)",
#  "sub_id:12495515, hadm_id:22064317: intubation/extubation pair: (Timestamp('2155-09-28 22:00:00'), Timestamp('2155-10-02 11:45:00'))",
#  "sub_id:12495515, hadm_id:22064317: intubation/extubation pair: (Timestamp('2155-10-05 06:59:00'), None)",
#  "sub_id:13033327, hadm_id:21093920: intubation/extubation pair: (Timestamp('2146-01-05 17:41:00'), Timestamp('2146-01-11 15:42:00'))",
#  "sub_id:13033327, hadm_id:21093920: intubation/extubation pair: (Timestamp('2146-01-20 15:12:00'), Timestamp('2146-01-23 09:25:00'))",
#  "sub_id:13033327, hadm_id:21093920: intubation/extubation pair: (Timestamp('2146-01-27 05:08:00'), None)",
#  "sub_id:13033327, hadm_id:21093920: intubation/extubation pair: (Timestamp('2146-01-29 10:00:00'), None)",
#  "sub_id:13515178, hadm_id:20762918: intubation/extubation pair: (Timestamp('2154-01-14 11:37:00'), None)",
#  "sub_id:13515178, hadm_id:20762918: intubation/extubation pair: (Timestamp('2154-01-20 16:15:00'), Timestamp('2154-01-26 11:55:00'))",
#  "sub_id:13515178, hadm_id:20762918: intubation/extubation pair: (Timestamp('2154-01-26 12:26:00'), None)",
#  "sub_id:13515178, hadm_id:28966068: intubation/extubation pair: (Timestamp('2154-04-15 21:00:00'), Timestamp('2154-04-17 17:22:00'))",
#  "sub_id:13696494, hadm_id:20396589: intubation/extubation pair: (Timestamp('2194-06-25 21:00:00'), Timestamp('2194-07-11 12:41:00'))",
#  "sub_id:13696494, hadm_id:20396589: intubation/extubation pair: (Timestamp('2194-07-12 04:45:00'), Timestamp('2194-07-18 09:24:00'))",
#  "sub_id:18344437, hadm_id:20800087: intubation/extubation pair: (Timestamp('2170-11-15 09:40:00'), Timestamp('2170-11-17 16:50:00'))",
#  "sub_id:18344437, hadm_id:20800087: intubation/extubation pair: (Timestamp('2170-12-03 01:52:00'), None)",
#  "sub_id:18344437, hadm_id:20800087: intubation/extubation pair: (Timestamp('2170-12-15 03:00:00'), Timestamp('2170-12-18 13:11:00'))",
#  "sub_id:19997367, hadm_id:20617667: intubation/extubation pair: (Timestamp('2126-04-26 20:14:00'), Timestamp('2126-05-02 16:30:00'))",
#  "sub_id:19997367, hadm_id:20617667: intubation/extubation pair: (Timestamp('2126-05-05 18:20:00'), Timestamp('2126-05-08 17:29:00'))"]

# %%
# 전체 데이터로 확인
processed_df_full, pair_logs2, pair_results2, extracted_data2 = process_intubation_data_grouped(intubation_extubation)
pair_logs2
# Out:
# ["sub_id:10004401, hadm_id:29988601: intubation/extubation pair: (Timestamp('2144-01-27 19:00:00'), Timestamp('2144-01-30 12:30:00'))",
#  "sub_id:10004401, hadm_id:29988601: intubation/extubation pair: (Timestamp('2144-01-30 13:00:00'), None)",
#  "sub_id:10020740, hadm_id:23831430: intubation/extubation pair: (Timestamp('2150-03-27 07:44:00'), Timestamp('2150-03-27 16:33:00'))",
#  "sub_id:10020740, hadm_id:23831430: intubation/extubation pair: (Timestamp('2150-03-30 08:20:00'), Timestamp('2150-04-02 01:09:00'))",
#  "sub_id:10024982, hadm_id:25154057: intubation/extubation pair: (Timestamp('2203-10-02 11:00:00'), Timestamp('2203-10-09 14:50:00'))",
#  "sub_id:10027602, hadm_id:28166872: intubation/extubation pair: (Timestamp('2201-11-07 15:00:00'), Timestamp('2201-11-09 12:45:00'))",
#  "sub_id:10032381, hadm_id:20176432: intubation/extubation pair: (Timestamp('2115-07-06 02:15:00'), Timestamp('2115-07-15 11:00:00'))",
#  "sub_id:10032381, hadm_id:20176432: intubation/extubation pair: (Timestamp('2115-07-18 17:00:00'), None)",
#  "sub_id:10039708, hadm_id:28258130: intubation/extubation pair: (Timestamp('2140-02-01 16:30:00'), Timestamp('2140-02-02 17:40:00'))",
#  "sub_id:10039708, hadm_id:28258130: intubation/extubation pair: (Timestamp('2140-02-02 19:03:00'), Timestamp('2140-02-06 11:27:00'))",
#  "sub_id:10079700, hadm_id:24239751: intubation/extubation pair: (Timestamp('2115-09-27 17:23:00'), None)",
#  "sub_id:10079700, hadm_id:24239751: intubation/extubation pair: (Timestamp('2115-10-11 14:05:00'), Timestamp('2115-10-11 15:40:00'))",
#  "sub_id:10085667, hadm_id:27382550: intubation/extubation pair: (Timestamp('2192-12-15 22:30:00'), Timestamp('2192-12-16 11:45:00'))",
#  "sub_id:10090454, hadm_id:29525590: intubation/extubation pair: (Timestamp('2169-02-06 19:00:00'), None)",
#  "sub_id:10090454, hadm_id:29525590: intubation/extubation pair: (Timestamp('2169-02-10 16:22:00'), Timestamp('2169-02-10 21:16:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-05-09 19:02:00'), None)",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-03 20:50:00'), Timestamp('2118-06-06 16:33:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-07 01:40:00'), Timestamp('2118-06-08 11:55:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-18 01:48:00'), Timestamp('2118-06-21 03:30:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-21 08:28:00'), Timestamp('2118-06-27 12:45:00'))",
#  "sub_id:10109956, hadm_id:26022059: intubation/extubation pair: (Timestamp('2184-05-14 04:15:00'), Timestamp('2184-05-22 12:20:00'))",
#  "sub_id:10115397, hadm_id:28605901: intubation/extubation pair: (Timestamp('2133-01-10 11:15:00'), Timestamp('2133-01-16 08:39:00'))",
#  "sub_id:10117273, hadm_id:24446922: intubation/extubation pair: (Timestamp('2184-08-20 08:42:00'), Timestamp('2184-08-20 11:30:00'))",
#  "sub_id:10117273, hadm_id:24446922: intubation/extubation pair: (Timestamp('2184-08-21 17:15:00'), Timestamp('2184-08-26 10:35:00'))",
#  "sub_id:10119017, hadm_id:20229125: intubation/extubation pair: (Timestamp('2159-08-14 06:38:00'), Timestamp('2159-08-18 13:38:00'))",
#  "sub_id:10122589, hadm_id:28594240: intubation/extubation pair: (Timestamp('2180-04-09 08:00:00'), Timestamp('2180-04-10 15:05:00'))",
#  "sub_id:10125047, hadm_id:26680668: intubation/extubation pair: (Timestamp('2180-01-19 00:00:00'), Timestamp('2180-01-20 08:05:00'))",
#  "sub_id:10125047, hadm_id:26680668: intubation/extubation pair: (Timestamp('2180-01-21 13:12:00'), Timestamp('2180-01-24 13:38:00'))",
#  "sub_id:10125047, hadm_id:26680668: intubation/extubation pair: (Timestamp('2180-01-24 15:20:00'), None)",
#  "sub_id:10136619, hadm_id:23362878: intubation/extubation pair: (Timestamp('2141-01-21 07:55:00'), None)",
#  "sub_id:10136619, hadm_id:23362878: intubation/extubation pair: (Timestamp('2141-01-23 04:30:00'), None)",
#  "sub_id:10143030, hadm_id:27543597: intubation/extubation pair: (Timestamp('2180-05-17 01:55:00'), None)",
#  "sub_id:10143030, hadm_id:27543597: intubation/extubation pair: (Timestamp('2180-06-01 13:10:00'), None)",
#  "sub_id:10143030, hadm_id:27543597: intubation/extubation pair: (Timestamp('2180-06-20 18:39:00'), None)",
#  "sub_id:10150335, hadm_id:24113307: intubation/extubation pair: (Timestamp('2144-09-12 04:35:00'), Timestamp('2144-09-12 18:50:00'))",
#  "sub_id:10150335, hadm_id:24113307: intubation/extubation pair: (Timestamp('2144-09-12 19:11:00'), Timestamp('2144-09-15 14:42:00'))",
#  "sub_id:10150335, hadm_id:24113307: intubation/extubation pair: (Timestamp('2144-09-17 01:00:00'), None)",
#  "sub_id:10151556, hadm_id:20815067: intubation/extubation pair: (Timestamp('2184-02-14 16:19:00'), None)",
#  "sub_id:10151556, hadm_id:20815067: intubation/extubation pair: (Timestamp('2184-03-21 00:25:00'), None)",
#  "sub_id:10160622, hadm_id:28663041: intubation/extubation pair: (Timestamp('2180-05-25 11:17:00'), Timestamp('2180-05-31 18:30:00'))",
#  "sub_id:10160622, hadm_id:28663041: intubation/extubation pair: (Timestamp('2180-06-02 10:55:00'), Timestamp('2180-06-15 14:59:00'))",
#  "sub_id:10163709, hadm_id:29550274: intubation/extubation pair: (Timestamp('2148-03-23 01:44:00'), Timestamp('2148-03-23 11:47:00'))",
#  "sub_id:10163709, hadm_id:29550274: intubation/extubation pair: (Timestamp('2148-03-23 15:08:00'), Timestamp('2148-03-25 14:51:00'))",
#  "sub_id:10173670, hadm_id:21801929: intubation/extubation pair: (Timestamp('2125-02-02 13:30:00'), Timestamp('2125-02-08 12:30:00'))",
#  "sub_id:10179383, hadm_id:20170028: intubation/extubation pair: (Timestamp('2183-08-11 03:00:00'), Timestamp('2183-08-11 16:27:00'))",
#  "sub_id:10179383, hadm_id:20170028: intubation/extubation pair: (Timestamp('2183-08-13 00:05:00'), Timestamp('2183-08-17 13:59:00'))",
#  "sub_id:10185829, hadm_id:22742058: intubation/extubation pair: (Timestamp('2157-09-06 08:16:00'), Timestamp('2157-09-08 12:04:00'))",
#  "sub_id:10186500, hadm_id:27961292: intubation/extubation pair: (Timestamp('2181-05-06 17:00:00'), Timestamp('2181-05-07 17:00:00'))",
#  "sub_id:10186500, hadm_id:27961292: intubation/extubation pair: (Timestamp('2181-05-22 02:00:00'), None)",
#  "sub_id:10193074, hadm_id:22392305: intubation/extubation pair: (Timestamp('2121-02-16 15:00:00'), Timestamp('2121-02-19 14:00:00'))",
#  "sub_id:10203444, hadm_id:25550068: intubation/extubation pair: (Timestamp('2134-08-22 14:22:00'), Timestamp('2134-08-24 13:30:00'))",
#  "sub_id:10229323, hadm_id:25045444: intubation/extubation pair: (Timestamp('2164-12-25 13:38:00'), Timestamp('2165-01-02 10:01:00'))",
#  "sub_id:10229323, hadm_id:25045444: intubation/extubation pair: (Timestamp('2165-01-02 10:15:00'), None)",
#  "sub_id:10233088, hadm_id:24630582: intubation/extubation pair: (Timestamp('2161-10-09 00:00:00'), Timestamp('2161-10-14 14:30:00'))",
#  "sub_id:10233088, hadm_id:24630582: intubation/extubation pair: (Timestamp('2161-10-15 08:58:00'), Timestamp('2161-10-18 18:33:00'))",
#  "sub_id:10233597, hadm_id:27468267: intubation/extubation pair: (Timestamp('2187-12-14 20:56:00'), Timestamp('2187-12-18 16:25:00'))",
#  "sub_id:10233597, hadm_id:27468267: intubation/extubation pair: (Timestamp('2187-12-19 03:52:00'), Timestamp('2187-12-23 13:55:00'))",
#  "sub_id:10233597, hadm_id:27468267: intubation/extubation pair: (Timestamp('2187-12-29 06:22:00'), None)",
#  "sub_id:10236222, hadm_id:23831668: intubation/extubation pair: (Timestamp('2200-01-01 22:26:00'), Timestamp('2200-01-03 16:10:00'))",
#  "sub_id:10244046, hadm_id:27440644: intubation/extubation pair: (Timestamp('2157-01-07 08:30:00'), Timestamp('2157-01-08 08:30:00'))",
#  "sub_id:10251182, hadm_id:29312838: intubation/extubation pair: (Timestamp('2155-05-10 14:50:00'), Timestamp('2155-05-11 04:52:00'))",
#  "sub_id:10254774, hadm_id:21124863: intubation/extubation pair: (Timestamp('2119-02-22 17:00:00'), Timestamp('2119-03-02 08:36:00'))",
#  "sub_id:10258162, hadm_id:28433140: intubation/extubation pair: (Timestamp('2150-09-19 01:00:00'), Timestamp('2150-09-20 10:15:00'))",
#  "sub_id:10258162, hadm_id:28433140: intubation/extubation pair: (Timestamp('2150-09-28 08:00:00'), None)",
#  "sub_id:10258162, hadm_id:28433140: intubation/extubation pair: (Timestamp('2150-10-01 00:20:00'), Timestamp('2150-10-01 00:22:00'))",
#  "sub_id:10262096, hadm_id:23639696: intubation/extubation pair: (Timestamp('2167-03-10 18:17:00'), None)",
#  "sub_id:10262096, hadm_id:23639696: intubation/extubation pair: (Timestamp('2167-03-11 20:00:00'), Timestamp('2167-03-13 21:05:00'))",
#  "sub_id:10267084, hadm_id:28933075: intubation/extubation pair: (Timestamp('2147-12-01 11:15:00'), None)",
#  "sub_id:10267084, hadm_id:28933075: intubation/extubation pair: (Timestamp('2147-12-01 19:57:00'), Timestamp('2147-12-01 23:40:00'))",
#  "sub_id:10268877, hadm_id:25238883: intubation/extubation pair: (Timestamp('2181-03-07 09:06:00'), Timestamp('2181-03-22 19:45:00'))",
#  "sub_id:10280054, hadm_id:20177063: intubation/extubation pair: (Timestamp('2143-04-29 11:43:00'), Timestamp('2143-05-01 10:42:00'))",
#  "sub_id:10295020, hadm_id:24995523: intubation/extubation pair: (Timestamp('2147-06-08 23:05:00'), None)",
#  "sub_id:10295020, hadm_id:24995523: intubation/extubation pair: (Timestamp('2147-06-10 17:41:00'), Timestamp('2147-06-14 10:45:00'))",
#  "sub_id:10302157, hadm_id:24530152: intubation/extubation pair: (Timestamp('2189-03-21 13:00:00'), Timestamp('2189-03-28 16:52:00'))",
#  "sub_id:10304606, hadm_id:25532105: intubation/extubation pair: (Timestamp('2160-10-26 14:20:00'), Timestamp('2160-10-28 16:37:00'))",
#  "sub_id:10304606, hadm_id:25532105: intubation/extubation pair: (Timestamp('2160-10-31 16:25:00'), Timestamp('2160-11-08 15:00:00'))",
#  "sub_id:10304606, hadm_id:25532105: intubation/extubation pair: (Timestamp('2160-11-09 20:45:00'), None)",
#  "sub_id:10308297, hadm_id:27825244: intubation/extubation pair: (Timestamp('2189-01-24 16:57:00'), Timestamp('2189-01-25 02:11:00'))",
#  "sub_id:10308342, hadm_id:24888258: intubation/extubation pair: (Timestamp('2162-11-20 23:20:00'), Timestamp('2162-11-25 12:19:00'))",
#  "sub_id:10309969, hadm_id:23107749: intubation/extubation pair: (Timestamp('2182-01-21 10:24:00'), Timestamp('2182-02-06 10:59:00'))",
#  "sub_id:10309969, hadm_id:23107749: intubation/extubation pair: (Timestamp('2182-02-06 12:05:00'), None)",
#  "sub_id:10311956, hadm_id:25628815: intubation/extubation pair: (Timestamp('2123-03-12 15:23:00'), Timestamp('2123-03-18 08:10:00'))",
#  "sub_id:10321446, hadm_id:26487233: intubation/extubation pair: (Timestamp('2179-08-04 13:07:00'), Timestamp('2179-08-05 11:10:00'))",
#  "sub_id:10321569, hadm_id:24124902: intubation/extubation pair: (Timestamp('2143-12-15 17:00:00'), Timestamp('2143-12-16 15:17:00'))",
#  "sub_id:10321933, hadm_id:29792275: intubation/extubation pair: (Timestamp('2119-09-09 16:50:00'), Timestamp('2119-09-11 09:28:00'))",
#  "sub_id:10332371, hadm_id:29819591: intubation/extubation pair: (Timestamp('2149-03-06 11:00:00'), Timestamp('2149-03-13 06:45:00'))",
#  "sub_id:10332371, hadm_id:29819591: intubation/extubation pair: (Timestamp('2149-03-13 07:00:00'), Timestamp('2149-03-21 12:04:00'))",
#  "sub_id:10342123, hadm_id:23603937: intubation/extubation pair: (Timestamp('2163-10-26 02:15:00'), Timestamp('2163-10-29 12:24:00'))",
#  "sub_id:10347400, hadm_id:29775800: intubation/extubation pair: (Timestamp('2161-05-20 01:35:00'), Timestamp('2161-05-23 15:30:00'))",
#  "sub_id:10347400, hadm_id:29775800: intubation/extubation pair: (Timestamp('2161-05-27 05:40:00'), Timestamp('2161-05-27 10:55:00'))",
#  "sub_id:10353094, hadm_id:24688773: intubation/extubation pair: (Timestamp('2188-10-18 14:10:00'), Timestamp('2188-10-20 09:05:00'))",
#  "sub_id:10353094, hadm_id:24688773: intubation/extubation pair: (Timestamp('2188-10-22 16:41:00'), None)",
#  "sub_id:10354450, hadm_id:28518599: intubation/extubation pair: (Timestamp('2163-08-29 03:30:00'), Timestamp('2163-09-02 23:10:00'))",
#  "sub_id:10354450, hadm_id:28518599: intubation/extubation pair: (Timestamp('2163-09-02 23:40:00'), Timestamp('2163-09-11 10:16:00'))",
#  "sub_id:10354450, hadm_id:28518599: intubation/extubation pair: (Timestamp('2163-09-11 11:34:00'), None)",
#  "sub_id:10355745, hadm_id:24924037: intubation/extubation pair: (Timestamp('2177-10-22 17:42:00'), Timestamp('2177-10-26 09:44:00'))",
#  "sub_id:10355745, hadm_id:24924037: intubation/extubation pair: (Timestamp('2177-10-26 11:00:00'), Timestamp('2177-11-01 15:58:00'))",
#  "sub_id:10355745, hadm_id:24924037: intubation/extubation pair: (Timestamp('2177-11-01 17:31:00'), None)",
#  "sub_id:10357284, hadm_id:24550737: intubation/extubation pair: (Timestamp('2133-10-06 10:50:00'), Timestamp('2133-10-08 09:00:00'))",
#  "sub_id:10357863, hadm_id:25031044: intubation/extubation pair: (Timestamp('2118-03-15 08:30:00'), Timestamp('2118-03-18 07:53:00'))",
#  "sub_id:10370642, hadm_id:28038797: intubation/extubation pair: (Timestamp('2128-12-19 05:00:00'), Timestamp('2128-12-28 12:14:00'))",
#  "sub_id:10370642, hadm_id:28038797: intubation/extubation pair: (Timestamp('2128-12-28 21:35:00'), Timestamp('2129-01-01 13:17:00'))",
#  "sub_id:10378026, hadm_id:24981696: intubation/extubation pair: (Timestamp('2129-07-26 17:00:00'), Timestamp('2129-07-28 14:00:00'))",
#  "sub_id:10388400, hadm_id:23303089: intubation/extubation pair: (Timestamp('2137-06-21 03:30:00'), Timestamp('2137-06-22 11:10:00'))",
#  "sub_id:10388400, hadm_id:23303089: intubation/extubation pair: (Timestamp('2137-07-15 11:10:00'), Timestamp('2137-07-20 12:03:00'))",
#  "sub_id:10390732, hadm_id:26272149: intubation/extubation pair: (Timestamp('2143-07-31 03:25:00'), Timestamp('2143-08-07 09:48:00'))",
#  "sub_id:10390732, hadm_id:26272149: intubation/extubation pair: (Timestamp('2143-08-09 11:22:00'), Timestamp('2143-08-13 14:30:00'))",
#  "sub_id:10400895, hadm_id:21029062: intubation/extubation pair: (Timestamp('2125-05-11 14:20:00'), Timestamp('2125-05-12 12:49:00'))",
#  "sub_id:10400895, hadm_id:21029062: intubation/extubation pair: (Timestamp('2125-05-12 18:38:00'), Timestamp('2125-05-14 08:09:00'))",
#  "sub_id:10404109, hadm_id:29867820: intubation/extubation pair: (Timestamp('2146-12-28 10:00:00'), Timestamp('2146-12-30 13:07:00'))",
#  "sub_id:10404109, hadm_id:29867820: intubation/extubation pair: (Timestamp('2146-12-30 15:00:00'), Timestamp('2146-12-31 13:00:00'))",
#  "sub_id:10407740, hadm_id:23073830: intubation/extubation pair: (Timestamp('2165-01-23 10:51:00'), Timestamp('2165-01-23 15:49:00'))",
#  "sub_id:10423466, hadm_id:24868706: intubation/extubation pair: (Timestamp('2133-07-03 17:00:00'), Timestamp('2133-07-09 18:00:00'))",
#  "sub_id:10428240, hadm_id:22917399: intubation/extubation pair: (Timestamp('2158-04-12 15:00:00'), Timestamp('2158-04-16 09:50:00'))",
#  "sub_id:10438089, hadm_id:28261508: intubation/extubation pair: (Timestamp('2120-02-16 09:15:00'), Timestamp('2120-02-22 15:50:00'))",
#  "sub_id:10438089, hadm_id:28261508: intubation/extubation pair: (Timestamp('2120-02-28 19:45:00'), Timestamp('2120-03-11 09:14:00'))",
#  "sub_id:10440245, hadm_id:23174788: intubation/extubation pair: (Timestamp('2162-08-17 22:30:00'), Timestamp('2162-08-20 15:43:00'))",
#  "sub_id:10440899, hadm_id:26609648: intubation/extubation pair: (Timestamp('2145-03-30 08:40:00'), Timestamp('2145-04-05 11:01:00'))",
#  "sub_id:10440899, hadm_id:26609648: intubation/extubation pair: (Timestamp('2145-04-06 20:25:00'), None)",
#  "sub_id:10445331, hadm_id:24253259: intubation/extubation pair: (Timestamp('2160-03-06 04:12:00'), Timestamp('2160-03-08 13:55:00'))",
#  "sub_id:10452075, hadm_id:28206315: intubation/extubation pair: (Timestamp('2111-04-06 16:53:00'), Timestamp('2111-04-06 20:49:00'))",
#  "sub_id:10452075, hadm_id:28206315: intubation/extubation pair: (Timestamp('2111-04-07 06:32:00'), Timestamp('2111-04-08 09:10:00'))",
#  "sub_id:10454567, hadm_id:23632536: intubation/extubation pair: (Timestamp('2153-02-17 11:57:00'), Timestamp('2153-02-20 12:15:00'))",
#  "sub_id:10454567, hadm_id:23632536: intubation/extubation pair: (Timestamp('2153-02-20 15:20:00'), None)",
#  "sub_id:10455694, hadm_id:29811294: intubation/extubation pair: (Timestamp('2162-04-02 14:30:00'), Timestamp('2162-04-06 15:30:00'))",
#  "sub_id:10455694, hadm_id:29811294: intubation/extubation pair: (Timestamp('2162-04-06 17:16:00'), None)",
#  "sub_id:10456513, hadm_id:24713298: intubation/extubation pair: (Timestamp('2120-03-19 15:00:00'), Timestamp('2120-03-23 10:45:00'))",
#  "sub_id:10471192, hadm_id:28299148: intubation/extubation pair: (Timestamp('2118-10-19 00:30:00'), Timestamp('2118-10-24 09:35:00'))",
#  "sub_id:10471192, hadm_id:28299148: intubation/extubation pair: (Timestamp('2118-10-27 17:45:00'), None)",
#  "sub_id:10472107, hadm_id:24126677: intubation/extubation pair: (Timestamp('2179-06-22 00:27:00'), Timestamp('2179-06-24 18:35:00'))",
#  "sub_id:10472107, hadm_id:24126677: intubation/extubation pair: (Timestamp('2179-06-24 19:30:00'), Timestamp('2179-07-14 17:31:00'))",
#  "sub_id:10480346, hadm_id:20489735: intubation/extubation pair: (Timestamp('2188-07-07 15:53:00'), Timestamp('2188-07-08 08:37:00'))",
#  "sub_id:10486056, hadm_id:26777411: intubation/extubation pair: (Timestamp('2173-07-05 07:40:00'), Timestamp('2173-07-07 14:40:00'))",
#  "sub_id:10488031, hadm_id:25655870: intubation/extubation pair: (Timestamp('2154-12-07 20:10:00'), Timestamp('2154-12-10 13:30:00'))",
#  "sub_id:10501162, hadm_id:24511516: intubation/extubation pair: (Timestamp('2191-06-23 19:16:00'), Timestamp('2191-07-07 14:00:00'))",
#  "sub_id:10510839, hadm_id:20853488: intubation/extubation pair: (Timestamp('2125-07-14 21:06:00'), Timestamp('2125-07-16 12:10:00'))",
#  "sub_id:10515638, hadm_id:24976128: intubation/extubation pair: (Timestamp('2149-08-30 13:19:00'), Timestamp('2149-09-01 11:43:00'))",
#  "sub_id:10515638, hadm_id:24976128: intubation/extubation pair: (Timestamp('2149-09-01 20:22:00'), Timestamp('2149-09-03 15:50:00'))",
#  "sub_id:10527074, hadm_id:27892723: intubation/extubation pair: (Timestamp('2171-02-11 16:37:00'), None)",
#  "sub_id:10527074, hadm_id:27892723: intubation/extubation pair: (Timestamp('2171-02-14 16:21:00'), None)",
#  "sub_id:10528589, hadm_id:22414279: intubation/extubation pair: (Timestamp('2122-10-27 06:28:00'), Timestamp('2122-10-30 09:55:00'))",
#  "sub_id:10533034, hadm_id:20901025: intubation/extubation pair: (Timestamp('2141-11-17 22:15:00'), Timestamp('2141-11-29 14:31:00'))",
#  "sub_id:10533034, hadm_id:20901025: intubation/extubation pair: (Timestamp('2141-12-02 09:06:00'), Timestamp('2141-12-15 14:30:00'))",
#  "sub_id:10545747, hadm_id:25020409: intubation/extubation pair: (Timestamp('2152-09-21 10:00:00'), Timestamp('2152-09-27 14:42:00'))",
#  "sub_id:10545967, hadm_id:27498545: intubation/extubation pair: (Timestamp('2186-05-13 18:38:00'), Timestamp('2186-05-13 20:32:00'))",
#  "sub_id:10554112, hadm_id:20318099: intubation/extubation pair: (Timestamp('2152-06-21 19:13:00'), Timestamp('2152-06-29 13:18:00'))",
#  "sub_id:10556002, hadm_id:29077178: intubation/extubation pair: (Timestamp('2160-09-20 09:00:00'), Timestamp('2160-09-21 21:18:00'))",
#  "sub_id:10556002, hadm_id:29077178: intubation/extubation pair: (Timestamp('2160-09-24 10:00:00'), None)",
#  "sub_id:10556676, hadm_id:25577156: intubation/extubation pair: (Timestamp('2163-11-04 23:30:00'), Timestamp('2163-11-12 11:50:00'))",
#  "sub_id:10556676, hadm_id:25577156: intubation/extubation pair: (Timestamp('2163-12-07 02:00:00'), None)",
#  "sub_id:10562205, hadm_id:20149612: intubation/extubation pair: (Timestamp('2149-04-30 09:30:00'), None)",
#  "sub_id:10562205, hadm_id:20149612: intubation/extubation pair: (Timestamp('2149-05-06 04:34:00'), Timestamp('2149-05-07 09:10:00'))",
#  "sub_id:10564844, hadm_id:22721259: intubation/extubation pair: (Timestamp('2137-07-25 18:15:00'), Timestamp('2137-07-26 15:28:00'))",
#  "sub_id:10566618, hadm_id:24100858: intubation/extubation pair: (Timestamp('2112-07-31 06:05:00'), None)",
#  "sub_id:10566618, hadm_id:24100858: intubation/extubation pair: (Timestamp('2112-08-04 15:16:00'), Timestamp('2112-08-05 08:34:00'))",
#  "sub_id:10570615, hadm_id:28618207: intubation/extubation pair: (Timestamp('2187-09-15 21:00:00'), Timestamp('2187-09-20 08:22:00'))",
#  "sub_id:10570615, hadm_id:28618207: intubation/extubation pair: (Timestamp('2187-09-28 10:30:00'), Timestamp('2187-09-28 17:00:00'))",
#  "sub_id:10597337, hadm_id:28427709: intubation/extubation pair: (Timestamp('2163-09-21 21:00:00'), Timestamp('2163-09-27 01:30:00'))",
#  "sub_id:10597337, hadm_id:28427709: intubation/extubation pair: (Timestamp('2163-10-03 01:20:00'), Timestamp('2163-10-10 11:39:00'))",
#  "sub_id:10625497, hadm_id:26227206: intubation/extubation pair: (Timestamp('2180-06-08 05:45:00'), Timestamp('2180-06-11 13:29:00'))",
#  "sub_id:10625497, hadm_id:26227206: intubation/extubation pair: (Timestamp('2180-06-14 11:00:00'), Timestamp('2180-06-17 09:52:00'))",
#  "sub_id:10630310, hadm_id:29121601: intubation/extubation pair: (Timestamp('2168-12-22 12:45:00'), Timestamp('2168-12-30 10:40:00'))",
#  "sub_id:10630310, hadm_id:29121601: intubation/extubation pair: (Timestamp('2168-12-30 10:47:00'), None)",
#  "sub_id:10641795, hadm_id:22739609: intubation/extubation pair: (Timestamp('2146-04-28 08:20:00'), Timestamp('2146-04-29 12:05:00'))",
#  "sub_id:10641795, hadm_id:22739609: intubation/extubation pair: (Timestamp('2146-04-29 12:35:00'), Timestamp('2146-05-06 14:00:00'))",
#  "sub_id:10641937, hadm_id:22804676: intubation/extubation pair: (Timestamp('2123-12-11 18:00:00'), Timestamp('2123-12-16 15:30:00'))",
#  "sub_id:10641937, hadm_id:22804676: intubation/extubation pair: (Timestamp('2124-01-15 15:54:00'), None)",
#  "sub_id:10650537, hadm_id:23831277: intubation/extubation pair: (Timestamp('2158-03-10 00:22:00'), Timestamp('2158-03-10 12:15:00'))",
#  "sub_id:10656173, hadm_id:25778760: intubation/extubation pair: (Timestamp('2177-09-17 14:47:00'), None)",
#  "sub_id:10656173, hadm_id:25778760: intubation/extubation pair: (Timestamp('2177-09-20 10:42:00'), None)",
#  "sub_id:10663695, hadm_id:22455973: intubation/extubation pair: (Timestamp('2139-11-13 01:45:00'), Timestamp('2139-11-25 12:33:00'))",
#  "sub_id:10667797, hadm_id:28092930: intubation/extubation pair: (Timestamp('2154-06-02 15:49:00'), Timestamp('2154-06-14 12:40:00'))",
#  "sub_id:10667797, hadm_id:28092930: intubation/extubation pair: (Timestamp('2154-06-14 17:30:00'), Timestamp('2154-06-14 23:45:00'))",
#  "sub_id:10668585, hadm_id:22652510: intubation/extubation pair: (Timestamp('2146-03-31 14:39:00'), Timestamp('2146-04-04 11:44:00'))",
#  "sub_id:10670236, hadm_id:20938672: intubation/extubation pair: (Timestamp('2185-07-27 14:56:00'), Timestamp('2185-07-31 12:25:00'))",
#  "sub_id:10670818, hadm_id:21108661: intubation/extubation pair: (Timestamp('2153-04-30 11:45:00'), Timestamp('2153-04-30 21:25:00'))",
#  "sub_id:10670818, hadm_id:21108661: intubation/extubation pair: (Timestamp('2153-05-26 11:15:00'), Timestamp('2153-07-20 20:31:00'))",
#  "sub_id:10680821, hadm_id:23326088: intubation/extubation pair: (Timestamp('2116-04-25 18:21:00'), Timestamp('2116-04-28 08:40:00'))",
#  "sub_id:10680821, hadm_id:23326088: intubation/extubation pair: (Timestamp('2116-04-29 07:30:00'), Timestamp('2116-04-30 18:00:00'))",
#  "sub_id:10684286, hadm_id:27967192: intubation/extubation pair: (Timestamp('2173-11-05 04:57:00'), Timestamp('2173-11-08 10:37:00'))",
#  "sub_id:10684286, hadm_id:27967192: intubation/extubation pair: (Timestamp('2173-11-10 05:57:00'), Timestamp('2173-11-16 11:11:00'))",
#  "sub_id:10684286, hadm_id:27967192: intubation/extubation pair: (Timestamp('2173-11-21 22:30:00'), Timestamp('2173-11-22 12:53:00'))",
#  "sub_id:10692563, hadm_id:28888564: intubation/extubation pair: (Timestamp('2193-09-10 14:50:00'), Timestamp('2193-09-12 10:20:00'))",
#  "sub_id:10698299, hadm_id:24429289: intubation/extubation pair: (Timestamp('2174-11-02 21:08:00'), Timestamp('2174-11-13 14:34:00'))",
#  "sub_id:10701573, hadm_id:24245464: intubation/extubation pair: (Timestamp('2180-08-12 21:40:00'), Timestamp('2180-08-13 10:15:00'))",
#  "sub_id:10701573, hadm_id:24245464: intubation/extubation pair: (Timestamp('2180-08-14 14:24:00'), Timestamp('2180-08-15 18:55:00'))",
#  "sub_id:10710573, hadm_id:29923776: intubation/extubation pair: (Timestamp('2114-04-19 11:30:00'), Timestamp('2114-04-23 09:26:00'))",
#  "sub_id:10712217, hadm_id:21561906: intubation/extubation pair: (Timestamp('2177-11-17 14:31:00'), None)",
#  "sub_id:10712217, hadm_id:21561906: intubation/extubation pair: (Timestamp('2177-11-22 00:51:00'), Timestamp('2177-11-23 02:58:00'))",
#  "sub_id:10712217, hadm_id:21561906: intubation/extubation pair: (Timestamp('2177-11-23 04:20:00'), Timestamp('2177-11-26 01:50:00'))",
#  "sub_id:10712217, hadm_id:21561906: intubation/extubation pair: (Timestamp('2177-11-26 02:15:00'), None)",
#  "sub_id:10714685, hadm_id:22120092: intubation/extubation pair: (Timestamp('2146-06-26 22:20:00'), None)",
#  "sub_id:10714685, hadm_id:22120092: intubation/extubation pair: (Timestamp('2146-06-28 08:00:00'), None)",
#  "sub_id:10715209, hadm_id:27459912: intubation/extubation pair: (Timestamp('2157-08-28 14:11:00'), Timestamp('2157-08-29 11:10:00'))",
#  "sub_id:10724278, hadm_id:20624205: intubation/extubation pair: (Timestamp('2116-02-20 12:39:00'), Timestamp('2116-03-06 11:56:00'))",
#  "sub_id:10728002, hadm_id:28666836: intubation/extubation pair: (Timestamp('2182-06-22 02:45:00'), Timestamp('2182-06-24 08:15:00'))",
#  "sub_id:10728002, hadm_id:28666836: intubation/extubation pair: (Timestamp('2182-07-13 06:38:00'), Timestamp('2182-07-15 11:40:00'))",
#  "sub_id:10758974, hadm_id:21950450: intubation/extubation pair: (Timestamp('2145-02-11 11:35:00'), None)",
#  "sub_id:10758974, hadm_id:21950450: intubation/extubation pair: (Timestamp('2145-02-16 09:09:00'), Timestamp('2145-02-19 08:54:00'))",
#  "sub_id:10759132, hadm_id:28549219: intubation/extubation pair: (Timestamp('2144-05-15 15:19:00'), Timestamp('2144-05-17 12:38:00'))",
#  "sub_id:10759132, hadm_id:28549219: intubation/extubation pair: (Timestamp('2144-05-17 17:15:00'), Timestamp('2144-05-27 12:00:00'))",
#  "sub_id:10760672, hadm_id:29128660: intubation/extubation pair: (Timestamp('2129-06-17 12:49:00'), Timestamp('2129-06-24 21:40:00'))",
#  "sub_id:10771068, hadm_id:21520079: intubation/extubation pair: (Timestamp('2184-10-03 19:50:00'), Timestamp('2184-10-04 13:12:00'))",
#  "sub_id:10774669, hadm_id:28120845: intubation/extubation pair: (Timestamp('2156-04-19 20:00:00'), Timestamp('2156-04-22 09:45:00'))",
#  "sub_id:10780878, hadm_id:24037790: intubation/extubation pair: (Timestamp('2114-11-12 18:41:00'), Timestamp('2114-11-12 23:55:00'))",
#  "sub_id:10780878, hadm_id:24037790: intubation/extubation pair: (Timestamp('2114-11-19 11:26:00'), Timestamp('2114-11-19 15:42:00'))",
#  "sub_id:10785608, hadm_id:28290632: intubation/extubation pair: (Timestamp('2146-05-16 11:50:00'), Timestamp('2146-05-21 08:28:00'))",
#  "sub_id:10785700, hadm_id:29123449: intubation/extubation pair: (Timestamp('2128-03-06 04:45:00'), Timestamp('2128-03-07 16:00:00'))",
#  "sub_id:10790860, hadm_id:29350861: intubation/extubation pair: (Timestamp('2198-07-18 17:27:00'), None)",
#  "sub_id:10790860, hadm_id:29350861: intubation/extubation pair: (Timestamp('2198-08-12 11:56:00'), None)",
#  "sub_id:10795507, hadm_id:25606775: intubation/extubation pair: (Timestamp('2197-01-04 20:00:00'), Timestamp('2197-01-08 17:45:00'))",
#  "sub_id:10806305, hadm_id:22042362: intubation/extubation pair: (Timestamp('2163-11-20 23:21:00'), Timestamp('2163-12-01 11:42:00'))",
#  "sub_id:10806849, hadm_id:21477011: intubation/extubation pair: (Timestamp('2119-07-13 19:03:00'), Timestamp('2119-07-18 14:54:00'))",
#  "sub_id:10806849, hadm_id:21477011: intubation/extubation pair: (Timestamp('2119-07-19 18:00:00'), Timestamp('2119-07-25 14:36:00'))",
#  "sub_id:10806973, hadm_id:20436523: intubation/extubation pair: (Timestamp('2134-11-05 05:55:00'), Timestamp('2134-11-08 03:15:00'))",
#  "sub_id:10809326, hadm_id:22350919: intubation/extubation pair: (Timestamp('2115-09-14 15:01:00'), Timestamp('2115-09-18 11:25:00'))",
#  "sub_id:10809326, hadm_id:22350919: intubation/extubation pair: (Timestamp('2115-09-18 12:38:00'), None)",
#  "sub_id:10812824, hadm_id:27693546: intubation/extubation pair: (Timestamp('2134-08-26 14:45:00'), Timestamp('2134-09-02 12:11:00'))",
#  "sub_id:10813665, hadm_id:26936609: intubation/extubation pair: (Timestamp('2174-08-15 09:16:00'), Timestamp('2174-08-18 19:33:00'))",
#  "sub_id:10814691, hadm_id:20482625: intubation/extubation pair: (Timestamp('2138-02-06 16:25:00'), Timestamp('2138-02-10 16:50:00'))",
#  "sub_id:10826174, hadm_id:21175945: intubation/extubation pair: (Timestamp('2118-01-09 02:26:00'), Timestamp('2118-01-13 15:35:00'))",
#  "sub_id:10828063, hadm_id:23207427: intubation/extubation pair: (Timestamp('2149-04-12 12:28:00'), Timestamp('2149-04-13 14:30:00'))",
#  "sub_id:10828063, hadm_id:23207427: intubation/extubation pair: (Timestamp('2149-04-18 16:40:00'), Timestamp('2149-04-26 12:10:00'))",
#  "sub_id:10833812, hadm_id:29657171: intubation/extubation pair: (Timestamp('2171-04-06 21:45:00'), Timestamp('2171-04-14 11:00:00'))",
#  "sub_id:10834132, hadm_id:23607054: intubation/extubation pair: (Timestamp('2178-07-03 16:30:00'), Timestamp('2178-07-05 08:05:00'))",
#  "sub_id:10839217, hadm_id:23110547: intubation/extubation pair: (Timestamp('2160-11-12 16:30:00'), Timestamp('2160-11-16 10:51:00'))",
#  "sub_id:10839217, hadm_id:23110547: intubation/extubation pair: (Timestamp('2160-11-23 12:55:00'), Timestamp('2160-12-02 10:49:00'))",
#  "sub_id:10839217, hadm_id:23110547: intubation/extubation pair: (Timestamp('2160-12-08 01:00:00'), Timestamp('2160-12-11 12:15:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-02-15 09:00:00'), Timestamp('2133-02-18 10:10:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-02-21 09:55:00'), Timestamp('2133-02-21 15:21:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-02-24 12:15:00'), Timestamp('2133-02-25 12:40:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-03-04 05:40:00'), Timestamp('2133-03-06 18:20:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-03-07 05:15:00'), None)",
#  "sub_id:10850815, hadm_id:29529191: intubation/extubation pair: (Timestamp('2143-08-02 18:50:00'), Timestamp('2143-08-08 08:10:00'))",
#  "sub_id:10850815, hadm_id:29529191: intubation/extubation pair: (Timestamp('2143-08-10 13:56:00'), Timestamp('2143-08-12 15:15:00'))",
#  "sub_id:10853896, hadm_id:23383004: intubation/extubation pair: (Timestamp('2176-08-30 16:15:00'), Timestamp('2176-09-01 08:46:00'))",
#  "sub_id:10865504, hadm_id:20772091: intubation/extubation pair: (Timestamp('2178-12-10 01:00:00'), Timestamp('2178-12-14 12:24:00'))",
#  "sub_id:10865504, hadm_id:20772091: intubation/extubation pair: (Timestamp('2179-02-13 15:25:00'), Timestamp('2179-02-24 11:09:00'))",
#  "sub_id:10867981, hadm_id:20831772: intubation/extubation pair: (Timestamp('2168-09-07 14:10:00'), Timestamp('2168-09-10 16:30:00'))",
#  "sub_id:10874066, hadm_id:29765862: intubation/extubation pair: (Timestamp('2156-12-28 23:54:00'), Timestamp('2157-01-01 11:37:00'))",
#  "sub_id:10874066, hadm_id:29765862: intubation/extubation pair: (Timestamp('2157-01-05 03:40:00'), None)",
#  "sub_id:10878238, hadm_id:26780052: intubation/extubation pair: (Timestamp('2143-05-11 22:30:00'), Timestamp('2143-05-12 09:18:00'))",
#  "sub_id:10886970, hadm_id:26397173: intubation/extubation pair: (Timestamp('2144-07-25 05:30:00'), Timestamp('2144-07-25 09:30:00'))",
#  "sub_id:10886970, hadm_id:26397173: intubation/extubation pair: (Timestamp('2144-07-25 09:31:00'), Timestamp('2144-07-25 12:45:00'))",
#  "sub_id:10887901, hadm_id:28942534: intubation/extubation pair: (Timestamp('2171-09-29 19:00:00'), Timestamp('2171-10-05 13:20:00'))",
#  "sub_id:10900129, hadm_id:22036881: intubation/extubation pair: (Timestamp('2140-09-06 02:45:00'), Timestamp('2140-09-06 09:48:00'))",
#  "sub_id:10900129, hadm_id:22036881: intubation/extubation pair: (Timestamp('2140-09-13 00:00:00'), Timestamp('2140-09-21 17:50:00'))",
#  "sub_id:10900387, hadm_id:28246942: intubation/extubation pair: (Timestamp('2149-03-14 08:35:00'), Timestamp('2149-03-16 15:03:00'))",
#  "sub_id:10907695, hadm_id:28491009: intubation/extubation pair: (Timestamp('2151-11-15 15:24:00'), Timestamp('2151-11-16 11:09:00'))",
#  "sub_id:10910344, hadm_id:22604063: intubation/extubation pair: (Timestamp('2162-12-27 13:20:00'), Timestamp('2163-01-05 14:56:00'))",
#  "sub_id:10910797, hadm_id:23479816: intubation/extubation pair: (Timestamp('2142-01-13 23:45:00'), Timestamp('2142-01-17 16:00:00'))",
#  "sub_id:10911270, hadm_id:26543072: intubation/extubation pair: (Timestamp('2180-03-11 04:15:00'), None)",
#  "sub_id:10911270, hadm_id:26543072: intubation/extubation pair: (Timestamp('2180-03-14 22:34:00'), Timestamp('2180-03-17 13:05:00'))",
#  "sub_id:10914662, hadm_id:22281276: intubation/extubation pair: (Timestamp('2188-07-25 14:43:00'), Timestamp('2188-07-25 20:10:00'))",
#  "sub_id:10914662, hadm_id:22281276: intubation/extubation pair: (Timestamp('2188-07-26 03:30:00'), Timestamp('2188-07-27 08:56:00'))",
#  "sub_id:10918410, hadm_id:23928677: intubation/extubation pair: (Timestamp('2149-07-02 20:45:00'), Timestamp('2149-07-04 11:55:00'))",
#  "sub_id:10921049, hadm_id:26528195: intubation/extubation pair: (Timestamp('2141-01-06 11:17:00'), Timestamp('2141-01-06 15:06:00'))",
#  "sub_id:10921049, hadm_id:26528195: intubation/extubation pair: (Timestamp('2141-01-08 15:19:00'), Timestamp('2141-01-08 17:40:00'))",
#  "sub_id:10923536, hadm_id:23384208: intubation/extubation pair: (Timestamp('2154-07-09 10:00:00'), None)",
#  "sub_id:10923536, hadm_id:23384208: intubation/extubation pair: (Timestamp('2154-07-10 21:00:00'), Timestamp('2154-07-15 11:00:00'))",
#  "sub_id:10930214, hadm_id:21441177: intubation/extubation pair: (Timestamp('2191-05-20 10:45:00'), Timestamp('2191-05-27 12:16:00'))",
#  "sub_id:10930214, hadm_id:21441177: intubation/extubation pair: (Timestamp('2191-05-27 13:55:00'), None)",
#  "sub_id:10932961, hadm_id:22658799: intubation/extubation pair: (Timestamp('2151-09-30 21:00:00'), Timestamp('2151-10-07 13:53:00'))",
#  "sub_id:10935357, hadm_id:20085117: intubation/extubation pair: (Timestamp('2155-08-24 08:45:00'), Timestamp('2155-08-25 11:44:00'))",
#  "sub_id:10935357, hadm_id:20085117: intubation/extubation pair: (Timestamp('2155-09-08 16:15:00'), Timestamp('2155-09-14 00:31:00'))",
#  "sub_id:10939299, hadm_id:26422493: intubation/extubation pair: (Timestamp('2184-04-17 11:16:00'), Timestamp('2184-04-18 14:36:00'))",
#  "sub_id:10947245, hadm_id:24307798: intubation/extubation pair: (Timestamp('2136-10-20 17:28:00'), Timestamp('2136-11-07 12:16:00'))",
#  "sub_id:10954764, hadm_id:23274056: intubation/extubation pair: (Timestamp('2125-06-11 15:59:00'), Timestamp('2125-06-17 16:05:00'))",
#  "sub_id:10954764, hadm_id:23274056: intubation/extubation pair: (Timestamp('2125-07-03 11:58:00'), Timestamp('2125-07-06 15:07:00'))",
#  "sub_id:10975446, hadm_id:29433790: intubation/extubation pair: (Timestamp('2183-02-12 17:00:00'), Timestamp('2183-02-19 15:00:00'))",
#  "sub_id:10980029, hadm_id:22180118: intubation/extubation pair: (Timestamp('2137-03-01 07:25:00'), Timestamp('2137-03-10 12:17:00'))",
#  "sub_id:10985511, hadm_id:29883624: intubation/extubation pair: (Timestamp('2178-02-06 10:20:00'), Timestamp('2178-02-10 10:00:00'))",
#  "sub_id:10985511, hadm_id:29883624: intubation/extubation pair: (Timestamp('2178-02-21 18:01:00'), Timestamp('2178-02-28 10:30:00'))",
#  "sub_id:10989760, hadm_id:21430515: intubation/extubation pair: (Timestamp('2159-03-24 21:06:00'), Timestamp('2159-04-03 17:06:00'))",
#  "sub_id:10990398, hadm_id:27541056: intubation/extubation pair: (Timestamp('2175-12-15 16:51:00'), Timestamp('2175-12-18 15:23:00'))",
#  "sub_id:10992783, hadm_id:25268342: intubation/extubation pair: (Timestamp('2178-01-23 12:15:00'), Timestamp('2178-02-01 09:50:00'))",
#  "sub_id:10992783, hadm_id:25268342: intubation/extubation pair: (Timestamp('2178-02-05 07:37:00'), Timestamp('2178-02-10 15:18:00'))",
#  "sub_id:10999395, hadm_id:22094873: intubation/extubation pair: (Timestamp('2148-03-17 02:40:00'), Timestamp('2148-03-18 13:22:00'))",
#  "sub_id:11017644, hadm_id:21621302: intubation/extubation pair: (Timestamp('2174-01-19 04:30:00'), Timestamp('2174-01-24 07:55:00'))",
#  "sub_id:11017644, hadm_id:21621302: intubation/extubation pair: (Timestamp('2174-01-25 20:45:00'), Timestamp('2174-01-28 16:15:00'))",
#  "sub_id:11017644, hadm_id:21621302: intubation/extubation pair: (Timestamp('2174-01-28 16:26:00'), Timestamp('2174-01-30 08:52:00'))",
#  "sub_id:11018073, hadm_id:23761571: intubation/extubation pair: (Timestamp('2157-01-22 09:00:00'), Timestamp('2157-01-27 17:00:00'))",
#  "sub_id:11018073, hadm_id:23761571: intubation/extubation pair: (Timestamp('2157-02-25 13:09:00'), Timestamp('2157-02-27 08:17:00'))",
#  "sub_id:11018073, hadm_id:23761571: intubation/extubation pair: (Timestamp('2157-05-13 05:11:00'), Timestamp('2157-05-25 14:17:00'))",
#  "sub_id:11020202, hadm_id:27311676: intubation/extubation pair: (Timestamp('2121-03-06 14:15:00'), Timestamp('2121-03-19 14:45:00'))",
#  "sub_id:11020202, hadm_id:27311676: intubation/extubation pair: (Timestamp('2121-03-19 14:50:00'), Timestamp('2121-03-20 04:35:00'))",
#  "sub_id:11020202, hadm_id:27311676: intubation/extubation pair: (Timestamp('2121-03-20 04:40:00'), Timestamp('2121-03-21 10:12:00'))",
#  "sub_id:11030576, hadm_id:21648828: intubation/extubation pair: (Timestamp('2171-10-14 22:20:00'), Timestamp('2171-10-16 11:44:00'))",
#  "sub_id:11034210, hadm_id:28107091: intubation/extubation pair: (Timestamp('2152-11-12 20:10:00'), None)",
#  "sub_id:11034210, hadm_id:28107091: intubation/extubation pair: (Timestamp('2152-11-25 12:14:00'), Timestamp('2152-11-27 11:50:00'))",
#  "sub_id:11038253, hadm_id:25065906: intubation/extubation pair: (Timestamp('2114-12-15 18:30:00'), Timestamp('2114-12-19 16:15:00'))",
#  "sub_id:11042885, hadm_id:22299146: intubation/extubation pair: (Timestamp('2169-10-12 10:00:00'), Timestamp('2169-10-18 13:51:00'))",
#  "sub_id:11042885, hadm_id:22299146: intubation/extubation pair: (Timestamp('2169-10-19 18:30:00'), Timestamp('2169-11-01 20:30:00'))",
#  "sub_id:11044946, hadm_id:20017989: intubation/extubation pair: (Timestamp('2125-08-11 03:00:00'), Timestamp('2125-08-12 13:45:00'))",
#  "sub_id:11064566, hadm_id:26586602: intubation/extubation pair: (Timestamp('2146-10-13 06:30:00'), Timestamp('2146-10-17 06:30:00'))",
#  "sub_id:11064566, hadm_id:26586602: intubation/extubation pair: (Timestamp('2146-10-17 06:45:00'), None)",
#  "sub_id:11065431, hadm_id:21554363: intubation/extubation pair: (Timestamp('2181-04-16 14:13:00'), Timestamp('2181-04-22 14:30:00'))",
#  "sub_id:11065431, hadm_id:21554363: intubation/extubation pair: (Timestamp('2181-04-24 00:49:00'), None)",
#  "sub_id:11067215, hadm_id:23574374: intubation/extubation pair: (Timestamp('2168-05-01 11:30:00'), Timestamp('2168-05-07 07:10:00'))",
#  "sub_id:11067215, hadm_id:23574374: intubation/extubation pair: (Timestamp('2168-05-11 17:13:00'), Timestamp('2168-05-18 18:00:00'))",
#  "sub_id:11070185, hadm_id:24518501: intubation/extubation pair: (Timestamp('2122-12-23 17:07:00'), Timestamp('2122-12-28 08:49:00'))",
#  "sub_id:11074407, hadm_id:22457623: intubation/extubation pair: (Timestamp('2111-09-21 14:16:00'), Timestamp('2111-09-23 14:42:00'))",
#  "sub_id:11074407, hadm_id:22457623: intubation/extubation pair: (Timestamp('2111-09-25 09:30:00'), Timestamp('2111-09-30 12:00:00'))",
#  "sub_id:11076206, hadm_id:21257601: intubation/extubation pair: (Timestamp('2188-03-15 13:30:00'), Timestamp('2188-03-23 15:54:00'))",
#  "sub_id:11087410, hadm_id:25148713: intubation/extubation pair: (Timestamp('2147-12-31 22:20:00'), Timestamp('2148-01-03 18:19:00'))",
#  "sub_id:11095636, hadm_id:21937919: intubation/extubation pair: (Timestamp('2118-02-20 19:00:00'), Timestamp('2118-02-24 09:50:00'))",
#  "sub_id:11111901, hadm_id:29789360: intubation/extubation pair: (Timestamp('2163-12-29 15:00:00'), None)",
#  "sub_id:11111901, hadm_id:29789360: intubation/extubation pair: (Timestamp('2164-01-02 03:00:00'), None)",
#  "sub_id:11111901, hadm_id:29789360: intubation/extubation pair: (Timestamp('2164-01-04 10:00:00'), Timestamp('2164-01-10 09:56:00'))",
#  "sub_id:11117353, hadm_id:20679385: intubation/extubation pair: (Timestamp('2124-12-31 12:20:00'), None)",
#  "sub_id:11117353, hadm_id:20679385: intubation/extubation pair: (Timestamp('2125-01-03 19:50:00'), None)",
#  "sub_id:11121817, hadm_id:20802314: intubation/extubation pair: (Timestamp('2188-07-26 20:00:00'), Timestamp('2188-07-28 11:00:00'))",
#  "sub_id:11122975, hadm_id:20098892: intubation/extubation pair: (Timestamp('2155-04-30 23:15:00'), Timestamp('2155-05-01 13:18:00'))",
#  "sub_id:11134447, hadm_id:29068519: intubation/extubation pair: (Timestamp('2115-12-04 16:00:00'), Timestamp('2115-12-12 11:50:00'))",
#  "sub_id:11168650, hadm_id:23065690: intubation/extubation pair: (Timestamp('2138-03-07 03:40:00'), Timestamp('2138-03-07 15:15:00'))",
#  "sub_id:11168650, hadm_id:23065690: intubation/extubation pair: (Timestamp('2138-03-18 15:00:00'), None)",
#  "sub_id:11168650, hadm_id:26714990: intubation/extubation pair: (Timestamp('2129-11-10 19:30:00'), Timestamp('2129-11-14 16:40:00'))",
#  "sub_id:11168650, hadm_id:26714990: intubation/extubation pair: (Timestamp('2129-11-15 10:36:00'), None)",
#  "sub_id:11172546, hadm_id:25035599: intubation/extubation pair: (Timestamp('2181-12-12 10:30:00'), Timestamp('2181-12-12 11:45:00'))",
#  "sub_id:11172546, hadm_id:25035599: intubation/extubation pair: (Timestamp('2181-12-23 15:15:00'), Timestamp('2181-12-28 13:30:00'))",
#  "sub_id:11180585, hadm_id:20551749: intubation/extubation pair: (Timestamp('2140-10-15 23:15:00'), Timestamp('2140-10-18 16:00:00'))",
#  "sub_id:11181757, hadm_id:25175936: intubation/extubation pair: (Timestamp('2130-03-07 10:44:00'), Timestamp('2130-03-08 14:50:00'))",
#  "sub_id:11181757, hadm_id:25175936: intubation/extubation pair: (Timestamp('2130-03-24 23:20:00'), None)",
#  "sub_id:11182151, hadm_id:22537178: intubation/extubation pair: (Timestamp('2164-12-30 10:45:00'), Timestamp('2165-01-01 14:25:00'))",
#  "sub_id:11182632, hadm_id:20409313: intubation/extubation pair: (Timestamp('2129-10-16 01:12:00'), Timestamp('2129-10-17 23:20:00'))",
#  "sub_id:11186225, hadm_id:26338291: intubation/extubation pair: (Timestamp('2183-10-18 11:48:00'), Timestamp('2183-11-07 13:45:00'))",
#  "sub_id:11191438, hadm_id:20179421: intubation/extubation pair: (Timestamp('2112-01-03 16:47:00'), Timestamp('2112-01-04 18:00:00'))",
#  "sub_id:11191438, hadm_id:20179421: intubation/extubation pair: (Timestamp('2112-01-06 12:35:00'), Timestamp('2112-01-06 17:54:00'))",
#  "sub_id:11191438, hadm_id:20179421: intubation/extubation pair: (Timestamp('2112-01-06 18:15:00'), Timestamp('2112-01-07 17:01:00'))",
#  "sub_id:11204116, hadm_id:29628229: intubation/extubation pair: (Timestamp('2145-08-09 10:30:00'), Timestamp('2145-08-10 10:50:00'))",
#  "sub_id:11204116, hadm_id:29628229: intubation/extubation pair: (Timestamp('2145-08-13 00:50:00'), None)",
#  "sub_id:11205852, hadm_id:24128477: intubation/extubation pair: (Timestamp('2172-05-11 19:55:00'), None)",
#  "sub_id:11205852, hadm_id:24128477: intubation/extubation pair: (Timestamp('2172-05-18 09:12:00'), Timestamp('2172-05-25 18:36:00'))",
#  "sub_id:11213546, hadm_id:26189768: intubation/extubation pair: (Timestamp('2183-05-18 12:15:00'), Timestamp('2183-05-26 14:21:00'))",
#  "sub_id:11213546, hadm_id:26189768: intubation/extubation pair: (Timestamp('2183-05-31 20:35:00'), Timestamp('2183-06-03 04:34:00'))",
#  "sub_id:11216986, hadm_id:22969970: intubation/extubation pair: (Timestamp('2190-02-09 12:25:00'), Timestamp('2190-02-10 16:27:00'))",
#  "sub_id:11216986, hadm_id:22969970: intubation/extubation pair: (Timestamp('2190-03-19 13:59:00'), None)",
#  "sub_id:11219861, hadm_id:22198294: intubation/extubation pair: (Timestamp('2132-06-29 11:50:00'), Timestamp('2132-06-29 18:00:00'))",
#  "sub_id:11219861, hadm_id:22198294: intubation/extubation pair: (Timestamp('2132-07-01 02:21:00'), Timestamp('2132-07-03 08:16:00'))",
#  "sub_id:11230452, hadm_id:25832117: intubation/extubation pair: (Timestamp('2128-04-18 11:50:00'), Timestamp('2128-04-27 08:00:00'))",
#  "sub_id:11230452, hadm_id:25832117: intubation/extubation pair: (Timestamp('2128-05-02 23:00:00'), None)",
#  "sub_id:11239107, hadm_id:25883588: intubation/extubation pair: (Timestamp('2113-01-16 09:10:00'), Timestamp('2113-01-24 09:33:00'))",
#  "sub_id:11239107, hadm_id:25883588: intubation/extubation pair: (Timestamp('2113-01-31 12:45:00'), None)",
#  "sub_id:11258077, hadm_id:28500459: intubation/extubation pair: (Timestamp('2184-06-16 09:30:00'), Timestamp('2184-06-25 08:45:00'))",
#  "sub_id:11258077, hadm_id:28500459: intubation/extubation pair: (Timestamp('2184-06-25 09:00:00'), Timestamp('2184-07-02 11:17:00'))",
#  "sub_id:11258077, hadm_id:28500459: intubation/extubation pair: (Timestamp('2184-07-02 14:59:00'), None)",
#  "sub_id:11262853, hadm_id:20941131: intubation/extubation pair: (Timestamp('2178-05-04 18:59:00'), Timestamp('2178-05-08 16:21:00'))",
#  "sub_id:11269805, hadm_id:29844758: intubation/extubation pair: (Timestamp('2167-06-19 20:45:00'), Timestamp('2167-06-20 18:46:00'))",
#  "sub_id:11275795, hadm_id:21305184: intubation/extubation pair: (Timestamp('2147-03-10 00:02:00'), None)",
#  "sub_id:11275795, hadm_id:21305184: intubation/extubation pair: (Timestamp('2147-03-12 21:44:00'), Timestamp('2147-03-13 17:54:00'))",
#  "sub_id:11275795, hadm_id:21305184: intubation/extubation pair: (Timestamp('2147-03-15 09:55:00'), None)",
#  "sub_id:11288013, hadm_id:21287757: intubation/extubation pair: (Timestamp('2121-12-18 16:30:00'), None)",
#  "sub_id:11291823, hadm_id:21259664: intubation/extubation pair: (Timestamp('2112-08-19 03:39:00'), None)",
#  "sub_id:11291823, hadm_id:21259664: intubation/extubation pair: (Timestamp('2112-08-22 20:10:00'), Timestamp('2112-08-22 20:18:00'))",
#  "sub_id:11291823, hadm_id:22586748: intubation/extubation pair: (Timestamp('2115-12-18 22:40:00'), Timestamp('2115-12-24 14:07:00'))",
#  "sub_id:11291823, hadm_id:22586748: intubation/extubation pair: (Timestamp('2116-01-07 16:00:00'), Timestamp('2116-01-09 10:00:00'))",
#  "sub_id:11293517, hadm_id:21799365: intubation/extubation pair: (Timestamp('2165-11-04 19:08:00'), Timestamp('2165-11-14 15:48:00'))",
#  "sub_id:11293517, hadm_id:21799365: intubation/extubation pair: (Timestamp('2165-11-23 15:00:00'), None)",
#  "sub_id:11300581, hadm_id:29747297: intubation/extubation pair: (Timestamp('2120-03-22 03:30:00'), Timestamp('2120-03-27 15:13:00'))",
#  "sub_id:11300581, hadm_id:29747297: intubation/extubation pair: (Timestamp('2120-03-30 13:40:00'), None)",
#  "sub_id:11301473, hadm_id:26488073: intubation/extubation pair: (Timestamp('2163-06-23 12:35:00'), Timestamp('2163-06-24 17:08:00'))",
#  "sub_id:11304959, hadm_id:22713043: intubation/extubation pair: (Timestamp('2200-01-05 11:40:00'), Timestamp('2200-01-09 12:19:00'))",
#  "sub_id:11312196, hadm_id:20569926: intubation/extubation pair: (Timestamp('2139-01-23 12:25:00'), Timestamp('2139-01-28 18:33:00'))",
#  "sub_id:11326229, hadm_id:20635802: intubation/extubation pair: (Timestamp('2137-06-01 17:15:00'), None)",
#  "sub_id:11326229, hadm_id:20635802: intubation/extubation pair: (Timestamp('2137-06-06 09:00:00'), None)",
#  "sub_id:11326660, hadm_id:25434637: intubation/extubation pair: (Timestamp('2177-03-02 11:30:00'), Timestamp('2177-03-03 12:32:00'))",
#  "sub_id:11326660, hadm_id:25434637: intubation/extubation pair: (Timestamp('2177-03-13 11:40:00'), Timestamp('2177-03-29 18:00:00'))",
#  "sub_id:11326660, hadm_id:25434637: intubation/extubation pair: (Timestamp('2177-03-30 06:50:00'), Timestamp('2177-04-02 13:50:00'))",
#  "sub_id:11326660, hadm_id:25434637: intubation/extubation pair: (Timestamp('2177-04-07 01:00:00'), None)",
# ...
#  "sub_id:13090343, hadm_id:21316933: intubation/extubation pair: (Timestamp('2173-08-10 23:41:00'), Timestamp('2173-08-26 13:45:00'))",
#  "sub_id:13090343, hadm_id:21316933: intubation/extubation pair: (Timestamp('2173-08-27 08:00:00'), Timestamp('2173-08-28 11:45:00'))",
#  "sub_id:13110443, hadm_id:25130175: intubation/extubation pair: (Timestamp('2191-11-16 15:10:00'), Timestamp('2191-11-19 14:50:00'))",
#  "sub_id:13110443, hadm_id:25130175: intubation/extubation pair: (Timestamp('2191-11-19 14:59:00'), None)",
#  "sub_id:13114102, hadm_id:23387876: intubation/extubation pair: (Timestamp('2168-05-12 13:00:00'), Timestamp('2168-05-17 02:30:00'))",
#  "sub_id:13121870, hadm_id:27370800: intubation/extubation pair: (Timestamp('2171-10-05 15:15:00'), None)",
#  "sub_id:13121870, hadm_id:27370800: intubation/extubation pair: (Timestamp('2171-10-09 02:50:00'), None)",
#  "sub_id:13122945, hadm_id:22242120: intubation/extubation pair: (Timestamp('2138-02-25 17:19:00'), Timestamp('2138-02-28 08:45:00'))",
#  "sub_id:13122945, hadm_id:22242120: intubation/extubation pair: (Timestamp('2138-03-02 01:20:00'), None)",
#  "sub_id:13134081, hadm_id:20906131: intubation/extubation pair: (Timestamp('2113-03-16 04:01:00'), Timestamp('2113-03-17 15:12:00'))",
#  "sub_id:13135946, hadm_id:22133572: intubation/extubation pair: (Timestamp('2143-08-07 15:06:00'), Timestamp('2143-08-12 09:47:00'))",
#  "sub_id:13135946, hadm_id:22133572: intubation/extubation pair: (Timestamp('2143-08-14 12:07:00'), None)",
#  "sub_id:13138475, hadm_id:29847750: intubation/extubation pair: (Timestamp('2143-09-13 23:43:00'), None)",
#  "sub_id:13138475, hadm_id:29847750: intubation/extubation pair: (Timestamp('2143-09-17 02:45:00'), Timestamp('2143-09-18 15:45:00'))",
#  "sub_id:13138475, hadm_id:29847750: intubation/extubation pair: (Timestamp('2143-09-25 12:35:00'), None)",
#  "sub_id:13142166, hadm_id:21649104: intubation/extubation pair: (Timestamp('2174-03-12 10:30:00'), Timestamp('2174-03-14 10:15:00'))",
#  "sub_id:13142166, hadm_id:21649104: intubation/extubation pair: (Timestamp('2174-03-16 11:40:00'), Timestamp('2174-03-19 11:18:00'))",
#  "sub_id:13155939, hadm_id:25316345: intubation/extubation pair: (Timestamp('2189-05-19 07:35:00'), Timestamp('2189-05-20 21:04:00'))",
#  "sub_id:13155939, hadm_id:25316345: intubation/extubation pair: (Timestamp('2189-05-22 01:30:00'), Timestamp('2189-05-24 09:59:00'))",
#  "sub_id:13157621, hadm_id:21295657: intubation/extubation pair: (Timestamp('2121-10-19 07:50:00'), None)",
#  "sub_id:13157621, hadm_id:21295657: intubation/extubation pair: (Timestamp('2121-10-19 14:43:00'), Timestamp('2121-10-20 10:20:00'))",
#  "sub_id:13159019, hadm_id:24067663: intubation/extubation pair: (Timestamp('2139-11-10 08:30:00'), Timestamp('2139-11-11 14:13:00'))",
#  "sub_id:13164041, hadm_id:29039690: intubation/extubation pair: (Timestamp('2126-11-22 15:30:00'), None)",
#  "sub_id:13164041, hadm_id:29039690: intubation/extubation pair: (Timestamp('2126-12-01 15:49:00'), None)",
#  "sub_id:13164041, hadm_id:29039690: intubation/extubation pair: (Timestamp('2126-12-15 21:10:00'), Timestamp('2126-12-24 18:32:00'))",
#  "sub_id:13180512, hadm_id:24527016: intubation/extubation pair: (Timestamp('2151-04-19 16:40:00'), Timestamp('2151-04-25 13:30:00'))",
#  "sub_id:13182275, hadm_id:20284049: intubation/extubation pair: (Timestamp('2176-08-08 01:45:00'), Timestamp('2176-08-08 11:00:00'))",
#  "sub_id:13182275, hadm_id:20284049: intubation/extubation pair: (Timestamp('2176-08-08 17:15:00'), Timestamp('2176-08-12 13:00:00'))",
#  "sub_id:13188363, hadm_id:24879827: intubation/extubation pair: (Timestamp('2152-01-31 19:00:00'), Timestamp('2152-02-01 16:55:00'))",
#  "sub_id:13188363, hadm_id:24879827: intubation/extubation pair: (Timestamp('2152-02-03 20:47:00'), Timestamp('2152-04-01 14:14:00'))",
#  "sub_id:13188363, hadm_id:24879827: intubation/extubation pair: (Timestamp('2152-05-17 05:00:00'), None)",
#  "sub_id:13191989, hadm_id:28038618: intubation/extubation pair: (Timestamp('2116-11-29 18:25:00'), None)",
#  "sub_id:13191989, hadm_id:28038618: intubation/extubation pair: (Timestamp('2116-12-08 03:00:00'), Timestamp('2116-12-31 17:00:00'))",
#  "sub_id:13208026, hadm_id:20866231: intubation/extubation pair: (Timestamp('2166-01-29 13:30:00'), Timestamp('2166-02-01 12:45:00'))",
#  "sub_id:13208026, hadm_id:20866231: intubation/extubation pair: (Timestamp('2166-02-01 12:58:00'), Timestamp('2166-02-04 13:30:00'))",
#  "sub_id:13209752, hadm_id:21771189: intubation/extubation pair: (Timestamp('2165-12-04 10:30:00'), Timestamp('2165-12-21 08:00:00'))",
#  "sub_id:13210714, hadm_id:21705823: intubation/extubation pair: (Timestamp('2159-04-30 12:59:00'), Timestamp('2159-05-01 16:12:00'))",
#  "sub_id:13216259, hadm_id:20347425: intubation/extubation pair: (Timestamp('2138-10-12 07:20:00'), Timestamp('2138-10-14 12:15:00'))",
#  "sub_id:13224377, hadm_id:21807194: intubation/extubation pair: (Timestamp('2135-02-14 15:40:00'), Timestamp('2135-02-14 16:30:00'))",
#  "sub_id:13224377, hadm_id:21807194: intubation/extubation pair: (Timestamp('2135-03-09 16:00:00'), Timestamp('2135-03-17 13:10:00'))",
#  "sub_id:13224377, hadm_id:21807194: intubation/extubation pair: (Timestamp('2135-05-12 16:20:00'), None)",
#  "sub_id:13231528, hadm_id:26933831: intubation/extubation pair: (Timestamp('2185-06-17 23:23:00'), Timestamp('2185-06-24 22:00:00'))",
#  "sub_id:13231528, hadm_id:26933831: intubation/extubation pair: (Timestamp('2185-06-24 22:15:00'), Timestamp('2185-06-26 08:10:00'))",
#  "sub_id:13231630, hadm_id:26950311: intubation/extubation pair: (Timestamp('2186-08-13 12:45:00'), Timestamp('2186-08-14 12:20:00'))",
#  "sub_id:13231630, hadm_id:26950311: intubation/extubation pair: (Timestamp('2186-08-16 13:34:00'), None)",
#  "sub_id:13247581, hadm_id:26936299: intubation/extubation pair: (Timestamp('2143-06-16 14:11:00'), None)",
#  "sub_id:13247581, hadm_id:26936299: intubation/extubation pair: (Timestamp('2143-06-17 19:28:00'), Timestamp('2143-06-19 08:07:00'))",
#  "sub_id:13247654, hadm_id:25929133: intubation/extubation pair: (Timestamp('2121-01-10 18:00:00'), Timestamp('2121-01-11 14:20:00'))",
#  "sub_id:13247654, hadm_id:25929133: intubation/extubation pair: (Timestamp('2121-01-12 08:10:00'), Timestamp('2121-01-13 11:00:00'))",
#  "sub_id:13251286, hadm_id:20115323: intubation/extubation pair: (Timestamp('2144-11-07 15:00:00'), Timestamp('2144-11-08 13:15:00'))",
#  "sub_id:13256955, hadm_id:28710762: intubation/extubation pair: (Timestamp('2189-11-05 02:50:00'), Timestamp('2189-11-05 13:54:00'))",
#  "sub_id:13276959, hadm_id:29535509: intubation/extubation pair: (Timestamp('2138-08-25 17:34:00'), Timestamp('2138-08-27 11:45:00'))",
#  "sub_id:13276959, hadm_id:29535509: intubation/extubation pair: (Timestamp('2138-08-27 11:55:00'), Timestamp('2138-08-31 10:45:00'))",
#  "sub_id:13276959, hadm_id:29535509: intubation/extubation pair: (Timestamp('2138-09-02 17:00:00'), Timestamp('2138-09-04 10:00:00'))",
#  "sub_id:13280368, hadm_id:25603270: intubation/extubation pair: (Timestamp('2129-01-20 10:49:00'), None)",
#  "sub_id:13280368, hadm_id:25603270: intubation/extubation pair: (Timestamp('2129-01-31 16:46:00'), Timestamp('2129-02-02 15:34:00'))",
#  "sub_id:13283178, hadm_id:26706273: intubation/extubation pair: (Timestamp('2127-03-06 07:45:00'), Timestamp('2127-03-06 22:30:00'))",
#  "sub_id:13283178, hadm_id:26706273: intubation/extubation pair: (Timestamp('2127-03-07 00:10:00'), Timestamp('2127-03-09 10:15:00'))",
#  "sub_id:13287489, hadm_id:25580332: intubation/extubation pair: (Timestamp('2186-11-06 12:45:00'), Timestamp('2186-11-12 17:02:00'))",
#  "sub_id:13299285, hadm_id:21822177: intubation/extubation pair: (Timestamp('2178-01-11 11:55:00'), Timestamp('2178-01-20 13:00:00'))",
#  "sub_id:13299285, hadm_id:21822177: intubation/extubation pair: (Timestamp('2178-02-09 01:30:00'), None)",
#  "sub_id:13301272, hadm_id:20413622: intubation/extubation pair: (Timestamp('2146-05-06 20:30:00'), Timestamp('2146-05-08 23:11:00'))",
#  "sub_id:13312252, hadm_id:29667896: intubation/extubation pair: (Timestamp('2156-06-21 16:21:00'), Timestamp('2156-06-25 15:39:00'))",
#  "sub_id:13322057, hadm_id:25653494: intubation/extubation pair: (Timestamp('2173-11-24 00:55:00'), Timestamp('2173-11-26 12:49:00'))",
#  "sub_id:13326473, hadm_id:28930686: intubation/extubation pair: (Timestamp('2158-07-30 04:20:00'), Timestamp('2158-07-30 06:45:00'))",
#  "sub_id:13331269, hadm_id:20297853: intubation/extubation pair: (Timestamp('2123-04-06 18:00:00'), None)",
#  "sub_id:13331269, hadm_id:20297853: intubation/extubation pair: (Timestamp('2123-04-06 19:03:00'), None)",
#  "sub_id:13335237, hadm_id:29435960: intubation/extubation pair: (Timestamp('2186-09-26 15:00:00'), Timestamp('2186-09-30 17:50:00'))",
#  "sub_id:13336511, hadm_id:28936109: intubation/extubation pair: (Timestamp('2160-09-25 05:46:00'), Timestamp('2160-09-26 08:57:00'))",
#  "sub_id:13345716, hadm_id:26291980: intubation/extubation pair: (Timestamp('2134-05-30 21:50:00'), Timestamp('2134-06-05 09:25:00'))",
#  "sub_id:13345716, hadm_id:26291980: intubation/extubation pair: (Timestamp('2134-06-05 09:45:00'), None)",
#  "sub_id:13352372, hadm_id:28752421: intubation/extubation pair: (Timestamp('2147-05-24 23:43:00'), Timestamp('2147-05-28 16:58:00'))",
#  "sub_id:13352372, hadm_id:28752421: intubation/extubation pair: (Timestamp('2147-05-29 09:03:00'), None)",
#  "sub_id:13365915, hadm_id:29277897: intubation/extubation pair: (Timestamp('2179-01-19 02:00:00'), None)",
#  "sub_id:13365915, hadm_id:29277897: intubation/extubation pair: (Timestamp('2179-01-21 21:30:00'), Timestamp('2179-02-02 16:24:00'))",
#  "sub_id:13367954, hadm_id:25262787: intubation/extubation pair: (Timestamp('2117-01-02 08:35:00'), Timestamp('2117-01-04 08:30:00'))",
#  "sub_id:13388935, hadm_id:25319012: intubation/extubation pair: (Timestamp('2174-10-13 08:47:00'), Timestamp('2174-10-13 17:45:00'))",
#  "sub_id:13390728, hadm_id:26350081: intubation/extubation pair: (Timestamp('2120-02-13 21:00:00'), Timestamp('2120-02-25 16:40:00'))",
#  "sub_id:13394692, hadm_id:28720007: intubation/extubation pair: (Timestamp('2111-03-20 01:30:00'), Timestamp('2111-03-26 04:50:00'))",
#  "sub_id:13399504, hadm_id:20929866: intubation/extubation pair: (Timestamp('2119-11-28 15:38:00'), None)",
#  "sub_id:13402290, hadm_id:23123365: intubation/extubation pair: (Timestamp('2116-08-24 19:53:00'), Timestamp('2116-08-31 14:20:00'))",
#  "sub_id:13402290, hadm_id:23123365: intubation/extubation pair: (Timestamp('2116-08-31 14:26:00'), None)",
#  "sub_id:13411545, hadm_id:20440298: intubation/extubation pair: (Timestamp('2176-04-09 09:00:00'), Timestamp('2176-04-21 16:33:00'))",
#  "sub_id:13411545, hadm_id:20440298: intubation/extubation pair: (Timestamp('2176-04-23 19:46:00'), Timestamp('2176-04-24 15:00:00'))",
#  "sub_id:13415410, hadm_id:26910934: intubation/extubation pair: (Timestamp('2158-11-17 22:44:00'), Timestamp('2158-11-20 15:15:00'))",
#  "sub_id:13415410, hadm_id:26910934: intubation/extubation pair: (Timestamp('2158-11-21 06:40:00'), None)",
#  "sub_id:13415550, hadm_id:25548368: intubation/extubation pair: (Timestamp('2186-02-01 20:34:00'), Timestamp('2186-02-04 08:51:00'))",
#  "sub_id:13425422, hadm_id:20645875: intubation/extubation pair: (Timestamp('2164-12-15 12:00:00'), Timestamp('2164-12-15 15:00:00'))",
#  "sub_id:13443911, hadm_id:26077552: intubation/extubation pair: (Timestamp('2136-05-29 20:00:00'), Timestamp('2136-05-31 15:55:00'))",
#  "sub_id:13449480, hadm_id:25601260: intubation/extubation pair: (Timestamp('2144-01-21 22:41:00'), Timestamp('2144-01-29 08:00:00'))",
#  "sub_id:13462065, hadm_id:26750703: intubation/extubation pair: (Timestamp('2131-09-14 17:32:00'), Timestamp('2131-09-15 20:48:00'))",
#  "sub_id:13462065, hadm_id:26750703: intubation/extubation pair: (Timestamp('2131-09-16 09:27:00'), Timestamp('2131-09-21 13:45:00'))",
#  "sub_id:13462065, hadm_id:26750703: intubation/extubation pair: (Timestamp('2131-09-23 12:01:00'), None)",
#  "sub_id:13464769, hadm_id:26552927: intubation/extubation pair: (Timestamp('2124-03-30 12:50:00'), Timestamp('2124-03-31 15:10:00'))",
#  "sub_id:13464769, hadm_id:26552927: intubation/extubation pair: (Timestamp('2124-03-31 21:30:00'), Timestamp('2124-04-10 14:30:00'))",
#  "sub_id:13467066, hadm_id:27794492: intubation/extubation pair: (Timestamp('2133-10-26 12:00:00'), Timestamp('2133-10-30 12:08:00'))",
#  "sub_id:13467066, hadm_id:27794492: intubation/extubation pair: (Timestamp('2133-10-30 13:29:00'), Timestamp('2133-11-08 17:57:00'))",
#  "sub_id:13470702, hadm_id:25265899: intubation/extubation pair: (Timestamp('2134-02-13 11:45:00'), Timestamp('2134-02-17 13:18:00'))",
#  "sub_id:13474359, hadm_id:22461878: intubation/extubation pair: (Timestamp('2121-09-04 08:48:00'), Timestamp('2121-09-09 14:00:00'))",
#  "sub_id:13479420, hadm_id:21083808: intubation/extubation pair: (Timestamp('2168-01-24 01:57:00'), Timestamp('2168-01-28 18:15:00'))",
#  "sub_id:13481227, hadm_id:21444188: intubation/extubation pair: (Timestamp('2184-12-27 11:05:00'), Timestamp('2184-12-30 08:50:00'))",
#  "sub_id:13495200, hadm_id:29364600: intubation/extubation pair: (Timestamp('2160-12-20 16:00:00'), Timestamp('2160-12-24 12:30:00'))",
#  "sub_id:13496466, hadm_id:23642129: intubation/extubation pair: (Timestamp('2165-08-29 21:45:00'), None)",
#  "sub_id:13496466, hadm_id:23642129: intubation/extubation pair: (Timestamp('2165-09-01 22:40:00'), Timestamp('2165-09-12 15:06:00'))",
#  "sub_id:13496639, hadm_id:26484716: intubation/extubation pair: (Timestamp('2170-01-25 03:15:00'), Timestamp('2170-01-30 17:15:00'))",
#  "sub_id:13496639, hadm_id:26484716: intubation/extubation pair: (Timestamp('2170-02-10 18:16:00'), Timestamp('2170-02-10 18:44:00'))",
#  "sub_id:13496639, hadm_id:26484716: intubation/extubation pair: (Timestamp('2170-02-15 12:00:00'), Timestamp('2170-02-17 10:44:00'))",
#  "sub_id:13500689, hadm_id:24081317: intubation/extubation pair: (Timestamp('2137-09-15 03:20:00'), Timestamp('2137-09-18 15:03:00'))",
#  "sub_id:13500689, hadm_id:24081317: intubation/extubation pair: (Timestamp('2137-09-21 21:29:00'), Timestamp('2137-09-24 07:50:00'))",
#  "sub_id:13500689, hadm_id:24081317: intubation/extubation pair: (Timestamp('2137-09-29 08:40:00'), None)",
#  "sub_id:13507232, hadm_id:25829986: intubation/extubation pair: (Timestamp('2154-08-25 12:30:00'), Timestamp('2154-08-30 08:25:00'))",
#  "sub_id:13507232, hadm_id:25829986: intubation/extubation pair: (Timestamp('2154-08-30 18:20:00'), None)",
#  "sub_id:13512648, hadm_id:25653583: intubation/extubation pair: (Timestamp('2174-12-21 11:00:00'), Timestamp('2174-12-23 15:44:00'))",
#  "sub_id:13514465, hadm_id:28109699: intubation/extubation pair: (Timestamp('2120-10-27 18:10:00'), Timestamp('2120-10-30 10:32:00'))",
#  "sub_id:13515178, hadm_id:20762918: intubation/extubation pair: (Timestamp('2154-01-14 11:37:00'), None)",
#  "sub_id:13515178, hadm_id:20762918: intubation/extubation pair: (Timestamp('2154-01-20 16:15:00'), Timestamp('2154-01-26 11:55:00'))",
#  "sub_id:13515178, hadm_id:20762918: intubation/extubation pair: (Timestamp('2154-01-26 12:26:00'), None)",
#  "sub_id:13515178, hadm_id:28966068: intubation/extubation pair: (Timestamp('2154-04-15 21:00:00'), Timestamp('2154-04-17 17:22:00'))",
#  "sub_id:13516473, hadm_id:23613352: intubation/extubation pair: (Timestamp('2144-01-30 10:19:00'), Timestamp('2144-02-06 12:40:00'))",
#  "sub_id:13516473, hadm_id:23613352: intubation/extubation pair: (Timestamp('2144-02-16 16:25:00'), Timestamp('2144-02-19 15:26:00'))",
#  "sub_id:13516473, hadm_id:23613352: intubation/extubation pair: (Timestamp('2144-02-20 20:35:00'), None)",
#  "sub_id:13526177, hadm_id:21051213: intubation/extubation pair: (Timestamp('2141-04-28 02:19:00'), Timestamp('2141-05-09 10:07:00'))",
#  "sub_id:13526177, hadm_id:21051213: intubation/extubation pair: (Timestamp('2141-05-15 12:00:00'), None)",
#  "sub_id:13528306, hadm_id:20813943: intubation/extubation pair: (Timestamp('2178-11-09 12:00:00'), Timestamp('2178-11-13 11:35:00'))",
#  ...]

# %%
extracted_data2
# Out:
# [{'subject_id': 19997367,
#   'hadm_id': 20617667,
#   'int_stayid_x': 35616526,
#   'admittime_x': '2126-04-20 07:15:00',
#   'intubationtime_x': Timestamp('2126-04-26 20:14:00'),
#   'int_itemid_x': 224385,
#   'int_weight_x': 59.0,
#   'ext_stayid_x': 35616526.0,
#   'extubationtime_x': Timestamp('2126-04-22 08:23:00'),
#   'ext_itemid_x': 227194.0,
#   'ext_weight_x': 59.0,
#   'extubationcause_x': 'Planned Extubation',
#   'dischtime_x': '2126-05-19 14:15:00',
#   'deathtime_x': nan,
#   'int_stayid_y': 35616526,
#   'admittime_y': '2126-04-20 07:15:00',
#   'intubationtime_y': Timestamp('2126-04-26 20:14:00'),
#   'int_itemid_y': 224385,
#   'int_weight_y': 59.0,
#   'ext_stayid_y': 35616526.0,
#   'extubationtime_y': Timestamp('2126-05-02 16:30:00'),
#   'ext_itemid_y': 227194.0,
#   'ext_weight_y': 59.0,
#   'extubationcause_y': 'Planned Extubation',
#   'dischtime_y': '2126-05-19 14:15:00',
#   'deathtime_y': nan},
#  {'subject_id': 19997367,
#   'hadm_id': 20617667,
#   'int_stayid_x': 35616526,
#   'admittime_x': '2126-04-20 07:15:00',
#   'intubationtime_x': Timestamp('2126-05-05 18:20:00'),
#   'int_itemid_x': 224385,
#   'int_weight_x': 59.0,
#   'ext_stayid_x': 35616526.0,
#   'extubationtime_x': Timestamp('2126-04-22 08:23:00'),
#   'ext_itemid_x': 227194.0,
#   'ext_weight_x': 59.0,
#   'extubationcause_x': 'Planned Extubation',
#   'dischtime_x': '2126-05-19 14:15:00',
#   'deathtime_x': nan,
#   'int_stayid_y': 35616526,
#   'admittime_y': '2126-04-20 07:15:00',
#   'intubationtime_y': Timestamp('2126-04-26 20:14:00'),
#   'int_itemid_y': 224385,
#   'int_weight_y': 59.0,
#   'ext_stayid_y': 35616526.0,
#   'extubationtime_y': Timestamp('2126-05-08 17:29:00'),
#   'ext_itemid_y': 227194.0,
#   'ext_weight_y': 59.0,
#   'extubationcause_y': 'Planned Extubation',
#   'dischtime_y': '2126-05-19 14:15:00',
#   'deathtime_y': nan}]

# %% [markdown]
# time pairing test

# %%
pair_results2
# Out:
# {(19997367,
#   20617667): [(Timestamp('2126-04-26 20:14:00'),
#    Timestamp('2126-05-02 16:30:00')), (Timestamp('2126-05-05 18:20:00'),
#    Timestamp('2126-05-08 17:29:00'))]}

# %%
pair_logs2
# Out:
# ["sub_id:10004401, hadm_id:29988601: intubation/extubation pair: (Timestamp('2144-01-27 19:00:00'), Timestamp('2144-01-30 12:30:00'))",
#  "sub_id:10004401, hadm_id:29988601: intubation/extubation pair: (Timestamp('2144-01-30 13:00:00'), None)",
#  "sub_id:10020740, hadm_id:23831430: intubation/extubation pair: (Timestamp('2150-03-27 07:44:00'), Timestamp('2150-03-27 16:33:00'))",
#  "sub_id:10020740, hadm_id:23831430: intubation/extubation pair: (Timestamp('2150-03-30 08:20:00'), Timestamp('2150-04-02 01:09:00'))",
#  "sub_id:10024982, hadm_id:25154057: intubation/extubation pair: (Timestamp('2203-10-02 11:00:00'), Timestamp('2203-10-09 14:50:00'))",
#  "sub_id:10027602, hadm_id:28166872: intubation/extubation pair: (Timestamp('2201-11-07 15:00:00'), Timestamp('2201-11-09 12:45:00'))",
#  "sub_id:10032381, hadm_id:20176432: intubation/extubation pair: (Timestamp('2115-07-06 02:15:00'), Timestamp('2115-07-15 11:00:00'))",
#  "sub_id:10032381, hadm_id:20176432: intubation/extubation pair: (Timestamp('2115-07-18 17:00:00'), None)",
#  "sub_id:10039708, hadm_id:28258130: intubation/extubation pair: (Timestamp('2140-02-01 16:30:00'), Timestamp('2140-02-02 17:40:00'))",
#  "sub_id:10039708, hadm_id:28258130: intubation/extubation pair: (Timestamp('2140-02-02 19:03:00'), Timestamp('2140-02-06 11:27:00'))",
#  "sub_id:10079700, hadm_id:24239751: intubation/extubation pair: (Timestamp('2115-09-27 17:23:00'), None)",
#  "sub_id:10079700, hadm_id:24239751: intubation/extubation pair: (Timestamp('2115-10-11 14:05:00'), Timestamp('2115-10-11 15:40:00'))",
#  "sub_id:10085667, hadm_id:27382550: intubation/extubation pair: (Timestamp('2192-12-15 22:30:00'), Timestamp('2192-12-16 11:45:00'))",
#  "sub_id:10090454, hadm_id:29525590: intubation/extubation pair: (Timestamp('2169-02-06 19:00:00'), None)",
#  "sub_id:10090454, hadm_id:29525590: intubation/extubation pair: (Timestamp('2169-02-10 16:22:00'), Timestamp('2169-02-10 21:16:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-05-09 19:02:00'), None)",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-03 20:50:00'), Timestamp('2118-06-06 16:33:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-07 01:40:00'), Timestamp('2118-06-08 11:55:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-18 01:48:00'), Timestamp('2118-06-21 03:30:00'))",
#  "sub_id:10098215, hadm_id:22394571: intubation/extubation pair: (Timestamp('2118-06-21 08:28:00'), Timestamp('2118-06-27 12:45:00'))",
#  "sub_id:10109956, hadm_id:26022059: intubation/extubation pair: (Timestamp('2184-05-14 04:15:00'), Timestamp('2184-05-22 12:20:00'))",
#  "sub_id:10115397, hadm_id:28605901: intubation/extubation pair: (Timestamp('2133-01-10 11:15:00'), Timestamp('2133-01-16 08:39:00'))",
#  "sub_id:10117273, hadm_id:24446922: intubation/extubation pair: (Timestamp('2184-08-20 08:42:00'), Timestamp('2184-08-20 11:30:00'))",
#  "sub_id:10117273, hadm_id:24446922: intubation/extubation pair: (Timestamp('2184-08-21 17:15:00'), Timestamp('2184-08-26 10:35:00'))",
#  "sub_id:10119017, hadm_id:20229125: intubation/extubation pair: (Timestamp('2159-08-14 06:38:00'), Timestamp('2159-08-18 13:38:00'))",
#  "sub_id:10122589, hadm_id:28594240: intubation/extubation pair: (Timestamp('2180-04-09 08:00:00'), Timestamp('2180-04-10 15:05:00'))",
#  "sub_id:10125047, hadm_id:26680668: intubation/extubation pair: (Timestamp('2180-01-19 00:00:00'), Timestamp('2180-01-20 08:05:00'))",
#  "sub_id:10125047, hadm_id:26680668: intubation/extubation pair: (Timestamp('2180-01-21 13:12:00'), Timestamp('2180-01-24 13:38:00'))",
#  "sub_id:10125047, hadm_id:26680668: intubation/extubation pair: (Timestamp('2180-01-24 15:20:00'), None)",
#  "sub_id:10136619, hadm_id:23362878: intubation/extubation pair: (Timestamp('2141-01-21 07:55:00'), None)",
#  "sub_id:10136619, hadm_id:23362878: intubation/extubation pair: (Timestamp('2141-01-23 04:30:00'), None)",
#  "sub_id:10143030, hadm_id:27543597: intubation/extubation pair: (Timestamp('2180-05-17 01:55:00'), None)",
#  "sub_id:10143030, hadm_id:27543597: intubation/extubation pair: (Timestamp('2180-06-01 13:10:00'), None)",
#  "sub_id:10143030, hadm_id:27543597: intubation/extubation pair: (Timestamp('2180-06-20 18:39:00'), None)",
#  "sub_id:10150335, hadm_id:24113307: intubation/extubation pair: (Timestamp('2144-09-12 04:35:00'), Timestamp('2144-09-12 18:50:00'))",
#  "sub_id:10150335, hadm_id:24113307: intubation/extubation pair: (Timestamp('2144-09-12 19:11:00'), Timestamp('2144-09-15 14:42:00'))",
#  "sub_id:10150335, hadm_id:24113307: intubation/extubation pair: (Timestamp('2144-09-17 01:00:00'), None)",
#  "sub_id:10151556, hadm_id:20815067: intubation/extubation pair: (Timestamp('2184-02-14 16:19:00'), None)",
#  "sub_id:10151556, hadm_id:20815067: intubation/extubation pair: (Timestamp('2184-03-21 00:25:00'), None)",
#  "sub_id:10160622, hadm_id:28663041: intubation/extubation pair: (Timestamp('2180-05-25 11:17:00'), Timestamp('2180-05-31 18:30:00'))",
#  "sub_id:10160622, hadm_id:28663041: intubation/extubation pair: (Timestamp('2180-06-02 10:55:00'), Timestamp('2180-06-15 14:59:00'))",
#  "sub_id:10163709, hadm_id:29550274: intubation/extubation pair: (Timestamp('2148-03-23 01:44:00'), Timestamp('2148-03-23 11:47:00'))",
#  "sub_id:10163709, hadm_id:29550274: intubation/extubation pair: (Timestamp('2148-03-23 15:08:00'), Timestamp('2148-03-25 14:51:00'))",
#  "sub_id:10173670, hadm_id:21801929: intubation/extubation pair: (Timestamp('2125-02-02 13:30:00'), Timestamp('2125-02-08 12:30:00'))",
#  "sub_id:10179383, hadm_id:20170028: intubation/extubation pair: (Timestamp('2183-08-11 03:00:00'), Timestamp('2183-08-11 16:27:00'))",
#  "sub_id:10179383, hadm_id:20170028: intubation/extubation pair: (Timestamp('2183-08-13 00:05:00'), Timestamp('2183-08-17 13:59:00'))",
#  "sub_id:10185829, hadm_id:22742058: intubation/extubation pair: (Timestamp('2157-09-06 08:16:00'), Timestamp('2157-09-08 12:04:00'))",
#  "sub_id:10186500, hadm_id:27961292: intubation/extubation pair: (Timestamp('2181-05-06 17:00:00'), Timestamp('2181-05-07 17:00:00'))",
#  "sub_id:10186500, hadm_id:27961292: intubation/extubation pair: (Timestamp('2181-05-22 02:00:00'), None)",
#  "sub_id:10193074, hadm_id:22392305: intubation/extubation pair: (Timestamp('2121-02-16 15:00:00'), Timestamp('2121-02-19 14:00:00'))",
#  "sub_id:10203444, hadm_id:25550068: intubation/extubation pair: (Timestamp('2134-08-22 14:22:00'), Timestamp('2134-08-24 13:30:00'))",
#  "sub_id:10229323, hadm_id:25045444: intubation/extubation pair: (Timestamp('2164-12-25 13:38:00'), Timestamp('2165-01-02 10:01:00'))",
#  "sub_id:10229323, hadm_id:25045444: intubation/extubation pair: (Timestamp('2165-01-02 10:15:00'), None)",
#  "sub_id:10233088, hadm_id:24630582: intubation/extubation pair: (Timestamp('2161-10-09 00:00:00'), Timestamp('2161-10-14 14:30:00'))",
#  "sub_id:10233088, hadm_id:24630582: intubation/extubation pair: (Timestamp('2161-10-15 08:58:00'), Timestamp('2161-10-18 18:33:00'))",
#  "sub_id:10233597, hadm_id:27468267: intubation/extubation pair: (Timestamp('2187-12-14 20:56:00'), Timestamp('2187-12-18 16:25:00'))",
#  "sub_id:10233597, hadm_id:27468267: intubation/extubation pair: (Timestamp('2187-12-19 03:52:00'), Timestamp('2187-12-23 13:55:00'))",
#  "sub_id:10233597, hadm_id:27468267: intubation/extubation pair: (Timestamp('2187-12-29 06:22:00'), None)",
#  "sub_id:10236222, hadm_id:23831668: intubation/extubation pair: (Timestamp('2200-01-01 22:26:00'), Timestamp('2200-01-03 16:10:00'))",
#  "sub_id:10244046, hadm_id:27440644: intubation/extubation pair: (Timestamp('2157-01-07 08:30:00'), Timestamp('2157-01-08 08:30:00'))",
#  "sub_id:10251182, hadm_id:29312838: intubation/extubation pair: (Timestamp('2155-05-10 14:50:00'), Timestamp('2155-05-11 04:52:00'))",
#  "sub_id:10254774, hadm_id:21124863: intubation/extubation pair: (Timestamp('2119-02-22 17:00:00'), Timestamp('2119-03-02 08:36:00'))",
#  "sub_id:10258162, hadm_id:28433140: intubation/extubation pair: (Timestamp('2150-09-19 01:00:00'), Timestamp('2150-09-20 10:15:00'))",
#  "sub_id:10258162, hadm_id:28433140: intubation/extubation pair: (Timestamp('2150-09-28 08:00:00'), None)",
#  "sub_id:10258162, hadm_id:28433140: intubation/extubation pair: (Timestamp('2150-10-01 00:20:00'), Timestamp('2150-10-01 00:22:00'))",
#  "sub_id:10262096, hadm_id:23639696: intubation/extubation pair: (Timestamp('2167-03-10 18:17:00'), None)",
#  "sub_id:10262096, hadm_id:23639696: intubation/extubation pair: (Timestamp('2167-03-11 20:00:00'), Timestamp('2167-03-13 21:05:00'))",
#  "sub_id:10267084, hadm_id:28933075: intubation/extubation pair: (Timestamp('2147-12-01 11:15:00'), None)",
#  "sub_id:10267084, hadm_id:28933075: intubation/extubation pair: (Timestamp('2147-12-01 19:57:00'), Timestamp('2147-12-01 23:40:00'))",
#  "sub_id:10268877, hadm_id:25238883: intubation/extubation pair: (Timestamp('2181-03-07 09:06:00'), Timestamp('2181-03-22 19:45:00'))",
#  "sub_id:10280054, hadm_id:20177063: intubation/extubation pair: (Timestamp('2143-04-29 11:43:00'), Timestamp('2143-05-01 10:42:00'))",
#  "sub_id:10295020, hadm_id:24995523: intubation/extubation pair: (Timestamp('2147-06-08 23:05:00'), None)",
#  "sub_id:10295020, hadm_id:24995523: intubation/extubation pair: (Timestamp('2147-06-10 17:41:00'), Timestamp('2147-06-14 10:45:00'))",
#  "sub_id:10302157, hadm_id:24530152: intubation/extubation pair: (Timestamp('2189-03-21 13:00:00'), Timestamp('2189-03-28 16:52:00'))",
#  "sub_id:10304606, hadm_id:25532105: intubation/extubation pair: (Timestamp('2160-10-26 14:20:00'), Timestamp('2160-10-28 16:37:00'))",
#  "sub_id:10304606, hadm_id:25532105: intubation/extubation pair: (Timestamp('2160-10-31 16:25:00'), Timestamp('2160-11-08 15:00:00'))",
#  "sub_id:10304606, hadm_id:25532105: intubation/extubation pair: (Timestamp('2160-11-09 20:45:00'), None)",
#  "sub_id:10308297, hadm_id:27825244: intubation/extubation pair: (Timestamp('2189-01-24 16:57:00'), Timestamp('2189-01-25 02:11:00'))",
#  "sub_id:10308342, hadm_id:24888258: intubation/extubation pair: (Timestamp('2162-11-20 23:20:00'), Timestamp('2162-11-25 12:19:00'))",
#  "sub_id:10309969, hadm_id:23107749: intubation/extubation pair: (Timestamp('2182-01-21 10:24:00'), Timestamp('2182-02-06 10:59:00'))",
#  "sub_id:10309969, hadm_id:23107749: intubation/extubation pair: (Timestamp('2182-02-06 12:05:00'), None)",
#  "sub_id:10311956, hadm_id:25628815: intubation/extubation pair: (Timestamp('2123-03-12 15:23:00'), Timestamp('2123-03-18 08:10:00'))",
#  "sub_id:10321446, hadm_id:26487233: intubation/extubation pair: (Timestamp('2179-08-04 13:07:00'), Timestamp('2179-08-05 11:10:00'))",
#  "sub_id:10321569, hadm_id:24124902: intubation/extubation pair: (Timestamp('2143-12-15 17:00:00'), Timestamp('2143-12-16 15:17:00'))",
#  "sub_id:10321933, hadm_id:29792275: intubation/extubation pair: (Timestamp('2119-09-09 16:50:00'), Timestamp('2119-09-11 09:28:00'))",
#  "sub_id:10332371, hadm_id:29819591: intubation/extubation pair: (Timestamp('2149-03-06 11:00:00'), Timestamp('2149-03-13 06:45:00'))",
#  "sub_id:10332371, hadm_id:29819591: intubation/extubation pair: (Timestamp('2149-03-13 07:00:00'), Timestamp('2149-03-21 12:04:00'))",
#  "sub_id:10342123, hadm_id:23603937: intubation/extubation pair: (Timestamp('2163-10-26 02:15:00'), Timestamp('2163-10-29 12:24:00'))",
#  "sub_id:10347400, hadm_id:29775800: intubation/extubation pair: (Timestamp('2161-05-20 01:35:00'), Timestamp('2161-05-23 15:30:00'))",
#  "sub_id:10347400, hadm_id:29775800: intubation/extubation pair: (Timestamp('2161-05-27 05:40:00'), Timestamp('2161-05-27 10:55:00'))",
#  "sub_id:10353094, hadm_id:24688773: intubation/extubation pair: (Timestamp('2188-10-18 14:10:00'), Timestamp('2188-10-20 09:05:00'))",
#  "sub_id:10353094, hadm_id:24688773: intubation/extubation pair: (Timestamp('2188-10-22 16:41:00'), None)",
#  "sub_id:10354450, hadm_id:28518599: intubation/extubation pair: (Timestamp('2163-08-29 03:30:00'), Timestamp('2163-09-02 23:10:00'))",
#  "sub_id:10354450, hadm_id:28518599: intubation/extubation pair: (Timestamp('2163-09-02 23:40:00'), Timestamp('2163-09-11 10:16:00'))",
#  "sub_id:10354450, hadm_id:28518599: intubation/extubation pair: (Timestamp('2163-09-11 11:34:00'), None)",
#  "sub_id:10355745, hadm_id:24924037: intubation/extubation pair: (Timestamp('2177-10-22 17:42:00'), Timestamp('2177-10-26 09:44:00'))",
#  "sub_id:10355745, hadm_id:24924037: intubation/extubation pair: (Timestamp('2177-10-26 11:00:00'), Timestamp('2177-11-01 15:58:00'))",
#  "sub_id:10355745, hadm_id:24924037: intubation/extubation pair: (Timestamp('2177-11-01 17:31:00'), None)",
#  "sub_id:10357284, hadm_id:24550737: intubation/extubation pair: (Timestamp('2133-10-06 10:50:00'), Timestamp('2133-10-08 09:00:00'))",
#  "sub_id:10357863, hadm_id:25031044: intubation/extubation pair: (Timestamp('2118-03-15 08:30:00'), Timestamp('2118-03-18 07:53:00'))",
#  "sub_id:10370642, hadm_id:28038797: intubation/extubation pair: (Timestamp('2128-12-19 05:00:00'), Timestamp('2128-12-28 12:14:00'))",
#  "sub_id:10370642, hadm_id:28038797: intubation/extubation pair: (Timestamp('2128-12-28 21:35:00'), Timestamp('2129-01-01 13:17:00'))",
#  "sub_id:10378026, hadm_id:24981696: intubation/extubation pair: (Timestamp('2129-07-26 17:00:00'), Timestamp('2129-07-28 14:00:00'))",
#  "sub_id:10388400, hadm_id:23303089: intubation/extubation pair: (Timestamp('2137-06-21 03:30:00'), Timestamp('2137-06-22 11:10:00'))",
#  "sub_id:10388400, hadm_id:23303089: intubation/extubation pair: (Timestamp('2137-07-15 11:10:00'), Timestamp('2137-07-20 12:03:00'))",
#  "sub_id:10390732, hadm_id:26272149: intubation/extubation pair: (Timestamp('2143-07-31 03:25:00'), Timestamp('2143-08-07 09:48:00'))",
#  "sub_id:10390732, hadm_id:26272149: intubation/extubation pair: (Timestamp('2143-08-09 11:22:00'), Timestamp('2143-08-13 14:30:00'))",
#  "sub_id:10400895, hadm_id:21029062: intubation/extubation pair: (Timestamp('2125-05-11 14:20:00'), Timestamp('2125-05-12 12:49:00'))",
#  "sub_id:10400895, hadm_id:21029062: intubation/extubation pair: (Timestamp('2125-05-12 18:38:00'), Timestamp('2125-05-14 08:09:00'))",
#  "sub_id:10404109, hadm_id:29867820: intubation/extubation pair: (Timestamp('2146-12-28 10:00:00'), Timestamp('2146-12-30 13:07:00'))",
#  "sub_id:10404109, hadm_id:29867820: intubation/extubation pair: (Timestamp('2146-12-30 15:00:00'), Timestamp('2146-12-31 13:00:00'))",
#  "sub_id:10407740, hadm_id:23073830: intubation/extubation pair: (Timestamp('2165-01-23 10:51:00'), Timestamp('2165-01-23 15:49:00'))",
#  "sub_id:10423466, hadm_id:24868706: intubation/extubation pair: (Timestamp('2133-07-03 17:00:00'), Timestamp('2133-07-09 18:00:00'))",
#  "sub_id:10428240, hadm_id:22917399: intubation/extubation pair: (Timestamp('2158-04-12 15:00:00'), Timestamp('2158-04-16 09:50:00'))",
#  "sub_id:10438089, hadm_id:28261508: intubation/extubation pair: (Timestamp('2120-02-16 09:15:00'), Timestamp('2120-02-22 15:50:00'))",
#  "sub_id:10438089, hadm_id:28261508: intubation/extubation pair: (Timestamp('2120-02-28 19:45:00'), Timestamp('2120-03-11 09:14:00'))",
#  "sub_id:10440245, hadm_id:23174788: intubation/extubation pair: (Timestamp('2162-08-17 22:30:00'), Timestamp('2162-08-20 15:43:00'))",
#  "sub_id:10440899, hadm_id:26609648: intubation/extubation pair: (Timestamp('2145-03-30 08:40:00'), Timestamp('2145-04-05 11:01:00'))",
#  "sub_id:10440899, hadm_id:26609648: intubation/extubation pair: (Timestamp('2145-04-06 20:25:00'), None)",
#  "sub_id:10445331, hadm_id:24253259: intubation/extubation pair: (Timestamp('2160-03-06 04:12:00'), Timestamp('2160-03-08 13:55:00'))",
#  "sub_id:10452075, hadm_id:28206315: intubation/extubation pair: (Timestamp('2111-04-06 16:53:00'), Timestamp('2111-04-06 20:49:00'))",
#  "sub_id:10452075, hadm_id:28206315: intubation/extubation pair: (Timestamp('2111-04-07 06:32:00'), Timestamp('2111-04-08 09:10:00'))",
#  "sub_id:10454567, hadm_id:23632536: intubation/extubation pair: (Timestamp('2153-02-17 11:57:00'), Timestamp('2153-02-20 12:15:00'))",
#  "sub_id:10454567, hadm_id:23632536: intubation/extubation pair: (Timestamp('2153-02-20 15:20:00'), None)",
#  "sub_id:10455694, hadm_id:29811294: intubation/extubation pair: (Timestamp('2162-04-02 14:30:00'), Timestamp('2162-04-06 15:30:00'))",
#  "sub_id:10455694, hadm_id:29811294: intubation/extubation pair: (Timestamp('2162-04-06 17:16:00'), None)",
#  "sub_id:10456513, hadm_id:24713298: intubation/extubation pair: (Timestamp('2120-03-19 15:00:00'), Timestamp('2120-03-23 10:45:00'))",
#  "sub_id:10471192, hadm_id:28299148: intubation/extubation pair: (Timestamp('2118-10-19 00:30:00'), Timestamp('2118-10-24 09:35:00'))",
#  "sub_id:10471192, hadm_id:28299148: intubation/extubation pair: (Timestamp('2118-10-27 17:45:00'), None)",
#  "sub_id:10472107, hadm_id:24126677: intubation/extubation pair: (Timestamp('2179-06-22 00:27:00'), Timestamp('2179-06-24 18:35:00'))",
#  "sub_id:10472107, hadm_id:24126677: intubation/extubation pair: (Timestamp('2179-06-24 19:30:00'), Timestamp('2179-07-14 17:31:00'))",
#  "sub_id:10480346, hadm_id:20489735: intubation/extubation pair: (Timestamp('2188-07-07 15:53:00'), Timestamp('2188-07-08 08:37:00'))",
#  "sub_id:10486056, hadm_id:26777411: intubation/extubation pair: (Timestamp('2173-07-05 07:40:00'), Timestamp('2173-07-07 14:40:00'))",
#  "sub_id:10488031, hadm_id:25655870: intubation/extubation pair: (Timestamp('2154-12-07 20:10:00'), Timestamp('2154-12-10 13:30:00'))",
#  "sub_id:10501162, hadm_id:24511516: intubation/extubation pair: (Timestamp('2191-06-23 19:16:00'), Timestamp('2191-07-07 14:00:00'))",
#  "sub_id:10510839, hadm_id:20853488: intubation/extubation pair: (Timestamp('2125-07-14 21:06:00'), Timestamp('2125-07-16 12:10:00'))",
#  "sub_id:10515638, hadm_id:24976128: intubation/extubation pair: (Timestamp('2149-08-30 13:19:00'), Timestamp('2149-09-01 11:43:00'))",
#  "sub_id:10515638, hadm_id:24976128: intubation/extubation pair: (Timestamp('2149-09-01 20:22:00'), Timestamp('2149-09-03 15:50:00'))",
#  "sub_id:10527074, hadm_id:27892723: intubation/extubation pair: (Timestamp('2171-02-11 16:37:00'), None)",
#  "sub_id:10527074, hadm_id:27892723: intubation/extubation pair: (Timestamp('2171-02-14 16:21:00'), None)",
#  "sub_id:10528589, hadm_id:22414279: intubation/extubation pair: (Timestamp('2122-10-27 06:28:00'), Timestamp('2122-10-30 09:55:00'))",
#  "sub_id:10533034, hadm_id:20901025: intubation/extubation pair: (Timestamp('2141-11-17 22:15:00'), Timestamp('2141-11-29 14:31:00'))",
#  "sub_id:10533034, hadm_id:20901025: intubation/extubation pair: (Timestamp('2141-12-02 09:06:00'), Timestamp('2141-12-15 14:30:00'))",
#  "sub_id:10545747, hadm_id:25020409: intubation/extubation pair: (Timestamp('2152-09-21 10:00:00'), Timestamp('2152-09-27 14:42:00'))",
#  "sub_id:10545967, hadm_id:27498545: intubation/extubation pair: (Timestamp('2186-05-13 18:38:00'), Timestamp('2186-05-13 20:32:00'))",
#  "sub_id:10554112, hadm_id:20318099: intubation/extubation pair: (Timestamp('2152-06-21 19:13:00'), Timestamp('2152-06-29 13:18:00'))",
#  "sub_id:10556002, hadm_id:29077178: intubation/extubation pair: (Timestamp('2160-09-20 09:00:00'), Timestamp('2160-09-21 21:18:00'))",
#  "sub_id:10556002, hadm_id:29077178: intubation/extubation pair: (Timestamp('2160-09-24 10:00:00'), None)",
#  "sub_id:10556676, hadm_id:25577156: intubation/extubation pair: (Timestamp('2163-11-04 23:30:00'), Timestamp('2163-11-12 11:50:00'))",
#  "sub_id:10556676, hadm_id:25577156: intubation/extubation pair: (Timestamp('2163-12-07 02:00:00'), None)",
#  "sub_id:10562205, hadm_id:20149612: intubation/extubation pair: (Timestamp('2149-04-30 09:30:00'), None)",
#  "sub_id:10562205, hadm_id:20149612: intubation/extubation pair: (Timestamp('2149-05-06 04:34:00'), Timestamp('2149-05-07 09:10:00'))",
#  "sub_id:10564844, hadm_id:22721259: intubation/extubation pair: (Timestamp('2137-07-25 18:15:00'), Timestamp('2137-07-26 15:28:00'))",
#  "sub_id:10566618, hadm_id:24100858: intubation/extubation pair: (Timestamp('2112-07-31 06:05:00'), None)",
#  "sub_id:10566618, hadm_id:24100858: intubation/extubation pair: (Timestamp('2112-08-04 15:16:00'), Timestamp('2112-08-05 08:34:00'))",
#  "sub_id:10570615, hadm_id:28618207: intubation/extubation pair: (Timestamp('2187-09-15 21:00:00'), Timestamp('2187-09-20 08:22:00'))",
#  "sub_id:10570615, hadm_id:28618207: intubation/extubation pair: (Timestamp('2187-09-28 10:30:00'), Timestamp('2187-09-28 17:00:00'))",
#  "sub_id:10597337, hadm_id:28427709: intubation/extubation pair: (Timestamp('2163-09-21 21:00:00'), Timestamp('2163-09-27 01:30:00'))",
#  "sub_id:10597337, hadm_id:28427709: intubation/extubation pair: (Timestamp('2163-10-03 01:20:00'), Timestamp('2163-10-10 11:39:00'))",
#  "sub_id:10625497, hadm_id:26227206: intubation/extubation pair: (Timestamp('2180-06-08 05:45:00'), Timestamp('2180-06-11 13:29:00'))",
#  "sub_id:10625497, hadm_id:26227206: intubation/extubation pair: (Timestamp('2180-06-14 11:00:00'), Timestamp('2180-06-17 09:52:00'))",
#  "sub_id:10630310, hadm_id:29121601: intubation/extubation pair: (Timestamp('2168-12-22 12:45:00'), Timestamp('2168-12-30 10:40:00'))",
#  "sub_id:10630310, hadm_id:29121601: intubation/extubation pair: (Timestamp('2168-12-30 10:47:00'), None)",
#  "sub_id:10641795, hadm_id:22739609: intubation/extubation pair: (Timestamp('2146-04-28 08:20:00'), Timestamp('2146-04-29 12:05:00'))",
#  "sub_id:10641795, hadm_id:22739609: intubation/extubation pair: (Timestamp('2146-04-29 12:35:00'), Timestamp('2146-05-06 14:00:00'))",
#  "sub_id:10641937, hadm_id:22804676: intubation/extubation pair: (Timestamp('2123-12-11 18:00:00'), Timestamp('2123-12-16 15:30:00'))",
#  "sub_id:10641937, hadm_id:22804676: intubation/extubation pair: (Timestamp('2124-01-15 15:54:00'), None)",
#  "sub_id:10650537, hadm_id:23831277: intubation/extubation pair: (Timestamp('2158-03-10 00:22:00'), Timestamp('2158-03-10 12:15:00'))",
#  "sub_id:10656173, hadm_id:25778760: intubation/extubation pair: (Timestamp('2177-09-17 14:47:00'), None)",
#  "sub_id:10656173, hadm_id:25778760: intubation/extubation pair: (Timestamp('2177-09-20 10:42:00'), None)",
#  "sub_id:10663695, hadm_id:22455973: intubation/extubation pair: (Timestamp('2139-11-13 01:45:00'), Timestamp('2139-11-25 12:33:00'))",
#  "sub_id:10667797, hadm_id:28092930: intubation/extubation pair: (Timestamp('2154-06-02 15:49:00'), Timestamp('2154-06-14 12:40:00'))",
#  "sub_id:10667797, hadm_id:28092930: intubation/extubation pair: (Timestamp('2154-06-14 17:30:00'), Timestamp('2154-06-14 23:45:00'))",
#  "sub_id:10668585, hadm_id:22652510: intubation/extubation pair: (Timestamp('2146-03-31 14:39:00'), Timestamp('2146-04-04 11:44:00'))",
#  "sub_id:10670236, hadm_id:20938672: intubation/extubation pair: (Timestamp('2185-07-27 14:56:00'), Timestamp('2185-07-31 12:25:00'))",
#  "sub_id:10670818, hadm_id:21108661: intubation/extubation pair: (Timestamp('2153-04-30 11:45:00'), Timestamp('2153-04-30 21:25:00'))",
#  "sub_id:10670818, hadm_id:21108661: intubation/extubation pair: (Timestamp('2153-05-26 11:15:00'), Timestamp('2153-07-20 20:31:00'))",
#  "sub_id:10680821, hadm_id:23326088: intubation/extubation pair: (Timestamp('2116-04-25 18:21:00'), Timestamp('2116-04-28 08:40:00'))",
#  "sub_id:10680821, hadm_id:23326088: intubation/extubation pair: (Timestamp('2116-04-29 07:30:00'), Timestamp('2116-04-30 18:00:00'))",
#  "sub_id:10684286, hadm_id:27967192: intubation/extubation pair: (Timestamp('2173-11-05 04:57:00'), Timestamp('2173-11-08 10:37:00'))",
#  "sub_id:10684286, hadm_id:27967192: intubation/extubation pair: (Timestamp('2173-11-10 05:57:00'), Timestamp('2173-11-16 11:11:00'))",
#  "sub_id:10684286, hadm_id:27967192: intubation/extubation pair: (Timestamp('2173-11-21 22:30:00'), Timestamp('2173-11-22 12:53:00'))",
#  "sub_id:10692563, hadm_id:28888564: intubation/extubation pair: (Timestamp('2193-09-10 14:50:00'), Timestamp('2193-09-12 10:20:00'))",
#  "sub_id:10698299, hadm_id:24429289: intubation/extubation pair: (Timestamp('2174-11-02 21:08:00'), Timestamp('2174-11-13 14:34:00'))",
#  "sub_id:10701573, hadm_id:24245464: intubation/extubation pair: (Timestamp('2180-08-12 21:40:00'), Timestamp('2180-08-13 10:15:00'))",
#  "sub_id:10701573, hadm_id:24245464: intubation/extubation pair: (Timestamp('2180-08-14 14:24:00'), Timestamp('2180-08-15 18:55:00'))",
#  "sub_id:10710573, hadm_id:29923776: intubation/extubation pair: (Timestamp('2114-04-19 11:30:00'), Timestamp('2114-04-23 09:26:00'))",
#  "sub_id:10712217, hadm_id:21561906: intubation/extubation pair: (Timestamp('2177-11-17 14:31:00'), None)",
#  "sub_id:10712217, hadm_id:21561906: intubation/extubation pair: (Timestamp('2177-11-22 00:51:00'), Timestamp('2177-11-23 02:58:00'))",
#  "sub_id:10712217, hadm_id:21561906: intubation/extubation pair: (Timestamp('2177-11-23 04:20:00'), Timestamp('2177-11-26 01:50:00'))",
#  "sub_id:10712217, hadm_id:21561906: intubation/extubation pair: (Timestamp('2177-11-26 02:15:00'), None)",
#  "sub_id:10714685, hadm_id:22120092: intubation/extubation pair: (Timestamp('2146-06-26 22:20:00'), None)",
#  "sub_id:10714685, hadm_id:22120092: intubation/extubation pair: (Timestamp('2146-06-28 08:00:00'), None)",
#  "sub_id:10715209, hadm_id:27459912: intubation/extubation pair: (Timestamp('2157-08-28 14:11:00'), Timestamp('2157-08-29 11:10:00'))",
#  "sub_id:10724278, hadm_id:20624205: intubation/extubation pair: (Timestamp('2116-02-20 12:39:00'), Timestamp('2116-03-06 11:56:00'))",
#  "sub_id:10728002, hadm_id:28666836: intubation/extubation pair: (Timestamp('2182-06-22 02:45:00'), Timestamp('2182-06-24 08:15:00'))",
#  "sub_id:10728002, hadm_id:28666836: intubation/extubation pair: (Timestamp('2182-07-13 06:38:00'), Timestamp('2182-07-15 11:40:00'))",
#  "sub_id:10758974, hadm_id:21950450: intubation/extubation pair: (Timestamp('2145-02-11 11:35:00'), None)",
#  "sub_id:10758974, hadm_id:21950450: intubation/extubation pair: (Timestamp('2145-02-16 09:09:00'), Timestamp('2145-02-19 08:54:00'))",
#  "sub_id:10759132, hadm_id:28549219: intubation/extubation pair: (Timestamp('2144-05-15 15:19:00'), Timestamp('2144-05-17 12:38:00'))",
#  "sub_id:10759132, hadm_id:28549219: intubation/extubation pair: (Timestamp('2144-05-17 17:15:00'), Timestamp('2144-05-27 12:00:00'))",
#  "sub_id:10760672, hadm_id:29128660: intubation/extubation pair: (Timestamp('2129-06-17 12:49:00'), Timestamp('2129-06-24 21:40:00'))",
#  "sub_id:10771068, hadm_id:21520079: intubation/extubation pair: (Timestamp('2184-10-03 19:50:00'), Timestamp('2184-10-04 13:12:00'))",
#  "sub_id:10774669, hadm_id:28120845: intubation/extubation pair: (Timestamp('2156-04-19 20:00:00'), Timestamp('2156-04-22 09:45:00'))",
#  "sub_id:10780878, hadm_id:24037790: intubation/extubation pair: (Timestamp('2114-11-12 18:41:00'), Timestamp('2114-11-12 23:55:00'))",
#  "sub_id:10780878, hadm_id:24037790: intubation/extubation pair: (Timestamp('2114-11-19 11:26:00'), Timestamp('2114-11-19 15:42:00'))",
#  "sub_id:10785608, hadm_id:28290632: intubation/extubation pair: (Timestamp('2146-05-16 11:50:00'), Timestamp('2146-05-21 08:28:00'))",
#  "sub_id:10785700, hadm_id:29123449: intubation/extubation pair: (Timestamp('2128-03-06 04:45:00'), Timestamp('2128-03-07 16:00:00'))",
#  "sub_id:10790860, hadm_id:29350861: intubation/extubation pair: (Timestamp('2198-07-18 17:27:00'), None)",
#  "sub_id:10790860, hadm_id:29350861: intubation/extubation pair: (Timestamp('2198-08-12 11:56:00'), None)",
#  "sub_id:10795507, hadm_id:25606775: intubation/extubation pair: (Timestamp('2197-01-04 20:00:00'), Timestamp('2197-01-08 17:45:00'))",
#  "sub_id:10806305, hadm_id:22042362: intubation/extubation pair: (Timestamp('2163-11-20 23:21:00'), Timestamp('2163-12-01 11:42:00'))",
#  "sub_id:10806849, hadm_id:21477011: intubation/extubation pair: (Timestamp('2119-07-13 19:03:00'), Timestamp('2119-07-18 14:54:00'))",
#  "sub_id:10806849, hadm_id:21477011: intubation/extubation pair: (Timestamp('2119-07-19 18:00:00'), Timestamp('2119-07-25 14:36:00'))",
#  "sub_id:10806973, hadm_id:20436523: intubation/extubation pair: (Timestamp('2134-11-05 05:55:00'), Timestamp('2134-11-08 03:15:00'))",
#  "sub_id:10809326, hadm_id:22350919: intubation/extubation pair: (Timestamp('2115-09-14 15:01:00'), Timestamp('2115-09-18 11:25:00'))",
#  "sub_id:10809326, hadm_id:22350919: intubation/extubation pair: (Timestamp('2115-09-18 12:38:00'), None)",
#  "sub_id:10812824, hadm_id:27693546: intubation/extubation pair: (Timestamp('2134-08-26 14:45:00'), Timestamp('2134-09-02 12:11:00'))",
#  "sub_id:10813665, hadm_id:26936609: intubation/extubation pair: (Timestamp('2174-08-15 09:16:00'), Timestamp('2174-08-18 19:33:00'))",
#  "sub_id:10814691, hadm_id:20482625: intubation/extubation pair: (Timestamp('2138-02-06 16:25:00'), Timestamp('2138-02-10 16:50:00'))",
#  "sub_id:10826174, hadm_id:21175945: intubation/extubation pair: (Timestamp('2118-01-09 02:26:00'), Timestamp('2118-01-13 15:35:00'))",
#  "sub_id:10828063, hadm_id:23207427: intubation/extubation pair: (Timestamp('2149-04-12 12:28:00'), Timestamp('2149-04-13 14:30:00'))",
#  "sub_id:10828063, hadm_id:23207427: intubation/extubation pair: (Timestamp('2149-04-18 16:40:00'), Timestamp('2149-04-26 12:10:00'))",
#  "sub_id:10833812, hadm_id:29657171: intubation/extubation pair: (Timestamp('2171-04-06 21:45:00'), Timestamp('2171-04-14 11:00:00'))",
#  "sub_id:10834132, hadm_id:23607054: intubation/extubation pair: (Timestamp('2178-07-03 16:30:00'), Timestamp('2178-07-05 08:05:00'))",
#  "sub_id:10839217, hadm_id:23110547: intubation/extubation pair: (Timestamp('2160-11-12 16:30:00'), Timestamp('2160-11-16 10:51:00'))",
#  "sub_id:10839217, hadm_id:23110547: intubation/extubation pair: (Timestamp('2160-11-23 12:55:00'), Timestamp('2160-12-02 10:49:00'))",
#  "sub_id:10839217, hadm_id:23110547: intubation/extubation pair: (Timestamp('2160-12-08 01:00:00'), Timestamp('2160-12-11 12:15:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-02-15 09:00:00'), Timestamp('2133-02-18 10:10:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-02-21 09:55:00'), Timestamp('2133-02-21 15:21:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-02-24 12:15:00'), Timestamp('2133-02-25 12:40:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-03-04 05:40:00'), Timestamp('2133-03-06 18:20:00'))",
#  "sub_id:10850048, hadm_id:22784596: intubation/extubation pair: (Timestamp('2133-03-07 05:15:00'), None)",
#  "sub_id:10850815, hadm_id:29529191: intubation/extubation pair: (Timestamp('2143-08-02 18:50:00'), Timestamp('2143-08-08 08:10:00'))",
#  "sub_id:10850815, hadm_id:29529191: intubation/extubation pair: (Timestamp('2143-08-10 13:56:00'), Timestamp('2143-08-12 15:15:00'))",
#  "sub_id:10853896, hadm_id:23383004: intubation/extubation pair: (Timestamp('2176-08-30 16:15:00'), Timestamp('2176-09-01 08:46:00'))",
#  "sub_id:10865504, hadm_id:20772091: intubation/extubation pair: (Timestamp('2178-12-10 01:00:00'), Timestamp('2178-12-14 12:24:00'))",
#  "sub_id:10865504, hadm_id:20772091: intubation/extubation pair: (Timestamp('2179-02-13 15:25:00'), Timestamp('2179-02-24 11:09:00'))",
#  "sub_id:10867981, hadm_id:20831772: intubation/extubation pair: (Timestamp('2168-09-07 14:10:00'), Timestamp('2168-09-10 16:30:00'))",
#  "sub_id:10874066, hadm_id:29765862: intubation/extubation pair: (Timestamp('2156-12-28 23:54:00'), Timestamp('2157-01-01 11:37:00'))",
#  "sub_id:10874066, hadm_id:29765862: intubation/extubation pair: (Timestamp('2157-01-05 03:40:00'), None)",
#  "sub_id:10878238, hadm_id:26780052: intubation/extubation pair: (Timestamp('2143-05-11 22:30:00'), Timestamp('2143-05-12 09:18:00'))",
#  "sub_id:10886970, hadm_id:26397173: intubation/extubation pair: (Timestamp('2144-07-25 05:30:00'), Timestamp('2144-07-25 09:30:00'))",
#  "sub_id:10886970, hadm_id:26397173: intubation/extubation pair: (Timestamp('2144-07-25 09:31:00'), Timestamp('2144-07-25 12:45:00'))",
#  "sub_id:10887901, hadm_id:28942534: intubation/extubation pair: (Timestamp('2171-09-29 19:00:00'), Timestamp('2171-10-05 13:20:00'))",
#  "sub_id:10900129, hadm_id:22036881: intubation/extubation pair: (Timestamp('2140-09-06 02:45:00'), Timestamp('2140-09-06 09:48:00'))",
#  "sub_id:10900129, hadm_id:22036881: intubation/extubation pair: (Timestamp('2140-09-13 00:00:00'), Timestamp('2140-09-21 17:50:00'))",
#  "sub_id:10900387, hadm_id:28246942: intubation/extubation pair: (Timestamp('2149-03-14 08:35:00'), Timestamp('2149-03-16 15:03:00'))",
#  "sub_id:10907695, hadm_id:28491009: intubation/extubation pair: (Timestamp('2151-11-15 15:24:00'), Timestamp('2151-11-16 11:09:00'))",
#  "sub_id:10910344, hadm_id:22604063: intubation/extubation pair: (Timestamp('2162-12-27 13:20:00'), Timestamp('2163-01-05 14:56:00'))",
#  "sub_id:10910797, hadm_id:23479816: intubation/extubation pair: (Timestamp('2142-01-13 23:45:00'), Timestamp('2142-01-17 16:00:00'))",
#  "sub_id:10911270, hadm_id:26543072: intubation/extubation pair: (Timestamp('2180-03-11 04:15:00'), None)",
#  "sub_id:10911270, hadm_id:26543072: intubation/extubation pair: (Timestamp('2180-03-14 22:34:00'), Timestamp('2180-03-17 13:05:00'))",
#  "sub_id:10914662, hadm_id:22281276: intubation/extubation pair: (Timestamp('2188-07-25 14:43:00'), Timestamp('2188-07-25 20:10:00'))",
#  "sub_id:10914662, hadm_id:22281276: intubation/extubation pair: (Timestamp('2188-07-26 03:30:00'), Timestamp('2188-07-27 08:56:00'))",
#  "sub_id:10918410, hadm_id:23928677: intubation/extubation pair: (Timestamp('2149-07-02 20:45:00'), Timestamp('2149-07-04 11:55:00'))",
#  "sub_id:10921049, hadm_id:26528195: intubation/extubation pair: (Timestamp('2141-01-06 11:17:00'), Timestamp('2141-01-06 15:06:00'))",
#  "sub_id:10921049, hadm_id:26528195: intubation/extubation pair: (Timestamp('2141-01-08 15:19:00'), Timestamp('2141-01-08 17:40:00'))",
#  "sub_id:10923536, hadm_id:23384208: intubation/extubation pair: (Timestamp('2154-07-09 10:00:00'), None)",
#  "sub_id:10923536, hadm_id:23384208: intubation/extubation pair: (Timestamp('2154-07-10 21:00:00'), Timestamp('2154-07-15 11:00:00'))",
#  "sub_id:10930214, hadm_id:21441177: intubation/extubation pair: (Timestamp('2191-05-20 10:45:00'), Timestamp('2191-05-27 12:16:00'))",
#  "sub_id:10930214, hadm_id:21441177: intubation/extubation pair: (Timestamp('2191-05-27 13:55:00'), None)",
#  "sub_id:10932961, hadm_id:22658799: intubation/extubation pair: (Timestamp('2151-09-30 21:00:00'), Timestamp('2151-10-07 13:53:00'))",
#  "sub_id:10935357, hadm_id:20085117: intubation/extubation pair: (Timestamp('2155-08-24 08:45:00'), Timestamp('2155-08-25 11:44:00'))",
#  "sub_id:10935357, hadm_id:20085117: intubation/extubation pair: (Timestamp('2155-09-08 16:15:00'), Timestamp('2155-09-14 00:31:00'))",
#  "sub_id:10939299, hadm_id:26422493: intubation/extubation pair: (Timestamp('2184-04-17 11:16:00'), Timestamp('2184-04-18 14:36:00'))",
#  "sub_id:10947245, hadm_id:24307798: intubation/extubation pair: (Timestamp('2136-10-20 17:28:00'), Timestamp('2136-11-07 12:16:00'))",
#  "sub_id:10954764, hadm_id:23274056: intubation/extubation pair: (Timestamp('2125-06-11 15:59:00'), Timestamp('2125-06-17 16:05:00'))",
#  "sub_id:10954764, hadm_id:23274056: intubation/extubation pair: (Timestamp('2125-07-03 11:58:00'), Timestamp('2125-07-06 15:07:00'))",
#  "sub_id:10975446, hadm_id:29433790: intubation/extubation pair: (Timestamp('2183-02-12 17:00:00'), Timestamp('2183-02-19 15:00:00'))",
#  "sub_id:10980029, hadm_id:22180118: intubation/extubation pair: (Timestamp('2137-03-01 07:25:00'), Timestamp('2137-03-10 12:17:00'))",
#  "sub_id:10985511, hadm_id:29883624: intubation/extubation pair: (Timestamp('2178-02-06 10:20:00'), Timestamp('2178-02-10 10:00:00'))",
#  "sub_id:10985511, hadm_id:29883624: intubation/extubation pair: (Timestamp('2178-02-21 18:01:00'), Timestamp('2178-02-28 10:30:00'))",
#  "sub_id:10989760, hadm_id:21430515: intubation/extubation pair: (Timestamp('2159-03-24 21:06:00'), Timestamp('2159-04-03 17:06:00'))",
#  "sub_id:10990398, hadm_id:27541056: intubation/extubation pair: (Timestamp('2175-12-15 16:51:00'), Timestamp('2175-12-18 15:23:00'))",
#  "sub_id:10992783, hadm_id:25268342: intubation/extubation pair: (Timestamp('2178-01-23 12:15:00'), Timestamp('2178-02-01 09:50:00'))",
#  "sub_id:10992783, hadm_id:25268342: intubation/extubation pair: (Timestamp('2178-02-05 07:37:00'), Timestamp('2178-02-10 15:18:00'))",
#  "sub_id:10999395, hadm_id:22094873: intubation/extubation pair: (Timestamp('2148-03-17 02:40:00'), Timestamp('2148-03-18 13:22:00'))",
#  "sub_id:11017644, hadm_id:21621302: intubation/extubation pair: (Timestamp('2174-01-19 04:30:00'), Timestamp('2174-01-24 07:55:00'))",
#  "sub_id:11017644, hadm_id:21621302: intubation/extubation pair: (Timestamp('2174-01-25 20:45:00'), Timestamp('2174-01-28 16:15:00'))",
#  "sub_id:11017644, hadm_id:21621302: intubation/extubation pair: (Timestamp('2174-01-28 16:26:00'), Timestamp('2174-01-30 08:52:00'))",
#  "sub_id:11018073, hadm_id:23761571: intubation/extubation pair: (Timestamp('2157-01-22 09:00:00'), Timestamp('2157-01-27 17:00:00'))",
#  "sub_id:11018073, hadm_id:23761571: intubation/extubation pair: (Timestamp('2157-02-25 13:09:00'), Timestamp('2157-02-27 08:17:00'))",
#  "sub_id:11018073, hadm_id:23761571: intubation/extubation pair: (Timestamp('2157-05-13 05:11:00'), Timestamp('2157-05-25 14:17:00'))",
#  "sub_id:11020202, hadm_id:27311676: intubation/extubation pair: (Timestamp('2121-03-06 14:15:00'), Timestamp('2121-03-19 14:45:00'))",
#  "sub_id:11020202, hadm_id:27311676: intubation/extubation pair: (Timestamp('2121-03-19 14:50:00'), Timestamp('2121-03-20 04:35:00'))",
#  "sub_id:11020202, hadm_id:27311676: intubation/extubation pair: (Timestamp('2121-03-20 04:40:00'), Timestamp('2121-03-21 10:12:00'))",
#  "sub_id:11030576, hadm_id:21648828: intubation/extubation pair: (Timestamp('2171-10-14 22:20:00'), Timestamp('2171-10-16 11:44:00'))",
#  "sub_id:11034210, hadm_id:28107091: intubation/extubation pair: (Timestamp('2152-11-12 20:10:00'), None)",
#  "sub_id:11034210, hadm_id:28107091: intubation/extubation pair: (Timestamp('2152-11-25 12:14:00'), Timestamp('2152-11-27 11:50:00'))",
#  "sub_id:11038253, hadm_id:25065906: intubation/extubation pair: (Timestamp('2114-12-15 18:30:00'), Timestamp('2114-12-19 16:15:00'))",
#  "sub_id:11042885, hadm_id:22299146: intubation/extubation pair: (Timestamp('2169-10-12 10:00:00'), Timestamp('2169-10-18 13:51:00'))",
#  "sub_id:11042885, hadm_id:22299146: intubation/extubation pair: (Timestamp('2169-10-19 18:30:00'), Timestamp('2169-11-01 20:30:00'))",
#  "sub_id:11044946, hadm_id:20017989: intubation/extubation pair: (Timestamp('2125-08-11 03:00:00'), Timestamp('2125-08-12 13:45:00'))",
#  "sub_id:11064566, hadm_id:26586602: intubation/extubation pair: (Timestamp('2146-10-13 06:30:00'), Timestamp('2146-10-17 06:30:00'))",
#  "sub_id:11064566, hadm_id:26586602: intubation/extubation pair: (Timestamp('2146-10-17 06:45:00'), None)",
#  "sub_id:11065431, hadm_id:21554363: intubation/extubation pair: (Timestamp('2181-04-16 14:13:00'), Timestamp('2181-04-22 14:30:00'))",
#  "sub_id:11065431, hadm_id:21554363: intubation/extubation pair: (Timestamp('2181-04-24 00:49:00'), None)",
#  "sub_id:11067215, hadm_id:23574374: intubation/extubation pair: (Timestamp('2168-05-01 11:30:00'), Timestamp('2168-05-07 07:10:00'))",
#  "sub_id:11067215, hadm_id:23574374: intubation/extubation pair: (Timestamp('2168-05-11 17:13:00'), Timestamp('2168-05-18 18:00:00'))",
#  "sub_id:11070185, hadm_id:24518501: intubation/extubation pair: (Timestamp('2122-12-23 17:07:00'), Timestamp('2122-12-28 08:49:00'))",
#  "sub_id:11074407, hadm_id:22457623: intubation/extubation pair: (Timestamp('2111-09-21 14:16:00'), Timestamp('2111-09-23 14:42:00'))",
#  "sub_id:11074407, hadm_id:22457623: intubation/extubation pair: (Timestamp('2111-09-25 09:30:00'), Timestamp('2111-09-30 12:00:00'))",
#  "sub_id:11076206, hadm_id:21257601: intubation/extubation pair: (Timestamp('2188-03-15 13:30:00'), Timestamp('2188-03-23 15:54:00'))",
#  "sub_id:11087410, hadm_id:25148713: intubation/extubation pair: (Timestamp('2147-12-31 22:20:00'), Timestamp('2148-01-03 18:19:00'))",
#  "sub_id:11095636, hadm_id:21937919: intubation/extubation pair: (Timestamp('2118-02-20 19:00:00'), Timestamp('2118-02-24 09:50:00'))",
#  "sub_id:11111901, hadm_id:29789360: intubation/extubation pair: (Timestamp('2163-12-29 15:00:00'), None)",
#  "sub_id:11111901, hadm_id:29789360: intubation/extubation pair: (Timestamp('2164-01-02 03:00:00'), None)",
#  "sub_id:11111901, hadm_id:29789360: intubation/extubation pair: (Timestamp('2164-01-04 10:00:00'), Timestamp('2164-01-10 09:56:00'))",
#  "sub_id:11117353, hadm_id:20679385: intubation/extubation pair: (Timestamp('2124-12-31 12:20:00'), None)",
#  "sub_id:11117353, hadm_id:20679385: intubation/extubation pair: (Timestamp('2125-01-03 19:50:00'), None)",
#  "sub_id:11121817, hadm_id:20802314: intubation/extubation pair: (Timestamp('2188-07-26 20:00:00'), Timestamp('2188-07-28 11:00:00'))",
#  "sub_id:11122975, hadm_id:20098892: intubation/extubation pair: (Timestamp('2155-04-30 23:15:00'), Timestamp('2155-05-01 13:18:00'))",
#  "sub_id:11134447, hadm_id:29068519: intubation/extubation pair: (Timestamp('2115-12-04 16:00:00'), Timestamp('2115-12-12 11:50:00'))",
#  "sub_id:11168650, hadm_id:23065690: intubation/extubation pair: (Timestamp('2138-03-07 03:40:00'), Timestamp('2138-03-07 15:15:00'))",
#  "sub_id:11168650, hadm_id:23065690: intubation/extubation pair: (Timestamp('2138-03-18 15:00:00'), None)",
#  "sub_id:11168650, hadm_id:26714990: intubation/extubation pair: (Timestamp('2129-11-10 19:30:00'), Timestamp('2129-11-14 16:40:00'))",
#  "sub_id:11168650, hadm_id:26714990: intubation/extubation pair: (Timestamp('2129-11-15 10:36:00'), None)",
#  "sub_id:11172546, hadm_id:25035599: intubation/extubation pair: (Timestamp('2181-12-12 10:30:00'), Timestamp('2181-12-12 11:45:00'))",
#  "sub_id:11172546, hadm_id:25035599: intubation/extubation pair: (Timestamp('2181-12-23 15:15:00'), Timestamp('2181-12-28 13:30:00'))",
#  "sub_id:11180585, hadm_id:20551749: intubation/extubation pair: (Timestamp('2140-10-15 23:15:00'), Timestamp('2140-10-18 16:00:00'))",
#  "sub_id:11181757, hadm_id:25175936: intubation/extubation pair: (Timestamp('2130-03-07 10:44:00'), Timestamp('2130-03-08 14:50:00'))",
#  "sub_id:11181757, hadm_id:25175936: intubation/extubation pair: (Timestamp('2130-03-24 23:20:00'), None)",
#  "sub_id:11182151, hadm_id:22537178: intubation/extubation pair: (Timestamp('2164-12-30 10:45:00'), Timestamp('2165-01-01 14:25:00'))",
#  "sub_id:11182632, hadm_id:20409313: intubation/extubation pair: (Timestamp('2129-10-16 01:12:00'), Timestamp('2129-10-17 23:20:00'))",
#  "sub_id:11186225, hadm_id:26338291: intubation/extubation pair: (Timestamp('2183-10-18 11:48:00'), Timestamp('2183-11-07 13:45:00'))",
#  "sub_id:11191438, hadm_id:20179421: intubation/extubation pair: (Timestamp('2112-01-03 16:47:00'), Timestamp('2112-01-04 18:00:00'))",
#  "sub_id:11191438, hadm_id:20179421: intubation/extubation pair: (Timestamp('2112-01-06 12:35:00'), Timestamp('2112-01-06 17:54:00'))",
#  "sub_id:11191438, hadm_id:20179421: intubation/extubation pair: (Timestamp('2112-01-06 18:15:00'), Timestamp('2112-01-07 17:01:00'))",
#  "sub_id:11204116, hadm_id:29628229: intubation/extubation pair: (Timestamp('2145-08-09 10:30:00'), Timestamp('2145-08-10 10:50:00'))",
#  "sub_id:11204116, hadm_id:29628229: intubation/extubation pair: (Timestamp('2145-08-13 00:50:00'), None)",
#  "sub_id:11205852, hadm_id:24128477: intubation/extubation pair: (Timestamp('2172-05-11 19:55:00'), None)",
#  "sub_id:11205852, hadm_id:24128477: intubation/extubation pair: (Timestamp('2172-05-18 09:12:00'), Timestamp('2172-05-25 18:36:00'))",
#  "sub_id:11213546, hadm_id:26189768: intubation/extubation pair: (Timestamp('2183-05-18 12:15:00'), Timestamp('2183-05-26 14:21:00'))",
#  "sub_id:11213546, hadm_id:26189768: intubation/extubation pair: (Timestamp('2183-05-31 20:35:00'), Timestamp('2183-06-03 04:34:00'))",
#  "sub_id:11216986, hadm_id:22969970: intubation/extubation pair: (Timestamp('2190-02-09 12:25:00'), Timestamp('2190-02-10 16:27:00'))",
#  "sub_id:11216986, hadm_id:22969970: intubation/extubation pair: (Timestamp('2190-03-19 13:59:00'), None)",
#  "sub_id:11219861, hadm_id:22198294: intubation/extubation pair: (Timestamp('2132-06-29 11:50:00'), Timestamp('2132-06-29 18:00:00'))",
#  "sub_id:11219861, hadm_id:22198294: intubation/extubation pair: (Timestamp('2132-07-01 02:21:00'), Timestamp('2132-07-03 08:16:00'))",
#  "sub_id:11230452, hadm_id:25832117: intubation/extubation pair: (Timestamp('2128-04-18 11:50:00'), Timestamp('2128-04-27 08:00:00'))",
#  "sub_id:11230452, hadm_id:25832117: intubation/extubation pair: (Timestamp('2128-05-02 23:00:00'), None)",
#  "sub_id:11239107, hadm_id:25883588: intubation/extubation pair: (Timestamp('2113-01-16 09:10:00'), Timestamp('2113-01-24 09:33:00'))",
#  "sub_id:11239107, hadm_id:25883588: intubation/extubation pair: (Timestamp('2113-01-31 12:45:00'), None)",
#  "sub_id:11258077, hadm_id:28500459: intubation/extubation pair: (Timestamp('2184-06-16 09:30:00'), Timestamp('2184-06-25 08:45:00'))",
#  "sub_id:11258077, hadm_id:28500459: intubation/extubation pair: (Timestamp('2184-06-25 09:00:00'), Timestamp('2184-07-02 11:17:00'))",
#  "sub_id:11258077, hadm_id:28500459: intubation/extubation pair: (Timestamp('2184-07-02 14:59:00'), None)",
#  "sub_id:11262853, hadm_id:20941131: intubation/extubation pair: (Timestamp('2178-05-04 18:59:00'), Timestamp('2178-05-08 16:21:00'))",
#  "sub_id:11269805, hadm_id:29844758: intubation/extubation pair: (Timestamp('2167-06-19 20:45:00'), Timestamp('2167-06-20 18:46:00'))",
#  "sub_id:11275795, hadm_id:21305184: intubation/extubation pair: (Timestamp('2147-03-10 00:02:00'), None)",
#  "sub_id:11275795, hadm_id:21305184: intubation/extubation pair: (Timestamp('2147-03-12 21:44:00'), Timestamp('2147-03-13 17:54:00'))",
#  "sub_id:11275795, hadm_id:21305184: intubation/extubation pair: (Timestamp('2147-03-15 09:55:00'), None)",
#  "sub_id:11288013, hadm_id:21287757: intubation/extubation pair: (Timestamp('2121-12-18 16:30:00'), None)",
#  "sub_id:11291823, hadm_id:21259664: intubation/extubation pair: (Timestamp('2112-08-19 03:39:00'), None)",
#  "sub_id:11291823, hadm_id:21259664: intubation/extubation pair: (Timestamp('2112-08-22 20:10:00'), Timestamp('2112-08-22 20:18:00'))",
#  "sub_id:11291823, hadm_id:22586748: intubation/extubation pair: (Timestamp('2115-12-18 22:40:00'), Timestamp('2115-12-24 14:07:00'))",
#  "sub_id:11291823, hadm_id:22586748: intubation/extubation pair: (Timestamp('2116-01-07 16:00:00'), Timestamp('2116-01-09 10:00:00'))",
#  "sub_id:11293517, hadm_id:21799365: intubation/extubation pair: (Timestamp('2165-11-04 19:08:00'), Timestamp('2165-11-14 15:48:00'))",
#  "sub_id:11293517, hadm_id:21799365: intubation/extubation pair: (Timestamp('2165-11-23 15:00:00'), None)",
#  "sub_id:11300581, hadm_id:29747297: intubation/extubation pair: (Timestamp('2120-03-22 03:30:00'), Timestamp('2120-03-27 15:13:00'))",
#  "sub_id:11300581, hadm_id:29747297: intubation/extubation pair: (Timestamp('2120-03-30 13:40:00'), None)",
#  "sub_id:11301473, hadm_id:26488073: intubation/extubation pair: (Timestamp('2163-06-23 12:35:00'), Timestamp('2163-06-24 17:08:00'))",
#  "sub_id:11304959, hadm_id:22713043: intubation/extubation pair: (Timestamp('2200-01-05 11:40:00'), Timestamp('2200-01-09 12:19:00'))",
#  "sub_id:11312196, hadm_id:20569926: intubation/extubation pair: (Timestamp('2139-01-23 12:25:00'), Timestamp('2139-01-28 18:33:00'))",
#  "sub_id:11326229, hadm_id:20635802: intubation/extubation pair: (Timestamp('2137-06-01 17:15:00'), None)",
#  "sub_id:11326229, hadm_id:20635802: intubation/extubation pair: (Timestamp('2137-06-06 09:00:00'), None)",
#  "sub_id:11326660, hadm_id:25434637: intubation/extubation pair: (Timestamp('2177-03-02 11:30:00'), Timestamp('2177-03-03 12:32:00'))",
#  "sub_id:11326660, hadm_id:25434637: intubation/extubation pair: (Timestamp('2177-03-13 11:40:00'), Timestamp('2177-03-29 18:00:00'))",
#  "sub_id:11326660, hadm_id:25434637: intubation/extubation pair: (Timestamp('2177-03-30 06:50:00'), Timestamp('2177-04-02 13:50:00'))",
#  "sub_id:11326660, hadm_id:25434637: intubation/extubation pair: (Timestamp('2177-04-07 01:00:00'), None)",
# ...
#  "sub_id:13090343, hadm_id:21316933: intubation/extubation pair: (Timestamp('2173-08-10 23:41:00'), Timestamp('2173-08-26 13:45:00'))",
#  "sub_id:13090343, hadm_id:21316933: intubation/extubation pair: (Timestamp('2173-08-27 08:00:00'), Timestamp('2173-08-28 11:45:00'))",
#  "sub_id:13110443, hadm_id:25130175: intubation/extubation pair: (Timestamp('2191-11-16 15:10:00'), Timestamp('2191-11-19 14:50:00'))",
#  "sub_id:13110443, hadm_id:25130175: intubation/extubation pair: (Timestamp('2191-11-19 14:59:00'), None)",
#  "sub_id:13114102, hadm_id:23387876: intubation/extubation pair: (Timestamp('2168-05-12 13:00:00'), Timestamp('2168-05-17 02:30:00'))",
#  "sub_id:13121870, hadm_id:27370800: intubation/extubation pair: (Timestamp('2171-10-05 15:15:00'), None)",
#  "sub_id:13121870, hadm_id:27370800: intubation/extubation pair: (Timestamp('2171-10-09 02:50:00'), None)",
#  "sub_id:13122945, hadm_id:22242120: intubation/extubation pair: (Timestamp('2138-02-25 17:19:00'), Timestamp('2138-02-28 08:45:00'))",
#  "sub_id:13122945, hadm_id:22242120: intubation/extubation pair: (Timestamp('2138-03-02 01:20:00'), None)",
#  "sub_id:13134081, hadm_id:20906131: intubation/extubation pair: (Timestamp('2113-03-16 04:01:00'), Timestamp('2113-03-17 15:12:00'))",
#  "sub_id:13135946, hadm_id:22133572: intubation/extubation pair: (Timestamp('2143-08-07 15:06:00'), Timestamp('2143-08-12 09:47:00'))",
#  "sub_id:13135946, hadm_id:22133572: intubation/extubation pair: (Timestamp('2143-08-14 12:07:00'), None)",
#  "sub_id:13138475, hadm_id:29847750: intubation/extubation pair: (Timestamp('2143-09-13 23:43:00'), None)",
#  "sub_id:13138475, hadm_id:29847750: intubation/extubation pair: (Timestamp('2143-09-17 02:45:00'), Timestamp('2143-09-18 15:45:00'))",
#  "sub_id:13138475, hadm_id:29847750: intubation/extubation pair: (Timestamp('2143-09-25 12:35:00'), None)",
#  "sub_id:13142166, hadm_id:21649104: intubation/extubation pair: (Timestamp('2174-03-12 10:30:00'), Timestamp('2174-03-14 10:15:00'))",
#  "sub_id:13142166, hadm_id:21649104: intubation/extubation pair: (Timestamp('2174-03-16 11:40:00'), Timestamp('2174-03-19 11:18:00'))",
#  "sub_id:13155939, hadm_id:25316345: intubation/extubation pair: (Timestamp('2189-05-19 07:35:00'), Timestamp('2189-05-20 21:04:00'))",
#  "sub_id:13155939, hadm_id:25316345: intubation/extubation pair: (Timestamp('2189-05-22 01:30:00'), Timestamp('2189-05-24 09:59:00'))",
#  "sub_id:13157621, hadm_id:21295657: intubation/extubation pair: (Timestamp('2121-10-19 07:50:00'), None)",
#  "sub_id:13157621, hadm_id:21295657: intubation/extubation pair: (Timestamp('2121-10-19 14:43:00'), Timestamp('2121-10-20 10:20:00'))",
#  "sub_id:13159019, hadm_id:24067663: intubation/extubation pair: (Timestamp('2139-11-10 08:30:00'), Timestamp('2139-11-11 14:13:00'))",
#  "sub_id:13164041, hadm_id:29039690: intubation/extubation pair: (Timestamp('2126-11-22 15:30:00'), None)",
#  "sub_id:13164041, hadm_id:29039690: intubation/extubation pair: (Timestamp('2126-12-01 15:49:00'), None)",
#  "sub_id:13164041, hadm_id:29039690: intubation/extubation pair: (Timestamp('2126-12-15 21:10:00'), Timestamp('2126-12-24 18:32:00'))",
#  "sub_id:13180512, hadm_id:24527016: intubation/extubation pair: (Timestamp('2151-04-19 16:40:00'), Timestamp('2151-04-25 13:30:00'))",
#  "sub_id:13182275, hadm_id:20284049: intubation/extubation pair: (Timestamp('2176-08-08 01:45:00'), Timestamp('2176-08-08 11:00:00'))",
#  "sub_id:13182275, hadm_id:20284049: intubation/extubation pair: (Timestamp('2176-08-08 17:15:00'), Timestamp('2176-08-12 13:00:00'))",
#  "sub_id:13188363, hadm_id:24879827: intubation/extubation pair: (Timestamp('2152-01-31 19:00:00'), Timestamp('2152-02-01 16:55:00'))",
#  "sub_id:13188363, hadm_id:24879827: intubation/extubation pair: (Timestamp('2152-02-03 20:47:00'), Timestamp('2152-04-01 14:14:00'))",
#  "sub_id:13188363, hadm_id:24879827: intubation/extubation pair: (Timestamp('2152-05-17 05:00:00'), None)",
#  "sub_id:13191989, hadm_id:28038618: intubation/extubation pair: (Timestamp('2116-11-29 18:25:00'), None)",
#  "sub_id:13191989, hadm_id:28038618: intubation/extubation pair: (Timestamp('2116-12-08 03:00:00'), Timestamp('2116-12-31 17:00:00'))",
#  "sub_id:13208026, hadm_id:20866231: intubation/extubation pair: (Timestamp('2166-01-29 13:30:00'), Timestamp('2166-02-01 12:45:00'))",
#  "sub_id:13208026, hadm_id:20866231: intubation/extubation pair: (Timestamp('2166-02-01 12:58:00'), Timestamp('2166-02-04 13:30:00'))",
#  "sub_id:13209752, hadm_id:21771189: intubation/extubation pair: (Timestamp('2165-12-04 10:30:00'), Timestamp('2165-12-21 08:00:00'))",
#  "sub_id:13210714, hadm_id:21705823: intubation/extubation pair: (Timestamp('2159-04-30 12:59:00'), Timestamp('2159-05-01 16:12:00'))",
#  "sub_id:13216259, hadm_id:20347425: intubation/extubation pair: (Timestamp('2138-10-12 07:20:00'), Timestamp('2138-10-14 12:15:00'))",
#  "sub_id:13224377, hadm_id:21807194: intubation/extubation pair: (Timestamp('2135-02-14 15:40:00'), Timestamp('2135-02-14 16:30:00'))",
#  "sub_id:13224377, hadm_id:21807194: intubation/extubation pair: (Timestamp('2135-03-09 16:00:00'), Timestamp('2135-03-17 13:10:00'))",
#  "sub_id:13224377, hadm_id:21807194: intubation/extubation pair: (Timestamp('2135-05-12 16:20:00'), None)",
#  "sub_id:13231528, hadm_id:26933831: intubation/extubation pair: (Timestamp('2185-06-17 23:23:00'), Timestamp('2185-06-24 22:00:00'))",
#  "sub_id:13231528, hadm_id:26933831: intubation/extubation pair: (Timestamp('2185-06-24 22:15:00'), Timestamp('2185-06-26 08:10:00'))",
#  "sub_id:13231630, hadm_id:26950311: intubation/extubation pair: (Timestamp('2186-08-13 12:45:00'), Timestamp('2186-08-14 12:20:00'))",
#  "sub_id:13231630, hadm_id:26950311: intubation/extubation pair: (Timestamp('2186-08-16 13:34:00'), None)",
#  "sub_id:13247581, hadm_id:26936299: intubation/extubation pair: (Timestamp('2143-06-16 14:11:00'), None)",
#  "sub_id:13247581, hadm_id:26936299: intubation/extubation pair: (Timestamp('2143-06-17 19:28:00'), Timestamp('2143-06-19 08:07:00'))",
#  "sub_id:13247654, hadm_id:25929133: intubation/extubation pair: (Timestamp('2121-01-10 18:00:00'), Timestamp('2121-01-11 14:20:00'))",
#  "sub_id:13247654, hadm_id:25929133: intubation/extubation pair: (Timestamp('2121-01-12 08:10:00'), Timestamp('2121-01-13 11:00:00'))",
#  "sub_id:13251286, hadm_id:20115323: intubation/extubation pair: (Timestamp('2144-11-07 15:00:00'), Timestamp('2144-11-08 13:15:00'))",
#  "sub_id:13256955, hadm_id:28710762: intubation/extubation pair: (Timestamp('2189-11-05 02:50:00'), Timestamp('2189-11-05 13:54:00'))",
#  "sub_id:13276959, hadm_id:29535509: intubation/extubation pair: (Timestamp('2138-08-25 17:34:00'), Timestamp('2138-08-27 11:45:00'))",
#  "sub_id:13276959, hadm_id:29535509: intubation/extubation pair: (Timestamp('2138-08-27 11:55:00'), Timestamp('2138-08-31 10:45:00'))",
#  "sub_id:13276959, hadm_id:29535509: intubation/extubation pair: (Timestamp('2138-09-02 17:00:00'), Timestamp('2138-09-04 10:00:00'))",
#  "sub_id:13280368, hadm_id:25603270: intubation/extubation pair: (Timestamp('2129-01-20 10:49:00'), None)",
#  "sub_id:13280368, hadm_id:25603270: intubation/extubation pair: (Timestamp('2129-01-31 16:46:00'), Timestamp('2129-02-02 15:34:00'))",
#  "sub_id:13283178, hadm_id:26706273: intubation/extubation pair: (Timestamp('2127-03-06 07:45:00'), Timestamp('2127-03-06 22:30:00'))",
#  "sub_id:13283178, hadm_id:26706273: intubation/extubation pair: (Timestamp('2127-03-07 00:10:00'), Timestamp('2127-03-09 10:15:00'))",
#  "sub_id:13287489, hadm_id:25580332: intubation/extubation pair: (Timestamp('2186-11-06 12:45:00'), Timestamp('2186-11-12 17:02:00'))",
#  "sub_id:13299285, hadm_id:21822177: intubation/extubation pair: (Timestamp('2178-01-11 11:55:00'), Timestamp('2178-01-20 13:00:00'))",
#  "sub_id:13299285, hadm_id:21822177: intubation/extubation pair: (Timestamp('2178-02-09 01:30:00'), None)",
#  "sub_id:13301272, hadm_id:20413622: intubation/extubation pair: (Timestamp('2146-05-06 20:30:00'), Timestamp('2146-05-08 23:11:00'))",
#  "sub_id:13312252, hadm_id:29667896: intubation/extubation pair: (Timestamp('2156-06-21 16:21:00'), Timestamp('2156-06-25 15:39:00'))",
#  "sub_id:13322057, hadm_id:25653494: intubation/extubation pair: (Timestamp('2173-11-24 00:55:00'), Timestamp('2173-11-26 12:49:00'))",
#  "sub_id:13326473, hadm_id:28930686: intubation/extubation pair: (Timestamp('2158-07-30 04:20:00'), Timestamp('2158-07-30 06:45:00'))",
#  "sub_id:13331269, hadm_id:20297853: intubation/extubation pair: (Timestamp('2123-04-06 18:00:00'), None)",
#  "sub_id:13331269, hadm_id:20297853: intubation/extubation pair: (Timestamp('2123-04-06 19:03:00'), None)",
#  "sub_id:13335237, hadm_id:29435960: intubation/extubation pair: (Timestamp('2186-09-26 15:00:00'), Timestamp('2186-09-30 17:50:00'))",
#  "sub_id:13336511, hadm_id:28936109: intubation/extubation pair: (Timestamp('2160-09-25 05:46:00'), Timestamp('2160-09-26 08:57:00'))",
#  "sub_id:13345716, hadm_id:26291980: intubation/extubation pair: (Timestamp('2134-05-30 21:50:00'), Timestamp('2134-06-05 09:25:00'))",
#  "sub_id:13345716, hadm_id:26291980: intubation/extubation pair: (Timestamp('2134-06-05 09:45:00'), None)",
#  "sub_id:13352372, hadm_id:28752421: intubation/extubation pair: (Timestamp('2147-05-24 23:43:00'), Timestamp('2147-05-28 16:58:00'))",
#  "sub_id:13352372, hadm_id:28752421: intubation/extubation pair: (Timestamp('2147-05-29 09:03:00'), None)",
#  "sub_id:13365915, hadm_id:29277897: intubation/extubation pair: (Timestamp('2179-01-19 02:00:00'), None)",
#  "sub_id:13365915, hadm_id:29277897: intubation/extubation pair: (Timestamp('2179-01-21 21:30:00'), Timestamp('2179-02-02 16:24:00'))",
#  "sub_id:13367954, hadm_id:25262787: intubation/extubation pair: (Timestamp('2117-01-02 08:35:00'), Timestamp('2117-01-04 08:30:00'))",
#  "sub_id:13388935, hadm_id:25319012: intubation/extubation pair: (Timestamp('2174-10-13 08:47:00'), Timestamp('2174-10-13 17:45:00'))",
#  "sub_id:13390728, hadm_id:26350081: intubation/extubation pair: (Timestamp('2120-02-13 21:00:00'), Timestamp('2120-02-25 16:40:00'))",
#  "sub_id:13394692, hadm_id:28720007: intubation/extubation pair: (Timestamp('2111-03-20 01:30:00'), Timestamp('2111-03-26 04:50:00'))",
#  "sub_id:13399504, hadm_id:20929866: intubation/extubation pair: (Timestamp('2119-11-28 15:38:00'), None)",
#  "sub_id:13402290, hadm_id:23123365: intubation/extubation pair: (Timestamp('2116-08-24 19:53:00'), Timestamp('2116-08-31 14:20:00'))",
#  "sub_id:13402290, hadm_id:23123365: intubation/extubation pair: (Timestamp('2116-08-31 14:26:00'), None)",
#  "sub_id:13411545, hadm_id:20440298: intubation/extubation pair: (Timestamp('2176-04-09 09:00:00'), Timestamp('2176-04-21 16:33:00'))",
#  "sub_id:13411545, hadm_id:20440298: intubation/extubation pair: (Timestamp('2176-04-23 19:46:00'), Timestamp('2176-04-24 15:00:00'))",
#  "sub_id:13415410, hadm_id:26910934: intubation/extubation pair: (Timestamp('2158-11-17 22:44:00'), Timestamp('2158-11-20 15:15:00'))",
#  "sub_id:13415410, hadm_id:26910934: intubation/extubation pair: (Timestamp('2158-11-21 06:40:00'), None)",
#  "sub_id:13415550, hadm_id:25548368: intubation/extubation pair: (Timestamp('2186-02-01 20:34:00'), Timestamp('2186-02-04 08:51:00'))",
#  "sub_id:13425422, hadm_id:20645875: intubation/extubation pair: (Timestamp('2164-12-15 12:00:00'), Timestamp('2164-12-15 15:00:00'))",
#  "sub_id:13443911, hadm_id:26077552: intubation/extubation pair: (Timestamp('2136-05-29 20:00:00'), Timestamp('2136-05-31 15:55:00'))",
#  "sub_id:13449480, hadm_id:25601260: intubation/extubation pair: (Timestamp('2144-01-21 22:41:00'), Timestamp('2144-01-29 08:00:00'))",
#  "sub_id:13462065, hadm_id:26750703: intubation/extubation pair: (Timestamp('2131-09-14 17:32:00'), Timestamp('2131-09-15 20:48:00'))",
#  "sub_id:13462065, hadm_id:26750703: intubation/extubation pair: (Timestamp('2131-09-16 09:27:00'), Timestamp('2131-09-21 13:45:00'))",
#  "sub_id:13462065, hadm_id:26750703: intubation/extubation pair: (Timestamp('2131-09-23 12:01:00'), None)",
#  "sub_id:13464769, hadm_id:26552927: intubation/extubation pair: (Timestamp('2124-03-30 12:50:00'), Timestamp('2124-03-31 15:10:00'))",
#  "sub_id:13464769, hadm_id:26552927: intubation/extubation pair: (Timestamp('2124-03-31 21:30:00'), Timestamp('2124-04-10 14:30:00'))",
#  "sub_id:13467066, hadm_id:27794492: intubation/extubation pair: (Timestamp('2133-10-26 12:00:00'), Timestamp('2133-10-30 12:08:00'))",
#  "sub_id:13467066, hadm_id:27794492: intubation/extubation pair: (Timestamp('2133-10-30 13:29:00'), Timestamp('2133-11-08 17:57:00'))",
#  "sub_id:13470702, hadm_id:25265899: intubation/extubation pair: (Timestamp('2134-02-13 11:45:00'), Timestamp('2134-02-17 13:18:00'))",
#  "sub_id:13474359, hadm_id:22461878: intubation/extubation pair: (Timestamp('2121-09-04 08:48:00'), Timestamp('2121-09-09 14:00:00'))",
#  "sub_id:13479420, hadm_id:21083808: intubation/extubation pair: (Timestamp('2168-01-24 01:57:00'), Timestamp('2168-01-28 18:15:00'))",
#  "sub_id:13481227, hadm_id:21444188: intubation/extubation pair: (Timestamp('2184-12-27 11:05:00'), Timestamp('2184-12-30 08:50:00'))",
#  "sub_id:13495200, hadm_id:29364600: intubation/extubation pair: (Timestamp('2160-12-20 16:00:00'), Timestamp('2160-12-24 12:30:00'))",
#  "sub_id:13496466, hadm_id:23642129: intubation/extubation pair: (Timestamp('2165-08-29 21:45:00'), None)",
#  "sub_id:13496466, hadm_id:23642129: intubation/extubation pair: (Timestamp('2165-09-01 22:40:00'), Timestamp('2165-09-12 15:06:00'))",
#  "sub_id:13496639, hadm_id:26484716: intubation/extubation pair: (Timestamp('2170-01-25 03:15:00'), Timestamp('2170-01-30 17:15:00'))",
#  "sub_id:13496639, hadm_id:26484716: intubation/extubation pair: (Timestamp('2170-02-10 18:16:00'), Timestamp('2170-02-10 18:44:00'))",
#  "sub_id:13496639, hadm_id:26484716: intubation/extubation pair: (Timestamp('2170-02-15 12:00:00'), Timestamp('2170-02-17 10:44:00'))",
#  "sub_id:13500689, hadm_id:24081317: intubation/extubation pair: (Timestamp('2137-09-15 03:20:00'), Timestamp('2137-09-18 15:03:00'))",
#  "sub_id:13500689, hadm_id:24081317: intubation/extubation pair: (Timestamp('2137-09-21 21:29:00'), Timestamp('2137-09-24 07:50:00'))",
#  "sub_id:13500689, hadm_id:24081317: intubation/extubation pair: (Timestamp('2137-09-29 08:40:00'), None)",
#  "sub_id:13507232, hadm_id:25829986: intubation/extubation pair: (Timestamp('2154-08-25 12:30:00'), Timestamp('2154-08-30 08:25:00'))",
#  "sub_id:13507232, hadm_id:25829986: intubation/extubation pair: (Timestamp('2154-08-30 18:20:00'), None)",
#  "sub_id:13512648, hadm_id:25653583: intubation/extubation pair: (Timestamp('2174-12-21 11:00:00'), Timestamp('2174-12-23 15:44:00'))",
#  "sub_id:13514465, hadm_id:28109699: intubation/extubation pair: (Timestamp('2120-10-27 18:10:00'), Timestamp('2120-10-30 10:32:00'))",
#  "sub_id:13515178, hadm_id:20762918: intubation/extubation pair: (Timestamp('2154-01-14 11:37:00'), None)",
#  "sub_id:13515178, hadm_id:20762918: intubation/extubation pair: (Timestamp('2154-01-20 16:15:00'), Timestamp('2154-01-26 11:55:00'))",
#  "sub_id:13515178, hadm_id:20762918: intubation/extubation pair: (Timestamp('2154-01-26 12:26:00'), None)",
#  "sub_id:13515178, hadm_id:28966068: intubation/extubation pair: (Timestamp('2154-04-15 21:00:00'), Timestamp('2154-04-17 17:22:00'))",
#  "sub_id:13516473, hadm_id:23613352: intubation/extubation pair: (Timestamp('2144-01-30 10:19:00'), Timestamp('2144-02-06 12:40:00'))",
#  "sub_id:13516473, hadm_id:23613352: intubation/extubation pair: (Timestamp('2144-02-16 16:25:00'), Timestamp('2144-02-19 15:26:00'))",
#  "sub_id:13516473, hadm_id:23613352: intubation/extubation pair: (Timestamp('2144-02-20 20:35:00'), None)",
#  "sub_id:13526177, hadm_id:21051213: intubation/extubation pair: (Timestamp('2141-04-28 02:19:00'), Timestamp('2141-05-09 10:07:00'))",
#  "sub_id:13526177, hadm_id:21051213: intubation/extubation pair: (Timestamp('2141-05-15 12:00:00'), None)",
#  "sub_id:13528306, hadm_id:20813943: intubation/extubation pair: (Timestamp('2178-11-09 12:00:00'), Timestamp('2178-11-13 11:35:00'))",
#  ...]

# %% [markdown]
# Single value missing data

# %%
intubation_extubation_test[intubation_extubation_test.subject_id.isin([10004401, 10007818])]
# Out:
#    subject_id   hadm_id  int_stayid            admittime      intubationtime  \
# 2    10004401  27939719    31202136  2144-04-11 03:31:00 2144-04-11 05:03:00
# 3    10004401  29988601    32773003  2144-01-23 07:58:00 2144-01-27 19:00:00
# 4    10004401  29988601    32773003  2144-01-23 07:58:00 2144-01-30 13:00:00
# 6    10007818  22987108    32359580  2146-06-10 16:37:00 2146-06-22 12:49:00
#
#    int_itemid  int_weight  ext_stayid      extubationtime  ext_itemid  \
# 2      224385       120.0         NaN                 NaT         NaN
# 3      224385        76.0  32773003.0 2144-01-30 12:30:00    227194.0
# 4      224385        76.0  32773003.0 2144-01-30 12:30:00    227194.0
# 6      224385        86.2         NaN                 NaT         NaN
#
#    ext_weight     extubationcause            dischtime            deathtime
# 2         NaN                 NaN  2144-04-13 17:31:00                  NaN
# 3        76.0  Planned Extubation  2144-02-06 11:45:00                  NaN
# 4        76.0  Planned Extubation  2144-02-06 11:45:00                  NaN
# 6         NaN                 NaN  2146-07-12 00:00:00  2146-07-12 20:50:00

# %%
processed_df_grouped[processed_df_grouped.subject_id.isin([10004401, 10007818])]
# Out:
#    subject_id   hadm_id  int_stayid            admittime      intubationtime  \
# 2    10004401  27939719    31202136  2144-04-11 03:31:00 2144-04-11 05:03:00
# 3    10004401  29988601    32773003  2144-01-23 07:58:00 2144-01-27 19:00:00
# 4    10004401  29988601    32773003  2144-01-23 07:58:00 2144-01-30 13:00:00
# 6    10007818  22987108    32359580  2146-06-10 16:37:00 2146-06-22 12:49:00
#
#    int_itemid  int_weight  ext_stayid      extubationtime  ext_itemid  \
# 2      224385       120.0         NaN 2144-04-13 17:31:00         NaN
# 3      224385        76.0  32773003.0 2144-01-30 12:30:00    227194.0
# 4      224385        76.0  32773003.0 2144-01-30 12:30:00    227194.0
# 6      224385        86.2         NaN 2146-07-12 20:50:00         NaN
#
#    ext_weight     extubationcause            dischtime            deathtime
# 2         NaN                 NaN  2144-04-13 17:31:00                  NaN
# 3        76.0  Planned Extubation  2144-02-06 11:45:00                  NaN
# 4        76.0  Planned Extubation  2144-02-06 11:45:00                  NaN
# 6         NaN                 NaN  2146-07-12 00:00:00  2146-07-12 20:50:00

# %% [markdown]
# ------

# %%
test_subject = intubation_extubation[intubation_extubation.subject_id == 10098215]   # extract single subject
test_subject_sorted = test_subject.sort_values(by=['intubationtime'], ascending=[True])   # sort data in ascending order of intubationtime
test_subject_sorted
# Out:
#     subject_id   hadm_id  int_stayid            admittime      intubationtime  \
# 91    10098215  29752040    31800901  2117-10-25 20:40:00 2117-10-26 10:53:00
# 70    10098215  21701015    30598744  2118-01-10 03:42:00 2118-01-10 13:09:00
# 71    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 72    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 73    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 74    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 75    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 76    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 77    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 78    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 82    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 81    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 80    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 79    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 83    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 84    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 85    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 86    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 87    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 88    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 89    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 90    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 69    10098215  20652197    37703075  2118-08-14 20:31:00 2118-09-02 07:45:00
#
#     int_itemid  int_weight  ext_stayid      extubationtime  ext_itemid  \
# 91      224385        56.5  31800901.0 2117-10-29 09:25:00    227194.0
# 70      224385        57.0  30598744.0 2118-01-11 09:55:00    227194.0
# 71      224385        60.0  36018186.0 2118-06-06 16:33:00    227194.0
# 72      224385        60.0  36018186.0 2118-06-08 11:55:00    227194.0
# 73      224385        60.0  32301420.0 2118-06-21 03:30:00    225468.0
# 74      224385        60.0  32301420.0 2118-06-27 12:45:00    227194.0
# 75      224385        55.4  36018186.0 2118-06-06 16:33:00    227194.0
# 76      224385        55.4  36018186.0 2118-06-08 11:55:00    227194.0
# 77      224385        55.4  32301420.0 2118-06-21 03:30:00    225468.0
# 78      224385        55.4  32301420.0 2118-06-27 12:45:00    227194.0
# 82      224385        55.4  32301420.0 2118-06-27 12:45:00    227194.0
# 81      224385        55.4  32301420.0 2118-06-21 03:30:00    225468.0
# 80      224385        55.4  36018186.0 2118-06-08 11:55:00    227194.0
# 79      224385        55.4  36018186.0 2118-06-06 16:33:00    227194.0
# 83      224385        48.7  36018186.0 2118-06-06 16:33:00    227194.0
# 84      224385        48.7  36018186.0 2118-06-08 11:55:00    227194.0
# 85      224385        48.7  32301420.0 2118-06-21 03:30:00    225468.0
# 86      224385        48.7  32301420.0 2118-06-27 12:45:00    227194.0
# 87      224385        48.7  36018186.0 2118-06-06 16:33:00    227194.0
# 88      224385        48.7  36018186.0 2118-06-08 11:55:00    227194.0
# 89      224385        48.7  32301420.0 2118-06-21 03:30:00    225468.0
# 90      224385        48.7  32301420.0 2118-06-27 12:45:00    227194.0
# 69      224385        66.0  37703075.0 2118-09-05 11:20:00    227194.0
#
#     ext_weight                           extubationcause       int_ext_time  \
# 91        56.5                        Planned Extubation    2 days 22:32:00
# 70        57.0                        Planned Extubation    0 days 20:46:00
# 71        55.4                        Planned Extubation   27 days 21:31:00
# 72        55.4                        Planned Extubation   29 days 16:53:00
# 73        48.7  Unplanned Extuabtion (patient-initiated)   42 days 08:28:00
# 74        48.7                        Planned Extubation   48 days 17:43:00
# 75        55.4                        Planned Extubation    2 days 19:43:00
# 76        55.4                        Planned Extubation    4 days 15:05:00
# 77        48.7  Unplanned Extuabtion (patient-initiated)   17 days 06:40:00
# 78        48.7                        Planned Extubation   23 days 15:55:00
# 82        48.7                        Planned Extubation   20 days 11:05:00
# 81        48.7  Unplanned Extuabtion (patient-initiated)   14 days 01:50:00
# 80        55.4                        Planned Extubation    1 days 10:15:00
# 79        55.4                        Planned Extubation  -1 days +14:53:00
# 83        55.4                        Planned Extubation -12 days +14:45:00
# 84        55.4                        Planned Extubation -10 days +10:07:00
# 85        48.7  Unplanned Extuabtion (patient-initiated)    3 days 01:42:00
# 86        48.7                        Planned Extubation    9 days 10:57:00
# 87        55.4                        Planned Extubation -15 days +08:05:00
# 88        55.4                        Planned Extubation -13 days +03:27:00
# 89        48.7  Unplanned Extuabtion (patient-initiated)  -1 days +19:02:00
# 90        48.7                        Planned Extubation    6 days 04:17:00
# 69        66.0                        Planned Extubation    3 days 03:35:00
#
#               dischtime deathtime
# 91  2117-11-03 16:30:00       NaN
# 70  2118-02-13 19:00:00       NaN
# 71  2118-07-16 12:15:00       NaN
# 72  2118-07-16 12:15:00       NaN
# 73  2118-07-16 12:15:00       NaN
# 74  2118-07-16 12:15:00       NaN
# 75  2118-07-16 12:15:00       NaN
# 76  2118-07-16 12:15:00       NaN
# 77  2118-07-16 12:15:00       NaN
# 78  2118-07-16 12:15:00       NaN
# 82  2118-07-16 12:15:00       NaN
# 81  2118-07-16 12:15:00       NaN
# 80  2118-07-16 12:15:00       NaN
# 79  2118-07-16 12:15:00       NaN
# 83  2118-07-16 12:15:00       NaN
# 84  2118-07-16 12:15:00       NaN
# 85  2118-07-16 12:15:00       NaN
# 86  2118-07-16 12:15:00       NaN
# 87  2118-07-16 12:15:00       NaN
# 88  2118-07-16 12:15:00       NaN
# 89  2118-07-16 12:15:00       NaN
# 90  2118-07-16 12:15:00       NaN
# 69  2118-09-18 15:15:00       NaN

# %% [markdown]
# #### 1) hadm_id 별로 몇번의 intubation event가 있었는지 카운트

# %%
# Count the number of intubationtime events for each hadm_id
int_ext_counts = test_subject_sorted.groupby('hadm_id')[['intubationtime', 'extubationtime']].count()

# Display the counts
int_ext_counts.reset_index()
# Out:
#     hadm_id  intubationtime  extubationtime
# 0  20652197               1               1
# 1  21701015               1               1
# 2  22394571              20              20
# 3  29752040               1               1

# %% [markdown]
# subject-level 관련 함수

# %%
subject_id = 10098215
test_subject_unique_data = intubation_extubation[intubation_extubation.subject_id == subject_id]   # extract single subject
test_results = process_intubation_data_grouped(test_subject_unique_data)
# Out:
# 고유한 intubation 이벤트 수: 5
# 고유한 extubation 이벤트 수: 4
# extubation 결측치 수: 0
# --고유한 Intubation 이벤트--
# <DatetimeArray>
# ['2118-05-09 19:02:00', '2118-06-03 20:50:00', '2118-06-07 01:40:00',
#  '2118-06-18 01:48:00', '2118-06-21 08:28:00']
# Length: 5, dtype: datetime64[ns]
# --고유한 Extubation 이벤트--
# <DatetimeArray>
# ['2118-06-06 16:33:00', '2118-06-08 11:55:00', '2118-06-21 03:30:00',
#  '2118-06-27 12:45:00']
# Length: 4, dtype: datetime64[ns]
# list print test:
# 2118-05-09 19:02:00

# %%
test_subject_unique_data[test_subject_unique_data.hadm_id == 22394571]
# Out:
#     subject_id   hadm_id  int_stayid            admittime      intubationtime  \
# 71    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 72    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 73    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 74    10098215  22394571    32817342  2118-05-03 23:07:00 2118-05-09 19:02:00
# 75    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 76    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 77    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 78    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-03 20:50:00
# 79    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 80    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 81    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 82    10098215  22394571    36018186  2118-05-03 23:07:00 2118-06-07 01:40:00
# 83    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 84    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 85    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 86    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-18 01:48:00
# 87    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 88    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 89    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
# 90    10098215  22394571    32301420  2118-05-03 23:07:00 2118-06-21 08:28:00
#
#     int_itemid  int_weight  ext_stayid      extubationtime  ext_itemid  \
# 71      224385        60.0  36018186.0 2118-06-06 16:33:00    227194.0
# 72      224385        60.0  36018186.0 2118-06-08 11:55:00    227194.0
# 73      224385        60.0  32301420.0 2118-06-21 03:30:00    225468.0
# 74      224385        60.0  32301420.0 2118-06-27 12:45:00    227194.0
# 75      224385        55.4  36018186.0 2118-06-06 16:33:00    227194.0
# 76      224385        55.4  36018186.0 2118-06-08 11:55:00    227194.0
# 77      224385        55.4  32301420.0 2118-06-21 03:30:00    225468.0
# 78      224385        55.4  32301420.0 2118-06-27 12:45:00    227194.0
# 79      224385        55.4  36018186.0 2118-06-06 16:33:00    227194.0
# 80      224385        55.4  36018186.0 2118-06-08 11:55:00    227194.0
# 81      224385        55.4  32301420.0 2118-06-21 03:30:00    225468.0
# 82      224385        55.4  32301420.0 2118-06-27 12:45:00    227194.0
# 83      224385        48.7  36018186.0 2118-06-06 16:33:00    227194.0
# 84      224385        48.7  36018186.0 2118-06-08 11:55:00    227194.0
# 85      224385        48.7  32301420.0 2118-06-21 03:30:00    225468.0
# 86      224385        48.7  32301420.0 2118-06-27 12:45:00    227194.0
# 87      224385        48.7  36018186.0 2118-06-06 16:33:00    227194.0
# 88      224385        48.7  36018186.0 2118-06-08 11:55:00    227194.0
# 89      224385        48.7  32301420.0 2118-06-21 03:30:00    225468.0
# 90      224385        48.7  32301420.0 2118-06-27 12:45:00    227194.0
#
#     ext_weight                           extubationcause       int_ext_time  \
# 71        55.4                        Planned Extubation   27 days 21:31:00
# 72        55.4                        Planned Extubation   29 days 16:53:00
# 73        48.7  Unplanned Extuabtion (patient-initiated)   42 days 08:28:00
# 74        48.7                        Planned Extubation   48 days 17:43:00
# 75        55.4                        Planned Extubation    2 days 19:43:00
# 76        55.4                        Planned Extubation    4 days 15:05:00
# 77        48.7  Unplanned Extuabtion (patient-initiated)   17 days 06:40:00
# 78        48.7                        Planned Extubation   23 days 15:55:00
# 79        55.4                        Planned Extubation  -1 days +14:53:00
# 80        55.4                        Planned Extubation    1 days 10:15:00
# 81        48.7  Unplanned Extuabtion (patient-initiated)   14 days 01:50:00
# 82        48.7                        Planned Extubation   20 days 11:05:00
# 83        55.4                        Planned Extubation -12 days +14:45:00
# 84        55.4                        Planned Extubation -10 days +10:07:00
# 85        48.7  Unplanned Extuabtion (patient-initiated)    3 days 01:42:00
# 86        48.7                        Planned Extubation    9 days 10:57:00
# 87        55.4                        Planned Extubation -15 days +08:05:00
# 88        55.4                        Planned Extubation -13 days +03:27:00
# 89        48.7  Unplanned Extuabtion (patient-initiated)  -1 days +19:02:00
# 90        48.7                        Planned Extubation    6 days 04:17:00
#
#               dischtime deathtime
# 71  2118-07-16 12:15:00       NaN
# 72  2118-07-16 12:15:00       NaN
# 73  2118-07-16 12:15:00       NaN
# 74  2118-07-16 12:15:00       NaN
# 75  2118-07-16 12:15:00       NaN
# 76  2118-07-16 12:15:00       NaN
# 77  2118-07-16 12:15:00       NaN
# 78  2118-07-16 12:15:00       NaN
# 79  2118-07-16 12:15:00       NaN
# 80  2118-07-16 12:15:00       NaN
# 81  2118-07-16 12:15:00       NaN
# 82  2118-07-16 12:15:00       NaN
# 83  2118-07-16 12:15:00       NaN
# 84  2118-07-16 12:15:00       NaN
# 85  2118-07-16 12:15:00       NaN
# 86  2118-07-16 12:15:00       NaN
# 87  2118-07-16 12:15:00       NaN
# 88  2118-07-16 12:15:00       NaN
# 89  2118-07-16 12:15:00       NaN
# 90  2118-07-16 12:15:00       NaN

# %%
# DataFrame 처리
processed_df_grouped, logs_grouped = process_intubation_data_grouped(test_subject_sorted)

# 처리된 데이터와 로그 메시지 출력
processed_df_grouped.head(), logs_grouped

# %%
## 결측치 채우기 테스트
subject_id = 10004401  # extubation 결측치 존재

test_subject_missing_data = intubation_extubation[intubation_extubation.subject_id == subject_id]   # extract single subject
test_subject_missing_data_sorted = test_subject_missing_data.sort_values(by=['intubationtime'], ascending=[True])   # sort data in ascending order of intubationtime
test_subject_missing_data_sorted
# Out:
#    subject_id   hadm_id  int_stayid            admittime      intubationtime  \
# 3    10004401  29988601    32773003  2144-01-23 07:58:00 2144-01-27 19:00:00
# 4    10004401  29988601    32773003  2144-01-23 07:58:00 2144-01-30 13:00:00
# 2    10004401  27939719    31202136  2144-04-11 03:31:00 2144-04-11 05:03:00
#
#    int_itemid  int_weight  ext_stayid      extubationtime  ext_itemid  \
# 3      224385        76.0  32773003.0 2144-01-30 12:30:00    227194.0
# 4      224385        76.0  32773003.0 2144-01-30 12:30:00    227194.0
# 2      224385       120.0         NaN                 NaT         NaN
#
#    ext_weight     extubationcause      int_ext_time            dischtime  \
# 3        76.0  Planned Extubation   2 days 17:30:00  2144-02-06 11:45:00
# 4        76.0  Planned Extubation -1 days +23:30:00  2144-02-06 11:45:00
# 2         NaN                 NaN               NaT  2144-04-13 17:31:00
#
#   deathtime
# 3       NaN
# 4       NaN
# 2       NaN

# %%
# DataFrame 처리
processed_sub10004401, logs_grouped = process_intubation_data_grouped(test_subject_missing_data_sorted)

# 처리된 데이터와 로그 메시지 출력
processed_sub10004401
# Out:
# hadm_id: 27939719 처리 중...
# hadm_id: 29988601 처리 중...
# 하나 이상의 대체 이벤트가 있음. 계속 진행...
#    subject_id   hadm_id  int_stayid            admittime      intubationtime  \
# 3    10004401  29988601    32773003  2144-01-23 07:58:00 2144-01-27 19:00:00
# 4    10004401  29988601    32773003  2144-01-23 07:58:00 2144-01-30 13:00:00
# 2    10004401  27939719    31202136  2144-04-11 03:31:00 2144-04-11 05:03:00
#
#    int_itemid  int_weight  ext_stayid      extubationtime  ext_itemid  \
# 3      224385        76.0  32773003.0 2144-01-30 12:30:00    227194.0
# 4      224385        76.0  32773003.0 2144-01-30 12:30:00    227194.0
# 2      224385       120.0         NaN 2144-04-13 17:31:00         NaN
#
#    ext_weight     extubationcause      int_ext_time            dischtime  \
# 3        76.0  Planned Extubation   2 days 17:30:00  2144-02-06 11:45:00
# 4        76.0  Planned Extubation -1 days +23:30:00  2144-02-06 11:45:00
# 2         NaN                 NaN               NaT  2144-04-13 17:31:00
#
#   deathtime
# 3       NaN
# 4       NaN
# 2       NaN

# %%
## 결측치 채우기 테스트
subject_id = 10007818  # extubation 결측치 존재

test_subject_missing_data = intubation_extubation[intubation_extubation.subject_id == subject_id]   # extract single subject
test_subject_missing_data_sorted = test_subject_missing_data.sort_values(by=['intubationtime'], ascending=[True])   # sort data in ascending order of intubationtime
test_subject_missing_data_sorted
# Out:
#    subject_id   hadm_id  int_stayid            admittime      intubationtime  \
# 6    10007818  22987108    32359580  2146-06-10 16:37:00 2146-06-22 12:49:00
#
#    int_itemid  int_weight  ext_stayid extubationtime  ext_itemid  ext_weight  \
# 6      224385        86.2         NaN            NaT         NaN         NaN
#
#   extubationcause int_ext_time            dischtime            deathtime
# 6             NaN          NaT  2146-07-12 00:00:00  2146-07-12 20:50:00

# %%
# DataFrame 처리
processed_sub10004401, logs_grouped = process_intubation_data_grouped(test_subject_missing_data_sorted)

# 처리된 데이터와 로그 메시지 출력
processed_sub10004401
# Out:
# hadm_id: 22987108 처리 중...
#    subject_id   hadm_id  int_stayid            admittime      intubationtime  \
# 6    10007818  22987108    32359580  2146-06-10 16:37:00 2146-06-22 12:49:00
#
#    int_itemid  int_weight  ext_stayid      extubationtime  ext_itemid  \
# 6      224385        86.2         NaN 2146-07-12 20:50:00         NaN
#
#    ext_weight extubationcause int_ext_time            dischtime  \
# 6         NaN             NaN          NaT  2146-07-12 00:00:00
#
#              deathtime
# 6  2146-07-12 20:50:00

# %%
# 정렬알고리즘 테스트 예시
# start_times = [list of start times]
# end_times = [list of end times]
# sorted_pairs = find_pairs(start_times, end_times)

# %%
# Group the data by hadm_id and count duplicate values for intubationtime and extubationtime
intubation_duplicates = test_subject_sorted.groupby('hadm_id')['intubationtime'].value_counts()
extubation_duplicates = test_subject_sorted.groupby('hadm_id')['extubationtime'].value_counts()

# Prepare a DataFrame to display the results
duplicate_counts = pd.DataFrame({
    'Intubation Duplicates': intubation_duplicates,
    'Extubation Duplicates': extubation_duplicates
}).fillna(0).astype(int)

# Display the DataFrame
duplicate_counts.reset_index()
# Out:
#      hadm_id              level_1  Intubation Duplicates  \
# 0   20652197  2118-09-02 07:45:00                      1
# 1   20652197  2118-09-05 11:20:00                      0
# 2   21701015  2118-01-10 13:09:00                      1
# 3   21701015  2118-01-11 09:55:00                      0
# 4   22394571  2118-05-09 19:02:00                      4
# 5   22394571  2118-06-03 20:50:00                      4
# 6   22394571  2118-06-06 16:33:00                      0
# 7   22394571  2118-06-07 01:40:00                      4
# 8   22394571  2118-06-08 11:55:00                      0
# 9   22394571  2118-06-18 01:48:00                      4
# 10  22394571  2118-06-21 03:30:00                      0
# 11  22394571  2118-06-21 08:28:00                      4
# 12  22394571  2118-06-27 12:45:00                      0
# 13  29752040  2117-10-26 10:53:00                      1
# 14  29752040  2117-10-29 09:25:00                      0
#
#     Extubation Duplicates
# 0                       0
# 1                       1
# 2                       0
# 3                       1
# 4                       0
# 5                       0
# 6                       5
# 7                       0
# 8                       5
# 9                       0
# 10                      5
# 11                      0
# 12                      5
# 13                      0
# 14                      1

# %%
test_subject.shape
# Out:
# (12, 14)

# %%
test_subject2 = intubation_extubation_stay[intubation_extubation_stay.subject_id == 13033327]
test_subject2
# Out:
#       subject_id   hadm_id   stay_id            admittime  \
# 3032    13033327  21093920  39867250  2146-01-05 01:07:00
# 3033    13033327  21093920  39867250  2146-01-05 01:07:00
# 3034    13033327  21093920  39867250  2146-01-05 01:07:00
# 3035    13033327  21093920  39867250  2146-01-05 01:07:00
# 3036    13033327  21093920  39867250  2146-01-05 01:07:00
# 3037    13033327  21093920  39867250  2146-01-05 01:07:00
# 3038    13033327  21093920  39867250  2146-01-05 01:07:00
# 3039    13033327  21093920  39867250  2146-01-05 01:07:00
# 3040    13033327  21093920  39867250  2146-01-05 01:07:00
# 3041    13033327  21093920  39867250  2146-01-05 01:07:00
# 3042    13033327  21093920  39867250  2146-01-05 01:07:00
# 3043    13033327  21093920  39867250  2146-01-05 01:07:00
# 3044    13033327  21093920  39867250  2146-01-05 01:07:00
# 3045    13033327  21093920  39867250  2146-01-05 01:07:00
# 3046    13033327  21093920  39867250  2146-01-05 01:07:00
# 3047    13033327  21093920  39867250  2146-01-05 01:07:00
# 3048    13033327  21093920  39867250  2146-01-05 01:07:00
# 3049    13033327  21093920  39867250  2146-01-05 01:07:00
# 3050    13033327  21093920  39867250  2146-01-05 01:07:00
# 3051    13033327  21093920  39867250  2146-01-05 01:07:00
#
#            intubationtime  int_itemid  int_weight       extubationtime  \
# 3032  2146-01-05 17:41:00      224385        71.0  2146-01-11 15:42:00
# 3033  2146-01-05 17:41:00      224385        71.0  2146-01-16 16:00:00
# 3034  2146-01-05 17:41:00      224385        71.0  2146-01-18 13:05:00
# 3035  2146-01-05 17:41:00      224385        71.0  2146-01-23 09:25:00
# 3036  2146-01-05 17:41:00      224385        71.0  2146-01-29 10:00:00
# 3037  2146-01-20 15:12:00      224385        71.0  2146-01-11 15:42:00
# 3038  2146-01-20 15:12:00      224385        71.0  2146-01-16 16:00:00
# 3039  2146-01-20 15:12:00      224385        71.0  2146-01-18 13:05:00
# 3040  2146-01-20 15:12:00      224385        71.0  2146-01-23 09:25:00
# 3041  2146-01-20 15:12:00      224385        71.0  2146-01-29 10:00:00
# 3042  2146-01-27 05:08:00      224385        71.0  2146-01-11 15:42:00
# 3043  2146-01-27 05:08:00      224385        71.0  2146-01-16 16:00:00
# 3044  2146-01-27 05:08:00      224385        71.0  2146-01-18 13:05:00
# 3045  2146-01-27 05:08:00      224385        71.0  2146-01-23 09:25:00
# 3046  2146-01-27 05:08:00      224385        71.0  2146-01-29 10:00:00
# 3047  2146-01-29 10:00:00      224385        71.0  2146-01-11 15:42:00
# 3048  2146-01-29 10:00:00      224385        71.0  2146-01-16 16:00:00
# 3049  2146-01-29 10:00:00      224385        71.0  2146-01-18 13:05:00
# 3050  2146-01-29 10:00:00      224385        71.0  2146-01-23 09:25:00
# 3051  2146-01-29 10:00:00      224385        71.0  2146-01-29 10:00:00
#
#       ext_itemid  ext_weight                               extubationcause  \
# 3032    227194.0        71.0                            Planned Extubation
# 3033    227194.0        71.0                            Planned Extubation
# 3034    227194.0        71.0                            Planned Extubation
# 3035    227194.0        71.0                            Planned Extubation
# 3036    225477.0        71.0  Unplanned Extuabtion (non-patient initiated)
# 3037    227194.0        71.0                            Planned Extubation
# 3038    227194.0        71.0                            Planned Extubation
# 3039    227194.0        71.0                            Planned Extubation
# 3040    227194.0        71.0                            Planned Extubation
# 3041    225477.0        71.0  Unplanned Extuabtion (non-patient initiated)
# 3042    227194.0        71.0                            Planned Extubation
# 3043    227194.0        71.0                            Planned Extubation
# 3044    227194.0        71.0                            Planned Extubation
# 3045    227194.0        71.0                            Planned Extubation
# 3046    225477.0        71.0  Unplanned Extuabtion (non-patient initiated)
# 3047    227194.0        71.0                            Planned Extubation
# 3048    227194.0        71.0                            Planned Extubation
# 3049    227194.0        71.0                            Planned Extubation
# 3050    227194.0        71.0                            Planned Extubation
# 3051    225477.0        71.0  Unplanned Extuabtion (non-patient initiated)
#
#             int_ext_time            dischtime deathtime
# 3032     5 days 22:01:00  2146-02-15 17:10:00       NaN
# 3033    10 days 22:19:00  2146-02-15 17:10:00       NaN
# 3034    12 days 19:24:00  2146-02-15 17:10:00       NaN
# 3035    17 days 15:44:00  2146-02-15 17:10:00       NaN
# 3036    23 days 16:19:00  2146-02-15 17:10:00       NaN
# 3037   -9 days +00:30:00  2146-02-15 17:10:00       NaN
# 3038   -4 days +00:48:00  2146-02-15 17:10:00       NaN
# 3039   -3 days +21:53:00  2146-02-15 17:10:00       NaN
# 3040     2 days 18:13:00  2146-02-15 17:10:00       NaN
# 3041     8 days 18:48:00  2146-02-15 17:10:00       NaN
# 3042  -16 days +10:34:00  2146-02-15 17:10:00       NaN
# 3043  -11 days +10:52:00  2146-02-15 17:10:00       NaN
# 3044   -9 days +07:57:00  2146-02-15 17:10:00       NaN
# 3045   -4 days +04:17:00  2146-02-15 17:10:00       NaN
# 3046     2 days 04:52:00  2146-02-15 17:10:00       NaN
# 3047  -18 days +05:42:00  2146-02-15 17:10:00       NaN
# 3048  -13 days +06:00:00  2146-02-15 17:10:00       NaN
# 3049  -11 days +03:05:00  2146-02-15 17:10:00       NaN
# 3050   -7 days +23:25:00  2146-02-15 17:10:00       NaN
# 3051     0 days 00:00:00  2146-02-15 17:10:00       NaN

# %%
su

# %%
int_dup_count = intubation_extubation.groupby(['subject_id', 'hadm_id', 'int_stayid'])['intubationtime'].nunique().reset_index()
int_dup_count = int_dup_count.rename(columns={'intubationtime': 'unique_intubation_count'})

int_dup_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7330 entries, 0 to 7329
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   subject_id               7330 non-null   int64
#  1   hadm_id                  7330 non-null   int64
#  2   int_stayid               7330 non-null   float64
#  3   unique_intubation_count  7330 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 229.2 KB

# %%
int_dup_count[int_dup_count.unique_intubation_count > 1]
# Out:
#       subject_id   hadm_id  int_stayid  unique_intubation_count
# 3       10004401  29988601  32773003.0                        2
# 22      10032381  20176432  34622731.0                        2
# 29      10039708  28258130  33281088.0                        2
# 51      10090454  29525590  38669202.0                        2
# 56      10098215  22394571  32301420.0                        2
# ...          ...       ...         ...                      ...
# 7263    19913577  20355379  37544707.0                        3
# 7273    19928728  21394753  32643307.0                        2
# 7287    19949739  25237531  32028235.0                        2
# 7294    19960105  27292691  31512322.0                        2
# 7326    19997367  20617667  35616526.0                        2
#
# [779 rows x 4 columns]

# %%
intubation_extubation[intubation_extubation.hadm_id == 22394571]
# Out:
#     subject_id   hadm_id  int_stayid            admittime  \
# 71    10098215  22394571  32817342.0  2118-05-03 23:07:00
# 72    10098215  22394571  32817342.0  2118-05-03 23:07:00
# 73    10098215  22394571  32817342.0  2118-05-03 23:07:00
# 74    10098215  22394571  32817342.0  2118-05-03 23:07:00
# 75    10098215  22394571  36018186.0  2118-05-03 23:07:00
# 76    10098215  22394571  36018186.0  2118-05-03 23:07:00
# 77    10098215  22394571  36018186.0  2118-05-03 23:07:00
# 78    10098215  22394571  36018186.0  2118-05-03 23:07:00
# 79    10098215  22394571  36018186.0  2118-05-03 23:07:00
# 80    10098215  22394571  36018186.0  2118-05-03 23:07:00
# 81    10098215  22394571  36018186.0  2118-05-03 23:07:00
# 82    10098215  22394571  36018186.0  2118-05-03 23:07:00
# 83    10098215  22394571  32301420.0  2118-05-03 23:07:00
# 84    10098215  22394571  32301420.0  2118-05-03 23:07:00
# 85    10098215  22394571  32301420.0  2118-05-03 23:07:00
# 86    10098215  22394571  32301420.0  2118-05-03 23:07:00
# 87    10098215  22394571  32301420.0  2118-05-03 23:07:00
# 88    10098215  22394571  32301420.0  2118-05-03 23:07:00
# 89    10098215  22394571  32301420.0  2118-05-03 23:07:00
# 90    10098215  22394571  32301420.0  2118-05-03 23:07:00
#
#          intubationtime  int_itemid  int_weight  ext_stayid  \
# 71  2118-05-09 19:02:00      224385        60.0  36018186.0
# 72  2118-05-09 19:02:00      224385        60.0  36018186.0
# 73  2118-05-09 19:02:00      224385        60.0  32301420.0
# 74  2118-05-09 19:02:00      224385        60.0  32301420.0
# 75  2118-06-03 20:50:00      224385        55.4  36018186.0
# 76  2118-06-03 20:50:00      224385        55.4  36018186.0
# 77  2118-06-03 20:50:00      224385        55.4  32301420.0
# 78  2118-06-03 20:50:00      224385        55.4  32301420.0
# 79  2118-06-07 01:40:00      224385        55.4  36018186.0
# 80  2118-06-07 01:40:00      224385        55.4  36018186.0
# 81  2118-06-07 01:40:00      224385        55.4  32301420.0
# 82  2118-06-07 01:40:00      224385        55.4  32301420.0
# 83  2118-06-18 01:48:00      224385        48.7  36018186.0
# 84  2118-06-18 01:48:00      224385        48.7  36018186.0
# 85  2118-06-18 01:48:00      224385        48.7  32301420.0
# 86  2118-06-18 01:48:00      224385        48.7  32301420.0
# 87  2118-06-21 08:28:00      224385        48.7  36018186.0
# 88  2118-06-21 08:28:00      224385        48.7  36018186.0
# 89  2118-06-21 08:28:00      224385        48.7  32301420.0
# 90  2118-06-21 08:28:00      224385        48.7  32301420.0
#
#          extubationtime  ext_itemid  ext_weight  \
# 71  2118-06-06 16:33:00    227194.0        55.4
# 72  2118-06-08 11:55:00    227194.0        55.4
# 73  2118-06-21 03:30:00    225468.0        48.7
# 74  2118-06-27 12:45:00    227194.0        48.7
# 75  2118-06-06 16:33:00    227194.0        55.4
# 76  2118-06-08 11:55:00    227194.0        55.4
# 77  2118-06-21 03:30:00    225468.0        48.7
# 78  2118-06-27 12:45:00    227194.0        48.7
# 79  2118-06-06 16:33:00    227194.0        55.4
# 80  2118-06-08 11:55:00    227194.0        55.4
# 81  2118-06-21 03:30:00    225468.0        48.7
# 82  2118-06-27 12:45:00    227194.0        48.7
# 83  2118-06-06 16:33:00    227194.0        55.4
# 84  2118-06-08 11:55:00    227194.0        55.4
# 85  2118-06-21 03:30:00    225468.0        48.7
# 86  2118-06-27 12:45:00    227194.0        48.7
# 87  2118-06-06 16:33:00    227194.0        55.4
# 88  2118-06-08 11:55:00    227194.0        55.4
# 89  2118-06-21 03:30:00    225468.0        48.7
# 90  2118-06-27 12:45:00    227194.0        48.7
#
#                              extubationcause        int_ext_time  \
# 71                        Planned Extubation    27 days 21:31:00
# 72                        Planned Extubation    29 days 16:53:00
# 73  Unplanned Extuabtion (patient-initiated)    42 days 08:28:00
# 74                        Planned Extubation    48 days 17:43:00
# 75                        Planned Extubation     2 days 19:43:00
# 76                        Planned Extubation     4 days 15:05:00
# 77  Unplanned Extuabtion (patient-initiated)    17 days 06:40:00
# 78                        Planned Extubation    23 days 15:55:00
# 79                        Planned Extubation   -1 days +14:53:00
# 80                        Planned Extubation     1 days 10:15:00
# 81  Unplanned Extuabtion (patient-initiated)    14 days 01:50:00
# 82                        Planned Extubation    20 days 11:05:00
# 83                        Planned Extubation  -12 days +14:45:00
# 84                        Planned Extubation  -10 days +10:07:00
# 85  Unplanned Extuabtion (patient-initiated)     3 days 01:42:00
# 86                        Planned Extubation     9 days 10:57:00
# 87                        Planned Extubation  -15 days +08:05:00
# 88                        Planned Extubation  -13 days +03:27:00
# 89  Unplanned Extuabtion (patient-initiated)   -1 days +19:02:00
# 90                        Planned Extubation     6 days 04:17:00
#
#               dischtime deathtime
# 71  2118-07-16 12:15:00       NaN
# 72  2118-07-16 12:15:00       NaN
# 73  2118-07-16 12:15:00       NaN
# 74  2118-07-16 12:15:00       NaN
# 75  2118-07-16 12:15:00       NaN
# 76  2118-07-16 12:15:00       NaN
# 77  2118-07-16 12:15:00       NaN
# 78  2118-07-16 12:15:00       NaN
# 79  2118-07-16 12:15:00       NaN
# 80  2118-07-16 12:15:00       NaN
# 81  2118-07-16 12:15:00       NaN
# 82  2118-07-16 12:15:00       NaN
# 83  2118-07-16 12:15:00       NaN
# 84  2118-07-16 12:15:00       NaN
# 85  2118-07-16 12:15:00       NaN
# 86  2118-07-16 12:15:00       NaN
# 87  2118-07-16 12:15:00       NaN
# 88  2118-07-16 12:15:00       NaN
# 89  2118-07-16 12:15:00       NaN
# 90  2118-07-16 12:15:00       NaN

# %%
def calculate_mismatches(df):
    """
    이 함수는 한번의 입원 중 복수의 삽관 및 발관 이벤트가 있는 경우를 계산합니다.
    데이터를 subject_id, hadm_id, stay_id로 그룹화하고 intubationtime 및 extubationtime에 대한 고유 값의 수를 계산한 후,
    이러한 시간에 대해 여러 개의 고유 값이 있는 그룹을 식별합니다.
    """
    # subject_id, hadm_id, stay_id로 그룹화
    grouped = df.groupby(['subject_id', 'hadm_id', 'stay_id'])

    # intubationtime 및 extubationtime에 대한 고유 값 수 계산
    unique_counts = grouped.agg({'intubationtime': pd.Series.nunique, 'extubationtime': pd.Series.nunique})

    # intubationtime 및 extubationtime에 여러 개의 고유 값이 있는 그룹 필터링
    potential_mismatches = unique_counts[(unique_counts['intubationtime'] > 1) | (unique_counts['extubationtime'] > 1)]

    return potential_mismatches.reset_index()

# 데이터프레임에 함수 적용
mismatch_stats = calculate_mismatches(intubation_extubation_stay)
mismatch_stats.head()
# Out:
#    subject_id   hadm_id   stay_id  intubationtime  extubationtime
# 0    10004401  29988601  32773003               2               1
# 1    10024982  25154057  37919901               1               2
# 2    10027602  28166872  32391858               1               2
# 3    10032381  20176432  34622731               2               1
# 4    10039708  28258130  33281088               2               2

# %%
mismatch_stats[mismatch_stats['subject_id'] == 13033327]
# Out:
#      subject_id   hadm_id   stay_id  intubationtime  extubationtime
# 400    13033327  21093920  39867250               4               5

# %%
mismatch_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1395 entries, 0 to 1394
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      1395 non-null   int64
#  1   hadm_id         1395 non-null   int64
#  2   stay_id         1395 non-null   int64
#  3   intubationtime  1395 non-null   int64
#  4   extubationtime  1395 non-null   int64
# dtypes: int64(5)
# memory usage: 54.6 KB

# %% [markdown]
# ### 2. Extubation 결측치 처리하기

# %%
# 결측치 확인
extubation_missing_count = intubation_extubation.extubationtime.isna().sum()
print(f'Extubation 결측치 개수: {extubation_missing_count} / {len(intubation_extubation)} ({round(extubation_missing_count/len(intubation_extubation) * 100, 2)}%)')
# Out:
# Extubation 결측치 개수: 1541 / 10928 (14.1%)

# %%
#데이터를 보면, 사망일과 퇴원일이 같은경우/다른경우가 있고, 사망은 없고 퇴원한 경우가 있음. 사망한 경우 사망하면 기기를 제거하므로 deathtime 을 쓰는 것이 적절할 것임. discharge를 할 경우 관을 유지하나? 보통 발관할 것 같은데..? 그래도 해당 병원에
#이 경우, extubationcause 에 deathtime 으로 적어서 deathtime 을 사용했음을 보여주려고 함.
#사망은 869건이니까 1840-869 = 971건이 퇴원한 경우임. 이 경우는 discharge time을 사용할지? 흠 역시 dischargetime 을 사용하는것이 적절할 것같음, 이 경우에도 extubationcause에 dischargetime 으로 적어야 할 것 같음
#그럼 이경우 코드를 어떻게 짤 수 있냐? 데이터 둘다 있으면 deathtime 에게 우선 순위를 주겠음(사유, 보통 더 정확함)

# %%
# intcount가 1인 경우, 다음 로직을 적용하여 채우도록하기
# #deathtime과 dischtime 둘 다 있는 경우, deathtime을 사용하여 extubationtime을 업데이트하고 extubationcause에 "deathtime" 문자열을 입력합니다.
# #deathtime이 있는 경우 (이전의 로직과 겹치지 않는다는 가정하에) 역시 deathtime을 사용하여 extubationtime을 업데이트하고 extubationcause에 "deathtime" 문자열을 입력합니다.
# #deathtime이 없고 dischtime만 있는 경우, dischtime을 사용하여 extubationtime을 업데이트하고 extubationcause에 "dischargetime" 문자열을 입력합니다.
# # deathtime과 dischtime 둘 다 있는 경우
# mask_both = (~check_extubation2['deathtime'].isna()) & (~check_extubation2['dischtime'].isna())
# check_extubation2.loc[mask_both, 'extubationtime'] = check_extubation2.loc[mask_both, 'deathtime']
# check_extubation2.loc[mask_both, 'extubationcause'] = 'deathtime'

# # deathtime만 있는 경우
# mask_death = (~check_extubation2['deathtime'].isna()) & (check_extubation2['dischtime'].isna())
# check_extubation2.loc[mask_death, 'extubationtime'] = check_extubation2.loc[mask_death, 'deathtime']
# check_extubation2.loc[mask_death, 'extubationcause'] = 'deathtime'

# # dischtime만 있는 경우
# mask_discharge = (check_extubation2['deathtime'].isna()) & (~check_extubation2['dischtime'].isna())
# check_extubation2.loc[mask_discharge, 'extubationtime'] = check_extubation2.loc[mask_discharge, 'dischtime']
# check_extubation2.loc[mask_discharge, 'extubationcause'] = 'dischargetime'

# %%
# #deathtime과 dischtime 둘 다 있는 경우, deathtime을 사용하여 extubationtime을 업데이트하고 extubationcause에 "deathtime" 문자열을 입력합니다.
# #deathtime이 있는 경우 (이전의 로직과 겹치지 않는다는 가정하에) 역시 deathtime을 사용하여 extubationtime을 업데이트하고 extubationcause에 "deathtime" 문자열을 입력합니다.
# #deathtime이 없고 dischtime만 있는 경우, dischtime을 사용하여 extubationtime을 업데이트하고 extubationcause에 "dischargetime" 문자열을 입력합니다.
# # deathtime과 dischtime 둘 다 있는 경우
# mask_both = (~check_extubation2['deathtime'].isna()) & (~check_extubation2['dischtime'].isna())
# check_extubation2.loc[mask_both, 'extubationtime'] = check_extubation2.loc[mask_both, 'deathtime']
# check_extubation2.loc[mask_both, 'extubationcause'] = 'deathtime'

# # deathtime만 있는 경우
# mask_death = (~check_extubation2['deathtime'].isna()) & (check_extubation2['dischtime'].isna())
# check_extubation2.loc[mask_death, 'extubationtime'] = check_extubation2.loc[mask_death, 'deathtime']
# check_extubation2.loc[mask_death, 'extubationcause'] = 'deathtime'

# # dischtime만 있는 경우
# mask_discharge = (check_extubation2['deathtime'].isna()) & (~check_extubation2['dischtime'].isna())
# check_extubation2.loc[mask_discharge, 'extubationtime'] = check_extubation2.loc[mask_discharge, 'dischtime']
# check_extubation2.loc[mask_discharge, 'extubationcause'] = 'dischargetime'

# %%
# #주의! extubationtime이 이미 데이터가 있는 경우 replace하면 안됨!
# #deathtime과 dischtime 둘 다 있는 경우, deathtime을 사용하여 extubationtime을 업데이트하고 extubationcause에 "deathtime" 문자열을 입력합니다.
# #deathtime이 있는 경우 (이전의 로직과 겹치지 않는다는 가정하에) 역시 deathtime을 사용하여 extubationtime을 업데이트하고 extubationcause에 "deathtime" 문자열을 입력합니다.
# #deathtime이 없고 dischtime만 있는 경우, dischtime을 사용하여 extubationtime을 업데이트하고 extubationcause에 "dischargetime" 문자열을 입력합니다.
# # deathtime과 dischtime 둘 다 있는 경우이면서 extubationtime이 NaN인 경우
# mask_both = (~intubation_extubation2['deathtime'].isna()) & (~intubation_extubation2['dischtime'].isna()) & (intubation_extubation2['extubationtime'].isna())
# intubation_extubation2.loc[mask_both, 'extubationtime'] = intubation_extubation2.loc[mask_both, 'deathtime']
# intubation_extubation2.loc[mask_both, 'extubationcause'] = 'deathtime'
# #
# # deathtime만 있는 경우이면서 extubationtime이 NaN인 경우
# mask_death = (~intubation_extubation2['deathtime'].isna()) & (intubation_extubation2['dischtime'].isna()) & (intubation_extubation2['extubationtime'].isna())
# intubation_extubation2.loc[mask_death, 'extubationtime'] = intubation_extubation2.loc[mask_death, 'deathtime']
# intubation_extubation2.loc[mask_death, 'extubationcause'] = 'deathtime'

# # dischtime만 있는 경우이면서 extubationtime이 NaN인 경우
# mask_discharge = (intubation_extubation2['deathtime'].isna()) & (~intubation_extubation2['dischtime'].isna()) & (intubation_extubation2['extubationtime'].isna())
# intubation_extubation2.loc[mask_discharge, 'extubationtime'] = intubation_extubation2.loc[mask_discharge, 'dischtime']
# intubation_extubation2.loc[mask_discharge, 'extubationcause'] = 'dischargetime'

# %%
# #여기서 intcount는 해당 입원에 총 몇번의 intubation을 했는지를 의미한다.
# #그러므로 같은 hadm_id에서 intcount와 seq가 같다면, dichtime 또는 deathtime 으로 extubationtime을 대체할 수 있다.
# #그외는 마지막 seq에 도달하기 전이므로, 다음 seq의 intubationtime 을 이전 seq의 extubationtime으로 대체한다.

# df = intubation_extubation3


# def replace_extubationtime_non(df):
#     # intcount와 intseq가 같고 extubationtime이 NaT인 행만 선택
#     mask_last_seq = (df['intcount'] == df['intseq']) & df['extubationtime'].isna()
    
#     # deathtime 또는 dischtime으로 extubationtime의 NaT 값을 대체
#     df.loc[mask_last_seq, 'extubationtime'] = df.loc[mask_last_seq, 'dischtime'].fillna(df.loc[mask_last_seq, 'deathtime'])
#     df.loc[mask_last_seq, 'extubationcause'] = 'dischtime'
    
#     # 그 외의 경우: 다음 seq의 intubationtime을 이전 seq의 extubationtime으로 대체
#     for idx, row in df.iterrows():
#         if row['intseq'] < row['intcount'] and pd.isna(row['extubationtime']):
#             next_row = df[(df['hadm_id'] == row['hadm_id']) & (df['intseq'] == row['intseq'] + 1)]
#             if not next_row.empty:
#                 df.at[idx, 'extubationtime'] = next_row['intubationtime'].values[0]
#                 df.at[idx, 'extubationcause'] = 'next_intubationtime'
    
#     return df

# # 데이터프레임에 함수 적용
# df = replace_extubationtime_non(df)

# %%
#만약 intubationtoextubationtime 이 음수이면서, intcount과 intseq가 같다면 dischtime 으로 extubationtime을 대체할 수 있다.
# intubationtoextubationtime이 음수인 경우 및 intcount와 intseq가 같은 경우, extubationtime을 dischtime으로 대체
