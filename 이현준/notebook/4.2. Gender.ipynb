# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
from dfply import *

# %%
import psycopg2

conn = psycopg2.connect(
    host = "localhost",
    user = "postgres",
    password="June3060!!",
    database = "mimic_data",
    port="5432"
)

cursor = conn.cursor()
print("database connected")
# Out:
# database connected

# %%
df = pd.read_csv("../Data/reintubation_df_240127.csv", index_col="Unnamed: 0")

# %%
df2= df.copy()
df2
# Out:
#       subject_id   hadm_id  int_stayid            admittime  \
# 0       10001884  26184834  37510196.0  2131-01-07 20:39:00
# 1       10003400  23559586  38383343.0  2137-08-04 00:07:00
# 2       10004401  27939719  31202136.0  2144-04-11 03:31:00
# 3       10004401  29988601  32773003.0  2144-01-23 07:58:00
# 4       10004401  29988601  32773003.0  2144-01-23 07:58:00
# ...          ...       ...         ...                  ...
# 9003    19997367  20617667  35616526.0  2126-04-20 07:15:00
# 9004    19997367  20617667  35616526.0  2126-04-20 07:15:00
# 9005    19999068  21606769  30143796.0  2161-08-24 04:10:00
# 9006    19999442  26785317  32336619.0  2148-11-19 10:00:00
# 9007    19999840  21033226  38978960.0  2164-09-10 13:47:00
#
#            intubationtime  int_itemid  int_weight  ext_stayid  \
# 0     2131-01-11 04:30:00    224385.0        65.0  37510196.0
# 1     2137-08-17 21:21:00    224385.0        90.5  38383343.0
# ...

# %% [markdown]
# -----

# %%
start_time = time.time()

cursor = conn.cursor()
cursor.execute("select * from mimiciv_hosp.patients;")
rows = cursor.fetchall()
columns_name = [desc[0] for desc in cursor.description]
patients = pd.DataFrame(rows, columns=columns_name)

end_time = time.time()
wait_time = end_time - start_time
print("경과 시간 : ", wait_time)

patients
# Out:
# 경과 시간 :  0.34253835678100586
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000068      F          19         2160       2008 - 2010
# 3         10000084      M          72         2160       2017 - 2019
# 4         10000102      F          27         2136       2008 - 2010
# ...            ...    ...         ...          ...               ...
# 299707    19999828      F          46         2147       2017 - 2019
# 299708    19999829      F          28         2186       2008 - 2010
# 299709    19999840      M          58         2164       2008 - 2010
# 299710    19999914      F          49         2158       2017 - 2019
# 299711    19999987      F          57         2145       2011 - 2013
#
#                dod
# 0       2180-09-09
# 1             None
# 2             None
# 3       2161-02-13
# ...

# %%
# 성별 데이터는 그대로 paired_df에 병합 진행

patients2 = patients[["subject_id", "gender"]]
patients2
# Out:
#         subject_id gender
# 0         10000032      F
# 1         10000048      F
# 2         10000068      F
# 3         10000084      M
# 4         10000102      F
# ...            ...    ...
# 299707    19999828      F
# 299708    19999829      F
# 299709    19999840      M
# 299710    19999914      F
# 299711    19999987      F
#
# [299712 rows x 2 columns]

# %%
df_age = df2 >> left_join(patients2, by="subject_id")
df_age
# Out:
#       subject_id   hadm_id  int_stayid            admittime  \
# 0       10001884  26184834  37510196.0  2131-01-07 20:39:00
# 1       10003400  23559586  38383343.0  2137-08-04 00:07:00
# 2       10004401  27939719  31202136.0  2144-04-11 03:31:00
# 3       10004401  29988601  32773003.0  2144-01-23 07:58:00
# 4       10004401  29988601  32773003.0  2144-01-23 07:58:00
# ...          ...       ...         ...                  ...
# 9003    19997367  20617667  35616526.0  2126-04-20 07:15:00
# 9004    19997367  20617667  35616526.0  2126-04-20 07:15:00
# 9005    19999068  21606769  30143796.0  2161-08-24 04:10:00
# 9006    19999442  26785317  32336619.0  2148-11-19 10:00:00
# 9007    19999840  21033226  38978960.0  2164-09-10 13:47:00
#
#            intubationtime  int_itemid  int_weight  ext_stayid  \
# 0     2131-01-11 04:30:00    224385.0        65.0  37510196.0
# 1     2137-08-17 21:21:00    224385.0        90.5  38383343.0
# ...

# %%
df_age["gender"].isna().sum()
# Out:
# 0

# %% [markdown]
# # 내용 정리
# * patients 환자의 성별 추출
# * paired된 데이터 프레임에 left_join 진행
# * gender 값에 NaN 값이 없는 것 확인

# %% [markdown]
# ## 문의사항

# %% [markdown]
# * 없습니다
